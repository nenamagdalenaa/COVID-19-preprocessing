# %%
import os
import json
import zipfile
import pandas as pd
from IPython.display import display
import shutil

# Pad naar de map met ZIP-bestanden en waar alles uitgepakt wordt
input_folder = "/home/nena-meijer/PyCharmMiscProject/VWS_dossiers_zip"
output_folder = "/home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles"

# Maximale bestandsnaam lengte (inclusief extensie)
MAX_FILENAME_LENGTH = 100

# Kies hier het ZIP-bestand dat je wilt testen (pas de naam aan)
test_zip_filename = "Beslissing op bezwaar Wob-besluit coronamaatregelen.zip"  # Zet hier de naam van het ZIP-bestand dat je wilt testen
zip_path = os.path.join(input_folder, test_zip_filename)

# Dossier-ID starten bij 1
dossier_id = 1
extract_path = os.path.join(output_folder, f"dossier_{dossier_id}")

# Zorg dat de map bestaat
os.makedirs(extract_path, exist_ok=True)

# Data opslag
data = []

# ZIP-bestand openen en verwerken
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    for zip_info in zip_ref.infolist():
        if zip_info.is_dir():
            continue  # Skip directories

        # Bepaal originele bestandsnaam en extensie
        original_name = os.path.basename(zip_info.filename)
        file_ext = os.path.splitext(original_name)[1].lower()

        # Beperk de naam tot MAX_FILENAME_LENGTH, behoud de extensie
        base_name = os.path.splitext(original_name)[0]
        if len(base_name) > MAX_FILENAME_LENGTH:
            base_name = base_name[:MAX_FILENAME_LENGTH]
        safe_filename = f"{base_name}{file_ext}"

        # Opslaan op veilige locatie
        safe_path = os.path.join(extract_path, safe_filename)

        # Bestand veilig extraheren
        with zip_ref.open(zip_info) as source, open(safe_path, "wb") as target:
            shutil.copyfileobj(source, target)

# Metadata.json uitlezen (als die bestaat)
metadata_path = os.path.join(extract_path, "metadata.json")
published_date, decision_date = None, None
dossier_name = None
if os.path.exists(metadata_path):
    with open(metadata_path, "r", encoding="utf-8") as f:
        metadata = json.load(f)
        dossier_name = metadata.get("title")
        published_date = metadata.get("published_date")
        decision_date = metadata.get("decision_date")

# Bestandsteller starten
file_counter = 1

# Loop door alle uitgepakte bestanden
for file in os.listdir(extract_path):
    if file == "metadata.json":  # Metadata.json zelf negeren
        continue

    file_path = os.path.join(extract_path, file)
    file_ext = os.path.splitext(file)[1].lower()

    # Genereer file_id (bijv. 1-1, 1-2, etc.)
    file_id = f"{dossier_id}-{file_counter}"
    file_counter += 1  # Verhoog teller

    # Opslaan in lijst
    data.append({
        "dossier_id": dossier_id,
        "dossier_name": dossier_name,
        "file_id": file_id,
        "file_name": file,
        "file_type": file_ext,
        "dossier_published_date": published_date,
        "dossier_decision_date": decision_date
    })

# DataFrame maken en weergeven
df = pd.DataFrame(data)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)
display(df)

# %%
import os
import json
import zipfile
import pandas as pd
from IPython.display import display
import shutil

# Pad naar de map met ZIP-bestanden en waar alles uitgepakt wordt
input_folder = "/home/nena-meijer/PyCharmMiscProject/VWS_dossiers_zip"
output_folder = "/home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles"

# Maximale bestandsnaam lengte (inclusief extensie)
MAX_FILENAME_LENGTH = 100

# Data opslag
data = []

# Zoek alle ZIP-bestanden in de input folder
zip_files = sorted([f for f in os.listdir(input_folder) if f.endswith(".zip")])

# Loop door alle ZIP-bestanden en verwerk ze
for dossier_id, zip_filename in enumerate(zip_files, start=1):
    zip_path = os.path.join(input_folder, zip_filename)
    extract_path = os.path.join(output_folder, f"dossier_{dossier_id}")

    # Zorg dat de map bestaat
    os.makedirs(extract_path, exist_ok=True)

    # ZIP-bestand openen en verwerken
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        for zip_info in zip_ref.infolist():
            if zip_info.is_dir():
                continue  # Skip directories

            # Bepaal originele bestandsnaam en extensie
            original_name = os.path.basename(zip_info.filename)
            file_ext = os.path.splitext(original_name)[1].lower()

            # Beperk de naam tot MAX_FILENAME_LENGTH, behoud de extensie
            base_name = os.path.splitext(original_name)[0]
            if len(base_name) > MAX_FILENAME_LENGTH:
                base_name = base_name[:MAX_FILENAME_LENGTH]
            safe_filename = f"{base_name}{file_ext}"

            # Opslaan op veilige locatie
            safe_path = os.path.join(extract_path, safe_filename)

            # Bestand veilig extraheren
            with zip_ref.open(zip_info) as source, open(safe_path, "wb") as target:
                shutil.copyfileobj(source, target)

    # Metadata.json uitlezen (als die bestaat)
    metadata_path = os.path.join(extract_path, "metadata.json")
    published_date, decision_date, dossier_name = None, None, None
    if os.path.exists(metadata_path):
        with open(metadata_path, "r", encoding="utf-8") as f:
            metadata = json.load(f)
            dossier_name = metadata.get("title")
            published_date = metadata.get("published_date")
            decision_date = metadata.get("decision_date")

    # Datumconversie naar datetime-formaat (indien beschikbaar)
    published_date = pd.to_datetime(published_date, errors='coerce')
    decision_date = pd.to_datetime(decision_date, errors='coerce')

    # Bestandsteller starten
    file_counter = 1

    # Loop door alle uitgepakte bestanden
    for file in os.listdir(extract_path):
        if file == "metadata.json":  # Metadata.json zelf negeren
            continue

        file_path = os.path.join(extract_path, file)
        file_ext = os.path.splitext(file)[1].lower()

        # Genereer file_id (bijv. 1-1, 1-2, etc.)
        file_id = f"{dossier_id}-{file_counter}"
        file_counter += 1  # Verhoog teller

        # Opslaan in lijst
        data.append({
            "dossier_id": dossier_id,
            "dossier_name": dossier_name,
            "file_id": file_id,
            "file_name": file,
            "file_source": file_path,
            "file_type": file_ext,
            "dossier_published_date": published_date,
            "dossier_decision_date": decision_date
        })

# DataFrame maken en weergeven
df = pd.DataFrame(data)

# Instellingen voor brede tabellen en volledige tekstweergave
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)

# DataFrame weergeven
display(df)

# %%
df.to_csv("df.csv", index=False)

# %%
import pandas as pd
from IPython.display import display

# CSV inlezen
df = pd.read_csv("df.csv")

# Filter alleen relevante kolommen
df_filtered = df[["dossier_id", "dossier_name", "file_name", "dossier_published_date", "dossier_decision_date"]]

# Verwijder metadata.json en groepeer per dossier_id
df_aggregated = (
    df_filtered[df_filtered["file_name"] != "metadata.json"]
    .groupby(["dossier_id", "dossier_name", "dossier_published_date", "dossier_decision_date"])
    .agg(document_count=("file_name", "count"))  # Tel documenten per dossier
    .reset_index()
)

# Instellingen om lange tekst volledig te tonen
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)

# DataFrame weergeven in Jupyter Notebook
display(df_aggregated)

# Opslaan als CSV
df_aggregated.to_csv("df_dossiers.csv", index=False)

print("✅ Geaggregeerde CSV opgeslagen als 'df_dossiers.csv'")
# Out:
#      dossier_id                                                                                                                   dossier_name dossier_published_date dossier_decision_date  document_count
# 0             1                                                                   (4e deel) Besluit Woo-verzoek Covid-19 aanpak DOC-19 Q4 2020             2024-02-05            2023-07-29             229
# 1             2                                                                          Woo-besluit aangaande kaders werkproces Wob-verzoeken             2024-03-22            2023-03-20              83
# 2             3                                                                        1e deel Besluit Woo verzoek Covid-19 aanpak ACC Q4 2020             2024-02-07            2022-08-18             208
# 3             4                                                                        2e deel Besluit Woo verzoek Covid-19 aanpak ACC Q1 2021             2024-02-08            2023-02-17             239
# 4             5                                                              3e deel Besluit Woo verzoek Covid-19 aanpak ACC-19 April-Mei 2021             2024-02-07            2022-05-12             144
# ..          ...                                                                                                                            ...                    ...                   ...             ...
# 215         216                                                                       Woo-deelbesluit aangaande overeenkomsten PCR-laboratoria             2024-06-06            2024-03-27              68
# 216         217                                                                 Woo-deelbesluit aangaande vaccinatie aansprakelijkheid Deel II             2024-10-09            2024-10-02             116
# 217         218                                                          Woo-deelbesluit aangaande ‘Capaciteit van ziekenhuizen IC-capaciteit'             2024-10-19            2024-09-12             199
# 218         219  Woo-deelbesluit aangaande ‘de inkoop van persoonlijke beschermingsmiddelen tijdens de coronacrisis en het onderzoek daarnaar’             2024-04-05            2024-02-14            2695
# 219         220                                                         Woo-verzoek d.d. 6 januari 2022 inzake het Europees Herstelfonds (LNV)             2024-02-05            2022-05-12               9
#
# [220 rows x 5 columns]
# ✅ Geaggregeerde CSV opgeslagen als 'df_dossiers.csv'

# %%
import pandas as pd
from IPython.display import display

# CSV inlezen
df = pd.read_csv("df.csv")

# Verwijder spaties in kolomnamen (indien nodig)
df.columns = df.columns.str.strip()

# Controleer of de verwachte kolommen aanwezig zijn
expected_columns = ["dossier_id", "file_name", "file_type"]
missing_columns = [col for col in expected_columns if col not in df.columns]

if missing_columns:
    print(f"❌ De volgende kolommen ontbreken in de CSV: {missing_columns}")
else:
    # Selecteer relevante kolommen en hernoem file_name naar document_title
    df_documents = df[["dossier_id", "file_name", "file_type"]].rename(
        columns={"file_name": "document_title", "file_type": "document_type"}
    )

    # Verwijder metadata.json
    df_documents = df_documents[df_documents["document_title"] != "metadata.json"]

    # Verwijder de punt uit document_type (extensie)
    df_documents["document_type"] = df_documents["document_type"].str.replace(".", "", regex=False)

    # Document-ID toevoegen (per dossier_id een oplopende teller)
    df_documents["document_id"] = (
        df_documents.groupby("dossier_id").cumcount() + 1  # Start teller bij 1 per dossier
    ).astype(str)

    # Combineer document_id met dossier_id
    df_documents["document_id"] = df_documents["dossier_id"].astype(str) + "-" + df_documents["document_id"]

    # Kolommen opnieuw ordenen
    df_documents = df_documents[["dossier_id", "document_id", "document_title", "document_type"]]

    # Opslaan als nieuwe CSV
    df_documents.to_csv("df_documents.csv", index=False)

    # DataFrame weergeven
    display(df_documents)
    print("✅ Geëxporteerd als 'df_documents.csv'")
# Out:
#         dossier_id document_id                                                                            document_title document_type
# 0                1         1-1                        VWS-WC-098-DOC201208J-Concept_Platte_tekst_herijkte_routekaart.pdf           pdf
# 1                1         1-2                         VWS-WC-098-201130D-Actiepuntenlijst_DOC-19_-_27_november_2020.pdf           pdf
# 2                1         1-3                  VWS-WC-098-201127F-Presentatie_verdiepingssessie_vaccinatiestrategie.pdf           pdf
# 3                1         1-4                   VWS-WC-098-201215F-Implementatie_gedragsinterventies_DGSC-19_en_RRT.pdf           pdf
# 4                1         1-5                                       VWS-WC-098-201006A-Agenda_DOC-19_6_oktober_2020.pdf           pdf
# ...            ...         ...                                                                                       ...           ...
# 109029         220       220-5                    VWS-WC-107-2a-2020_RV_0022_Masterplan_emissieloze_maritieme_sector.pdf           pdf
# 109030         220       220-6                      VWS-WC-107-1-FW_Masterplan_voor_een_emissieloze_maritieme_sector.pdf           pdf
# 109031         220       220-7                                        VWS-WC-107-4-video-overleg_Corona_herstelfonds.pdf           pdf
# 109032         220       220-8  VWS-WC-107-3-Vraag_om_informatie_over_RFF_in_relatie_tot_emissiearme_kotter_visserij.pdf           pdf
# 109033         220       220-9                 VWS-WC-107-6-RE_Reactie_gevraagd_op_fiche_emissieloze_kotter_voor_RRF.pdf           pdf
#
# [109034 rows x 4 columns]
# ✅ Geëxporteerd als 'df_documents.csv'

# %%
import time

def scrape_document_metadata(dossier_url):
    """Scrapet documentmetadata van alle pagina's binnen een dossier met een crawl delay."""

    # Extract dossier ID uit de URL
    dossier_id_match = re.search(r'/dossier/([^/]+)', dossier_url)
    dossier_id_str = dossier_id_match.group(1) if dossier_id_match else None

    metadata_list = []
    seen_documents = set()
    page = 1
    max_pages = 50  # Failsafe om te voorkomen dat hij oneindig blijft lopen

    while page <= max_pages:
        paged_url = f"{dossier_url}?prefix=VWS-WC&dossierId={dossier_id_str}&pu={page}#tabcontrol-1"
        response = requests.get(paged_url)
        if response.status_code != 200:
            print(f"Fout bij ophalen van {paged_url}")
            break

        soup = BeautifulSoup(response.text, "html.parser")
        table_rows = soup.select(".woo-table tbody tr")
        if not table_rows:
            print(f"Geen documenten gevonden op pagina {page}, stoppen met scrapen.")
            break

        new_documents_found = False

        for row in table_rows:
            try:
                # Document ID ophalen uit de eerste kolom
                doc_id_tag = row.select_one("td:nth-of-type(1)")
                doc_id = doc_id_tag.text.strip() if doc_id_tag else None

                # Document URL ophalen
                doc_link_tag = row.select_one("td:nth-of-type(3) a")
                doc_url = doc_link_tag["href"] if doc_link_tag else ""

                if not doc_id or doc_id in seen_documents:
                    continue

                seen_documents.add(doc_id)
                new_documents_found = True

                # Documenttype
                doc_type_tag = row.select_one("td:nth-of-type(2) use")
                doc_type_key = doc_type_tag["xlink:href"].split("#")[-1] if doc_type_tag else "unknown"
                doc_type = DOCUMENT_TYPE_MAP.get(doc_type_key, "Onbekend")

                # Documentdatum correct ophalen
                doc_date_tag = row.select_one("td:nth-of-type(4) time")
                doc_date = doc_date_tag["datetime"] if doc_date_tag else None

                metadata_list.append({
                    "document_id": doc_id,
                    "document_sourcetype": doc_type,
                    "document_date": doc_date,
                    "dossier_id": dossier_id
                })
            except Exception as e:
                print(f"Fout bij parsen: {e}")

        if not new_documents_found:
            print(f"Geen nieuwe documenten meer gevonden op pagina {page}, stoppen met scrapen.")
            break

        page += 1
        time.sleep(1)  # Crawl delay na elke pagina scrape

    for doc in metadata_list:
        print(doc)

    return metadata_list

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# Mapping van documenttypes
DOCUMENT_TYPE_MAP = {
    "unknown": "Onbekend",
    "pdf": "PDF",
    "email": "E-mailbericht",
    "presentation": "Presentatie",
    "doc": "Word-document",
    "chat": "Chatbericht",
    "image": "Afbeelding",
    "spreadsheet": "Spreadsheet"
}

# Inlezen van de bestaande documentgegevens
df_documents = pd.read_csv("df_documents_dates.csv", dtype={"document_id": str})
df_dossiers = pd.read_csv("df_dossiers_final.csv", dtype={"dossier_id": int})

# Handmatig dossier_id invoeren
dossier_id = 130

dossier = df_dossiers[df_dossiers["dossier_id"] == dossier_id].iloc[0]
dossier_url = dossier["dossier_sourceURL"]

print(f"Scrapen: {dossier_url}")
document_metadata = scrape_document_metadata(dossier_url)

# Omzetten naar dataframe
df_metadata = pd.DataFrame(document_metadata)

def extract_prefix(document_title):
    """Probeert het juiste dossierprefix te extraheren uit de document_title."""

    # Specifieke uitzondering: als het document begint met "VWS-WC-19.00-1-", dan is de prefix gewoon "VWS-WC"
    if document_title.startswith("VWS-WC-44"):
        return "VWS-WC-44"

    # Standaardpatronen voor prefixes
    match = re.match(r"^(VWS-WC-\d{3}|VWS-WOO-[A-Za-z0-9]+|VWS-WC)", document_title)
    return match.group(1) if match else None

def match_documents(df_documents, df_metadata, dossier_id):
    """Matcht gescrapete metadata met documenten op basis van dossierprefix en document_id."""
    df_documents_dossier = df_documents[df_documents["dossier_id"] == dossier_id]

    if df_documents_dossier.empty:
        print(f"⚠️ Geen documenten gevonden voor dossier_id {dossier_id}")
        return df_documents

    # Zoek het eerste document dat GEEN generieke naam heeft
    sample_document_title = None
    for title in df_documents_dossier["document_title"]:
        if not title.lower().startswith("besluitbrief"):  # Voeg andere generieke namen toe indien nodig
            sample_document_title = title
            break

    if not sample_document_title:
        print(f"❌ Geen geldig document gevonden om een prefix uit te halen voor dossier {dossier_id}.")
        return df_documents

    dossier_prefix = extract_prefix(sample_document_title)

    if not dossier_prefix:
        print(f"❌ Geen geldig dossierprefix gevonden in: {sample_document_title}")
        return df_documents

    print(f"🔎 Dossierprefix bepaald als: {dossier_prefix}")

    for i, doc_row in df_documents_dossier.iterrows():
        document_title = doc_row["document_title"]
        print(f"\n---\n🔍 Matching document: {document_title}")

        for _, meta_row in df_metadata.iterrows():
            meta_doc_id = str(meta_row["document_id"]).strip()  # Zorgt dat het ID een string is
            expected_identifier = f"{dossier_prefix}-{meta_doc_id}"  # Verwachte match

            # Exacte match met regex
            if re.search(rf"\b{re.escape(expected_identifier)}\b", document_title):
                print(f"  ✅ MATCH GEVONDEN! Updaten document {meta_doc_id}")

                df_documents.at[i, "document_sourcetype"] = meta_row["document_sourcetype"]
                df_documents.at[i, "document_date"] = meta_row["document_date"]

                # Print de waarde die in de CSV wordt gezet
                print(f"  📌 In CSV zetten → Type: {meta_row['document_sourcetype']}, Datum: {meta_row['document_date']}")
                break  # Stop met zoeken zodra de match is gevonden

    return df_documents

df_documents = match_documents(df_documents, df_metadata, dossier_id)

# Opslaan van de verrijkte dataset
df_documents.to_csv("df_documents_dates.csv", index=False)
print(f"Scraping en verrijking voltooid voor dossier {dossier_id}!")
print(dossier_url)
# Out:
# Scrapen: https://open.minvws.nl/dossier/VWS-WOO/3289906-1020870-wjz
# Geen nieuwe documenten meer gevonden op pagina 39, stoppen met scrapen.
# {'document_id': 'Gedeeltelijke openbaarmaking', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': 'Wob-besluit', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': '211130 Wob-deelbesluit RIVM mei 2020, 3289906-1020870-WJZ_Geredigeerd.pdf (PDF, 3.22 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': 'ministerie van Volksgezondheid, Welzijn en Sport', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': 'Mei 2020', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': '30 november 2021', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': "5.627 documenten,                        \n                                                    11.159 pagina's\n                            \n                                                \nInventarislijst", 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': 'RIVM', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': '270574', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '270606', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-11', 'dossier_id': 130}
# {'document_id': '270608', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '270609', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '270611', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-25', 'dossier_id': 130}
# {'document_id': '270612', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '270628', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '270632', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '270635', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '270657', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '270659', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '270664', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-06-02', 'dossier_id': 130}
# {'document_id': '270674', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '270696', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '270697', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '270700', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '270702', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '270709', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '270710', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-19', 'dossier_id': 130}
# {'document_id': '270712', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-22', 'dossier_id': 130}
# {'document_id': '270715', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '270745', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-06-09', 'dossier_id': 130}
# {'document_id': '270746', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '270783', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-28', 'dossier_id': 130}
# {'document_id': '270807', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '270811', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-06-03', 'dossier_id': 130}
# {'document_id': '286949', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286951', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286955', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286956', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286957', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286958', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286961', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286976', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286983', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286989', 'document_sourcetype': 'PDF', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '286992', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286993', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '286994', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-15', 'dossier_id': 130}
# {'document_id': '286995', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-08', 'dossier_id': 130}
# {'document_id': '286996', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286997', 'document_sourcetype': 'PDF', 'document_date': '2020-05-08', 'dossier_id': 130}
# {'document_id': '287001', 'document_sourcetype': 'PDF', 'document_date': '2020-05-05', 'dossier_id': 130}
# {'document_id': '287003', 'document_sourcetype': 'PDF', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '287008', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287010', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287012', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287016', 'document_sourcetype': 'PDF', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '287022', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '287026', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-25', 'dossier_id': 130}
# {'document_id': '287029', 'document_sourcetype': 'PDF', 'document_date': '2020-05-25', 'dossier_id': 130}
# {'document_id': '287036', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287039', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287065', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287066', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287071', 'document_sourcetype': 'PDF', 'document_date': '2020-05-01', 'dossier_id': 130}
# {'document_id': '287074', 'document_sourcetype': 'PDF', 'document_date': '2020-05-01', 'dossier_id': 130}
# {'document_id': '287077', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-01', 'dossier_id': 130}
# {'document_id': '287090', 'document_sourcetype': 'Spreadsheet', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287091', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '287092', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '287093', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287096', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287097', 'document_sourcetype': 'PDF', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '287106', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287108', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287109', 'document_sourcetype': 'PDF', 'document_date': '2020-05-11', 'dossier_id': 130}
# {'document_id': '287112', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287119', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '287125', 'document_sourcetype': 'PDF', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287127', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-15', 'dossier_id': 130}
# {'document_id': '287133', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287134', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '287136', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '287137', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287138', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-19', 'dossier_id': 130}
# {'document_id': '287139', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-19', 'dossier_id': 130}
# {'document_id': '287140', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '287142', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287143', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287149', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287153', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '287154', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-28', 'dossier_id': 130}
# {'document_id': '287157', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287160', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287165', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287167', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287173', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287176', 'document_sourcetype': 'PDF', 'document_date': '2020-05-05', 'dossier_id': 130}
# {'document_id': '287178', 'document_sourcetype': 'PDF', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287180', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287181', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '287182', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-01', 'dossier_id': 130}
# {'document_id': '287186', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287208', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-05', 'dossier_id': 130}
# {'document_id': '287209', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287210', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287217', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287218', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '287219', 'document_sourcetype': 'PDF', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '286999', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287045', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287054', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287056', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287058', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287060', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287159', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '287162', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287196', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287202', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287223', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286953', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286967', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286969', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286971', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286979', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286981', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286986', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287094', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287453', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287367', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287406', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-15', 'dossier_id': 130}
# {'document_id': '287408', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '287450', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287464', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-03', 'dossier_id': 130}
# {'document_id': '287466', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287488', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-25', 'dossier_id': 130}
# {'document_id': '287541', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '287575', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-30', 'dossier_id': 130}
# {'document_id': '287588', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-30', 'dossier_id': 130}
# {'document_id': '287594', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-30', 'dossier_id': 130}
# {'document_id': '287643', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-30', 'dossier_id': 130}
# {'document_id': '287655', 'document_sourcetype': 'Onbekend', 'document_date': '2021-01-07', 'dossier_id': 130}
# {'document_id': '287771', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '287773', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-26', 'dossier_id': 130}
# {'document_id': '287774', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-17', 'dossier_id': 130}
# {'document_id': '287776', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 130}
# {'document_id': '287821', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '288053', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-02', 'dossier_id': 130}
# {'document_id': '288057', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '288059', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '288192', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-10', 'dossier_id': 130}
# {'document_id': '288600', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-28', 'dossier_id': 130}
# {'document_id': '288611', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-02', 'dossier_id': 130}
# {'document_id': '288613', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-22', 'dossier_id': 130}
# {'document_id': '288877', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '288933', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-10', 'dossier_id': 130}
# {'document_id': '288982', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-10', 'dossier_id': 130}
# {'document_id': '288986', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-10', 'dossier_id': 130}
# {'document_id': '289201', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-29', 'dossier_id': 130}
# {'document_id': '289256', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-03', 'dossier_id': 130}
# {'document_id': '289269', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-03', 'dossier_id': 130}
# {'document_id': '289326', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-29', 'dossier_id': 130}
# {'document_id': '289420', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-03', 'dossier_id': 130}
# {'document_id': '289424', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-03', 'dossier_id': 130}
# {'document_id': '289520', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-24', 'dossier_id': 130}
# {'document_id': '289579', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-08', 'dossier_id': 130}
# {'document_id': '289593', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-08', 'dossier_id': 130}
# {'document_id': '289595', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '289614', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '289656', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '289658', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '289691', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-05', 'dossier_id': 130}
# {'document_id': '289785', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-06', 'dossier_id': 130}
# {'document_id': '289840', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '289876', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-11', 'dossier_id': 130}
# {'document_id': '290018', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-10', 'dossier_id': 130}
# {'document_id': '290064', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-11', 'dossier_id': 130}
# {'document_id': '290072', 'document_sourcetype': 'Onbekend', 'document_date': '2020-11-10', 'dossier_id': 130}
# {'document_id': '290112', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '290126', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-15', 'dossier_id': 130}
# {'document_id': '290171', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 130}
# {'document_id': '290173', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-05', 'dossier_id': 130}
# {'document_id': '290300', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '290301', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-29', 'dossier_id': 130}
# {'document_id': '290313', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '290438', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-17', 'dossier_id': 130}
# {'document_id': '290480', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '290483', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '290487', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '290489', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '290494', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '290498', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '290569', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '290591', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '290607', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '290609', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '290611', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '290612', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '290624', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-28', 'dossier_id': 130}
# {'document_id': '290626', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '290630', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '290655', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-11', 'dossier_id': 130}
# {'document_id': '290670', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '287507', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287041', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287062', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287069', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287158', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-01', 'dossier_id': 130}
# {'document_id': '288739', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '286991', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287005', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287006', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287007', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287009', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287014', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287015', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '287018', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287019', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287020', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287023', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287027', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287031', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287032', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287033', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287034', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287035', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287038', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287043', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287044', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287050', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '287051', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '287052', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '287053', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287064', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287068', 'document_sourcetype': 'Spreadsheet', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287073', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287076', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287078', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287079', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287080', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287081', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287082', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '287084', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '287085', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '287087', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287089', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287099', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287100', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287103', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287105', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287107', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287113', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287117', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287118', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287114', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '287115', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287121', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287122', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287123', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287124', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287128', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '287129', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287130', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '287141', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287144', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287145', 'document_sourcetype': 'Presentatie', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287147', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287148', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287150', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287151', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287155', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '287156', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '287174', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287170', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '287171', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '287175', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '287183', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287206', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287207', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287213', 'document_sourcetype': 'PDF', 'document_date': '2020-05-11', 'dossier_id': 130}
# {'document_id': '287215', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-26', 'dossier_id': 130}
# {'document_id': '287216', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '287221', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287222', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287226', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '270678', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '286964', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286966', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286973', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286977', 'document_sourcetype': 'Presentatie', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286978', 'document_sourcetype': 'Presentatie', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '286985', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287024', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287168', 'document_sourcetype': 'PDF', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '287184', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '287187', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-15', 'dossier_id': 130}
# {'document_id': '287188', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-19', 'dossier_id': 130}
# {'document_id': '287190', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '270555', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-08', 'dossier_id': 130}
# {'document_id': '286963', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '270557', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-12-14', 'dossier_id': 130}
# {'document_id': '287049', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '287088', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287163', 'document_sourcetype': 'PDF', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287185', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '287191', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-26', 'dossier_id': 130}
# {'document_id': '287192', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-29', 'dossier_id': 130}
# {'document_id': '287193', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287194', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-11', 'dossier_id': 130}
# {'document_id': '290616', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-04-29', 'dossier_id': 130}
# {'document_id': '290636', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-24', 'dossier_id': 130}
# {'document_id': '299651', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '301047', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-19', 'dossier_id': 130}
# {'document_id': '301049', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '301075', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '301482', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '13 februari 2025 14:58', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': '12 februari 2025 10:58', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': '27 november 2024 10:27', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': '25 november 2024 17:18', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 130}
# {'document_id': '287225', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '287227', 'document_sourcetype': 'PDF', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '287273', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287274', 'document_sourcetype': 'PDF', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '287276', 'document_sourcetype': 'PDF', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287278', 'document_sourcetype': 'PDF', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '287280', 'document_sourcetype': 'PDF', 'document_date': '2020-05-25', 'dossier_id': 130}
# {'document_id': '287282', 'document_sourcetype': 'PDF', 'document_date': '2020-05-26', 'dossier_id': 130}
# {'document_id': '287284', 'document_sourcetype': 'PDF', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '287286', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287288', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287289', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287291', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287294', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287298', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287299', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287300', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287301', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287303', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287311', 'document_sourcetype': 'PDF', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '287313', 'document_sourcetype': 'PDF', 'document_date': '2020-05-19', 'dossier_id': 130}
# {'document_id': '287315', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-01', 'dossier_id': 130}
# {'document_id': '287316', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287321', 'document_sourcetype': 'PDF', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '287324', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-01', 'dossier_id': 130}
# {'document_id': '287331', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-06', 'dossier_id': 130}
# {'document_id': '287333', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-08', 'dossier_id': 130}
# {'document_id': '287334', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-08', 'dossier_id': 130}
# {'document_id': '287337', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287338', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287342', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287343', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287344', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287345', 'document_sourcetype': 'PDF', 'document_date': '2020-05-25', 'dossier_id': 130}
# {'document_id': '287347', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287350', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287351', 'document_sourcetype': 'PDF', 'document_date': '2020-05-17', 'dossier_id': 130}
# {'document_id': '287353', 'document_sourcetype': 'PDF', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '287355', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287356', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287357', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287358', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287360', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287363', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287364', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287366', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287380', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287385', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287386', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-08', 'dossier_id': 130}
# {'document_id': '287389', 'document_sourcetype': 'PDF', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '287397', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-11', 'dossier_id': 130}
# {'document_id': '287398', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-28', 'dossier_id': 130}
# {'document_id': '287399', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-15', 'dossier_id': 130}
# {'document_id': '287402', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-28', 'dossier_id': 130}
# {'document_id': '287403', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287404', 'document_sourcetype': 'PDF', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '287411', 'document_sourcetype': 'PDF', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287413', 'document_sourcetype': 'PDF', 'document_date': '2020-05-28', 'dossier_id': 130}
# {'document_id': '287415', 'document_sourcetype': 'PDF', 'document_date': '2020-05-27', 'dossier_id': 130}
# {'document_id': '287418', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287419', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287420', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287421', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287423', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287424', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287426', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287427', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '287428', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287430', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-05', 'dossier_id': 130}
# {'document_id': '287431', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-18', 'dossier_id': 130}
# {'document_id': '287432', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '287434', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '287435', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287436', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-28', 'dossier_id': 130}
# {'document_id': '287438', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-07', 'dossier_id': 130}
# {'document_id': '287439', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287440', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287441', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287442', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-12', 'dossier_id': 130}
# {'document_id': '287454', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287455', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287456', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287457', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-13', 'dossier_id': 130}
# {'document_id': '287458', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287459', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287460', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-20', 'dossier_id': 130}
# {'document_id': '287461', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-19', 'dossier_id': 130}
# {'document_id': '287468', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '287472', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-19', 'dossier_id': 130}
# {'document_id': '287473', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287484', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-14', 'dossier_id': 130}
# {'document_id': '287491', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-28', 'dossier_id': 130}
# {'document_id': '287492', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287495', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-28', 'dossier_id': 130}
# {'document_id': '287496', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-05', 'dossier_id': 130}
# {'document_id': '287499', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-04', 'dossier_id': 130}
# {'document_id': '287501', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287502', 'document_sourcetype': 'PDF', 'document_date': '2020-08-04', 'dossier_id': 130}
# {'document_id': '287505', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-01', 'dossier_id': 130}
# {'document_id': '287506', 'document_sourcetype': 'Word-document', 'document_date': '2020-05-25', 'dossier_id': 130}
# ...
#   ✅ MATCH GEVONDEN! Updaten document 287091
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-06
#
# ---
# 🔍 Matching document: VWS-WOO-03-287418.pdf
#   ✅ MATCH GEVONDEN! Updaten document 287418
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-04
#
# ---
# 🔍 Matching document: VWS-WOO-03-294884.pdf
#   ✅ MATCH GEVONDEN! Updaten document 294884
#   📌 In CSV zetten → Type: PDF, Datum: 2020-11-10
#
# ---
# 🔍 Matching document: VWS-WOO-03-287608.pdf
#   ✅ MATCH GEVONDEN! Updaten document 287608
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-01-07
#
# ---
# 🔍 Matching document: VWS-WOO-03-289666.pdf
#   ✅ MATCH GEVONDEN! Updaten document 289666
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-14
#
# ---
# 🔍 Matching document: VWS-WOO-03-296398.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296398
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-05
#
# ---
# 🔍 Matching document: VWS-WOO-03-290768.pdf
#   ✅ MATCH GEVONDEN! Updaten document 290768
#   📌 In CSV zetten → Type: PDF, Datum: 2020-05-15
#
# ---
# 🔍 Matching document: VWS-WOO-03-297238.pdf
#   ✅ MATCH GEVONDEN! Updaten document 297238
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-16
#
# ---
# 🔍 Matching document: VWS-WOO-03-289388.pdf
#   ✅ MATCH GEVONDEN! Updaten document 289388
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-01
#
# ---
# 🔍 Matching document: VWS-WOO-03-292290.pdf
#   ✅ MATCH GEVONDEN! Updaten document 292290
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-20
#
# ---
# 🔍 Matching document: VWS-WOO-03-296067.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296067
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-06
#
# ---
# 🔍 Matching document: VWS-WOO-03-288541.pdf
#   ✅ MATCH GEVONDEN! Updaten document 288541
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-25
#
# ---
# 🔍 Matching document: VWS-WOO-03-287435.pdf
#   ✅ MATCH GEVONDEN! Updaten document 287435
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-04
#
# ---
# 🔍 Matching document: VWS-WOO-03-300110.pdf
#   ✅ MATCH GEVONDEN! Updaten document 300110
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-05
#
# ---
# 🔍 Matching document: VWS-WOO-03-297945.pdf
#   ✅ MATCH GEVONDEN! Updaten document 297945
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-15
#
# ---
# 🔍 Matching document: VWS-WOO-03-296667.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296667
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-27
#
# ---
# 🔍 Matching document: VWS-WOO-03-288549.pdf
#   ✅ MATCH GEVONDEN! Updaten document 288549
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-25
#
# ---
# 🔍 Matching document: VWS-WOO-03-298753.pdf
#   ✅ MATCH GEVONDEN! Updaten document 298753
#   📌 In CSV zetten → Type: PDF, Datum: 2020-05-08
#
# ---
# 🔍 Matching document: VWS-WOO-03-301465.pdf
#   ✅ MATCH GEVONDEN! Updaten document 301465
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-26
#
# ---
# 🔍 Matching document: VWS-WOO-03-293944.pdf
#   ✅ MATCH GEVONDEN! Updaten document 293944
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-08
#
# ---
# 🔍 Matching document: VWS-WOO-03-288054.pdf
#   ✅ MATCH GEVONDEN! Updaten document 288054
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-15
#
# ---
# 🔍 Matching document: VWS-WOO-03-297185.pdf
#   ✅ MATCH GEVONDEN! Updaten document 297185
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-06-04
#
# ---
# 🔍 Matching document: VWS-WOO-03-299225.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299225
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-14
#
# ---
# 🔍 Matching document: VWS-WOO-03-296834.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296834
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-14
#
# ---
# 🔍 Matching document: VWS-WOO-03-296507.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296507
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-13
#
# ---
# 🔍 Matching document: VWS-WOO-03-299012.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299012
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-20
#
# ---
# 🔍 Matching document: VWS-WOO-03-291680.pdf
#   ✅ MATCH GEVONDEN! Updaten document 291680
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-02
#
# ---
# 🔍 Matching document: VWS-WOO-03-300281.pdf
#   ✅ MATCH GEVONDEN! Updaten document 300281
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-04
#
# ---
# 🔍 Matching document: VWS-WOO-03-294772.pdf
#   ✅ MATCH GEVONDEN! Updaten document 294772
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-07-02
#
# ---
# 🔍 Matching document: VWS-WOO-03-292387.pdf
#   ✅ MATCH GEVONDEN! Updaten document 292387
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-19
#
# ---
# 🔍 Matching document: VWS-WOO-03-300423.pdf
#   ✅ MATCH GEVONDEN! Updaten document 300423
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-27
#
# ---
# 🔍 Matching document: VWS-WOO-03-299832.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299832
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-28
#
# ---
# 🔍 Matching document: VWS-WOO-03-289362.pdf
#   ✅ MATCH GEVONDEN! Updaten document 289362
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-15
#
# ---
# 🔍 Matching document: VWS-WOO-03-294657.pdf
#   ✅ MATCH GEVONDEN! Updaten document 294657
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-12
#
# ---
# 🔍 Matching document: VWS-WOO-03-295446.pdf
#   ✅ MATCH GEVONDEN! Updaten document 295446
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-18
#
# ---
# 🔍 Matching document: VWS-WOO-03-296475.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296475
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-06
#
# ---
# 🔍 Matching document: VWS-WOO-03-290384.pdf
#   ✅ MATCH GEVONDEN! Updaten document 290384
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-19
#
# ---
# 🔍 Matching document: VWS-WOO-03-298371.pdf
#   ✅ MATCH GEVONDEN! Updaten document 298371
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-11
#
# ---
# 🔍 Matching document: VWS-WOO-03-289109.pdf
#   ✅ MATCH GEVONDEN! Updaten document 289109
#   📌 In CSV zetten → Type: PDF, Datum: 2020-05-15
#
# ---
# 🔍 Matching document: VWS-WOO-03-301590.pdf
#   ✅ MATCH GEVONDEN! Updaten document 301590
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-11
#
# ---
# 🔍 Matching document: VWS-WOO-03-296882.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296882
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-25
#
# ---
# 🔍 Matching document: VWS-WOO-03-296886.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296886
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-29
#
# ---
# 🔍 Matching document: VWS-WOO-03-290955.pdf
#   ✅ MATCH GEVONDEN! Updaten document 290955
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-06
#
# ---
# 🔍 Matching document: VWS-WOO-03-290061.pdf
#   ✅ MATCH GEVONDEN! Updaten document 290061
#   📌 In CSV zetten → Type: PDF, Datum: 2020-05-05
#
# ---
# 🔍 Matching document: VWS-WOO-03-295913.pdf
#   ✅ MATCH GEVONDEN! Updaten document 295913
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-28
#
# ---
# 🔍 Matching document: VWS-WOO-03-299985.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299985
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-17
#
# ---
# 🔍 Matching document: VWS-WOO-03-300785.pdf
#   ✅ MATCH GEVONDEN! Updaten document 300785
#   📌 In CSV zetten → Type: PDF, Datum: 2020-05-18
#
# ---
# 🔍 Matching document: VWS-WOO-03-289850.pdf
#   ✅ MATCH GEVONDEN! Updaten document 289850
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-30
#
# ---
# 🔍 Matching document: VWS-WOO-03-297871.pdf
#   ✅ MATCH GEVONDEN! Updaten document 297871
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-27
#
# ---
# 🔍 Matching document: VWS-WOO-03-291492.pdf
#   ✅ MATCH GEVONDEN! Updaten document 291492
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-11
#
# ---
# 🔍 Matching document: VWS-WOO-03-295588.pdf
#   ✅ MATCH GEVONDEN! Updaten document 295588
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-15
#
# ---
# 🔍 Matching document: VWS-WOO-03-290988.pdf
#   ✅ MATCH GEVONDEN! Updaten document 290988
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-09-25
#
# ---
# 🔍 Matching document: VWS-WOO-03-301913.pdf
#   ✅ MATCH GEVONDEN! Updaten document 301913
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-26
#
# ---
# 🔍 Matching document: VWS-WOO-03-287759.pdf
#   ✅ MATCH GEVONDEN! Updaten document 287759
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-11
#
# ---
# 🔍 Matching document: VWS-WOO-03-299114.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299114
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-11
#
# ---
# 🔍 Matching document: VWS-WOO-03-286958.pdf
#   ✅ MATCH GEVONDEN! Updaten document 286958
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-04
#
# ---
# 🔍 Matching document: VWS-WOO-03-289745.pdf
#   ✅ MATCH GEVONDEN! Updaten document 289745
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-18
#
# ---
# 🔍 Matching document: VWS-WOO-03-300284.pdf
#   ✅ MATCH GEVONDEN! Updaten document 300284
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-04
#
# ---
# 🔍 Matching document: VWS-WOO-03-299487.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299487
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-27
#
# ---
# 🔍 Matching document: VWS-WOO-03-293854.pdf
#   ✅ MATCH GEVONDEN! Updaten document 293854
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-26
#
# ---
# 🔍 Matching document: VWS-WOO-03-294778.pdf
#   ✅ MATCH GEVONDEN! Updaten document 294778
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-07-15
#
# ---
# 🔍 Matching document: VWS-WOO-03-293127.pdf
#   ✅ MATCH GEVONDEN! Updaten document 293127
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-05
#
# ---
# 🔍 Matching document: VWS-WOO-03-290993.pdf
#   ✅ MATCH GEVONDEN! Updaten document 290993
#   📌 In CSV zetten → Type: Spreadsheet, Datum: 2020-05-05
#
# ---
# 🔍 Matching document: VWS-WOO-03-297908.pdf
#   ✅ MATCH GEVONDEN! Updaten document 297908
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-14
#
# ---
# 🔍 Matching document: VWS-WOO-03-299326.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299326
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-15
#
# ---
# 🔍 Matching document: VWS-WOO-03-296381.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296381
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-04
#
# ---
# 🔍 Matching document: VWS-WOO-03-299153.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299153
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-29
#
# ---
# 🔍 Matching document: VWS-WOO-03-296711.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296711
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-25
#
# ---
# 🔍 Matching document: VWS-WOO-03-295469.pdf
#   ✅ MATCH GEVONDEN! Updaten document 295469
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-13
#
# ---
# 🔍 Matching document: VWS-WOO-03-300644.pdf
#   ✅ MATCH GEVONDEN! Updaten document 300644
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-28
#
# ---
# 🔍 Matching document: VWS-WOO-03-299704.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299704
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-15
#
# ---
# 🔍 Matching document: VWS-WOO-03-298078.pdf
#   ✅ MATCH GEVONDEN! Updaten document 298078
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-27
#
# ---
# 🔍 Matching document: VWS-WOO-03-300681.pdf
#   ✅ MATCH GEVONDEN! Updaten document 300681
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-18
#
# ---
# 🔍 Matching document: VWS-WOO-03-293665.pdf
#   ✅ MATCH GEVONDEN! Updaten document 293665
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-07
#
# ---
# 🔍 Matching document: VWS-WOO-03-290648.pdf
#   ✅ MATCH GEVONDEN! Updaten document 290648
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-12
#
# ---
# 🔍 Matching document: VWS-WOO-03-295596.pdf
#   ✅ MATCH GEVONDEN! Updaten document 295596
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-14
#
# ---
# 🔍 Matching document: VWS-WOO-03-289899.pdf
#   ✅ MATCH GEVONDEN! Updaten document 289899
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-26
#
# ---
# 🔍 Matching document: VWS-WOO-03-300503.pdf
#   ✅ MATCH GEVONDEN! Updaten document 300503
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-04
#
# ---
# 🔍 Matching document: VWS-WOO-03-301258.pdf
#   ✅ MATCH GEVONDEN! Updaten document 301258
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-06
#
# ---
# 🔍 Matching document: VWS-WOO-03-296623.pdf
#   ✅ MATCH GEVONDEN! Updaten document 296623
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-28
#
# ---
# 🔍 Matching document: VWS-WOO-03-294635.pdf
#   ✅ MATCH GEVONDEN! Updaten document 294635
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-06
#
# ---
# 🔍 Matching document: VWS-WOO-03-291631.pdf
#   ✅ MATCH GEVONDEN! Updaten document 291631
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-12
#
# ---
# 🔍 Matching document: VWS-WOO-03-289499.pdf
#   ✅ MATCH GEVONDEN! Updaten document 289499
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-11
#
# ---
# 🔍 Matching document: VWS-WOO-03-295459.pdf
#   ✅ MATCH GEVONDEN! Updaten document 295459
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-29
#
# ---
# 🔍 Matching document: VWS-WOO-03-298077.pdf
#   ✅ MATCH GEVONDEN! Updaten document 298077
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-11
#
# ---
# 🔍 Matching document: VWS-WOO-03-299070.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299070
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-25
#
# ---
# 🔍 Matching document: VWS-WOO-03-292463.pdf
#   ✅ MATCH GEVONDEN! Updaten document 292463
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-27
#
# ---
# 🔍 Matching document: VWS-WOO-03-299739.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299739
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-17
#
# ---
# 🔍 Matching document: VWS-WOO-03-301914.pdf
#   ✅ MATCH GEVONDEN! Updaten document 301914
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-27
#
# ---
# 🔍 Matching document: VWS-WOO-03-291146.pdf
#   ✅ MATCH GEVONDEN! Updaten document 291146
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-18
#
# ---
# 🔍 Matching document: VWS-WOO-03-291887.pdf
#   ✅ MATCH GEVONDEN! Updaten document 291887
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-08
#
# ---
# 🔍 Matching document: VWS-WOO-03-289213.pdf
#   ✅ MATCH GEVONDEN! Updaten document 289213
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-26
#
# ---
# 🔍 Matching document: VWS-WOO-03-299363.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299363
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-04
#
# ---
# 🔍 Matching document: VWS-WOO-03-300534.pdf
#   ✅ MATCH GEVONDEN! Updaten document 300534
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-05
#
# ---
# 🔍 Matching document: VWS-WOO-03-298627.pdf
#   ✅ MATCH GEVONDEN! Updaten document 298627
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-05-31
#
# ---
# 🔍 Matching document: VWS-WOO-03-297144.pdf
#   ✅ MATCH GEVONDEN! Updaten document 297144
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-06
#
# ---
# 🔍 Matching document: VWS-WOO-03-288286.pdf
#   ✅ MATCH GEVONDEN! Updaten document 288286
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-05
#
# ---
# 🔍 Matching document: VWS-WOO-03-300852.pdf
#   ✅ MATCH GEVONDEN! Updaten document 300852
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-26
#
# ---
# 🔍 Matching document: VWS-WOO-03-290115.pdf
#   ✅ MATCH GEVONDEN! Updaten document 290115
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-13
#
# ---
# 🔍 Matching document: VWS-WOO-03-291102.pdf
#   ✅ MATCH GEVONDEN! Updaten document 291102
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-06
#
# ---
# 🔍 Matching document: VWS-WOO-03-287502.pdf
#   ✅ MATCH GEVONDEN! Updaten document 287502
#   📌 In CSV zetten → Type: PDF, Datum: 2020-08-04
#
# ---
# 🔍 Matching document: VWS-WOO-03-293178.pdf
#   ✅ MATCH GEVONDEN! Updaten document 293178
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-15
#
# ---
# 🔍 Matching document: VWS-WOO-03-293862.pdf
#   ✅ MATCH GEVONDEN! Updaten document 293862
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-20
#
# ---
# 🔍 Matching document: VWS-WOO-03-297007.pdf
#   ✅ MATCH GEVONDEN! Updaten document 297007
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-25
#
# ---
# 🔍 Matching document: VWS-WOO-03-299967.pdf
#   ✅ MATCH GEVONDEN! Updaten document 299967
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-18
#
# ---
# 🔍 Matching document: VWS-WOO-03-293715.pdf
#   ✅ MATCH GEVONDEN! Updaten document 293715
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-05-07
# Scraping en verrijking voltooid voor dossier 130!
# https://open.minvws.nl/dossier/VWS-WOO/3289906-1020870-wjz
