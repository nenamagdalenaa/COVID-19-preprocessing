# %%
import os
import json
import zipfile
import pandas as pd
from IPython.display import display
import shutil

# Pad naar de map met ZIP-bestanden en waar alles uitgepakt wordt
input_folder = "/home/nena-meijer/PyCharmMiscProject/VWS_dossiers_zip"
output_folder = "/home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles"

# Maximale bestandsnaam lengte (inclusief extensie)
MAX_FILENAME_LENGTH = 100

# Kies hier het ZIP-bestand dat je wilt testen (pas de naam aan)
test_zip_filename = "Beslissing op bezwaar Wob-besluit coronamaatregelen.zip"  # Zet hier de naam van het ZIP-bestand dat je wilt testen
zip_path = os.path.join(input_folder, test_zip_filename)

# Dossier-ID starten bij 1
dossier_id = 1
extract_path = os.path.join(output_folder, f"dossier_{dossier_id}")

# Zorg dat de map bestaat
os.makedirs(extract_path, exist_ok=True)

# Data opslag
data = []

# ZIP-bestand openen en verwerken
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    for zip_info in zip_ref.infolist():
        if zip_info.is_dir():
            continue  # Skip directories

        # Bepaal originele bestandsnaam en extensie
        original_name = os.path.basename(zip_info.filename)
        file_ext = os.path.splitext(original_name)[1].lower()

        # Beperk de naam tot MAX_FILENAME_LENGTH, behoud de extensie
        base_name = os.path.splitext(original_name)[0]
        if len(base_name) > MAX_FILENAME_LENGTH:
            base_name = base_name[:MAX_FILENAME_LENGTH]
        safe_filename = f"{base_name}{file_ext}"

        # Opslaan op veilige locatie
        safe_path = os.path.join(extract_path, safe_filename)

        # Bestand veilig extraheren
        with zip_ref.open(zip_info) as source, open(safe_path, "wb") as target:
            shutil.copyfileobj(source, target)

# Metadata.json uitlezen (als die bestaat)
metadata_path = os.path.join(extract_path, "metadata.json")
published_date, decision_date = None, None
dossier_name = None
if os.path.exists(metadata_path):
    with open(metadata_path, "r", encoding="utf-8") as f:
        metadata = json.load(f)
        dossier_name = metadata.get("title")
        published_date = metadata.get("published_date")
        decision_date = metadata.get("decision_date")

# Bestandsteller starten
file_counter = 1

# Loop door alle uitgepakte bestanden
for file in os.listdir(extract_path):
    if file == "metadata.json":  # Metadata.json zelf negeren
        continue

    file_path = os.path.join(extract_path, file)
    file_ext = os.path.splitext(file)[1].lower()

    # Genereer file_id (bijv. 1-1, 1-2, etc.)
    file_id = f"{dossier_id}-{file_counter}"
    file_counter += 1  # Verhoog teller

    # Opslaan in lijst
    data.append({
        "dossier_id": dossier_id,
        "dossier_name": dossier_name,
        "file_id": file_id,
        "file_name": file,
        "file_type": file_ext,
        "dossier_published_date": published_date,
        "dossier_decision_date": decision_date
    })

# DataFrame maken en weergeven
df = pd.DataFrame(data)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)
display(df)

# %%
import os
import json
import zipfile
import pandas as pd
from IPython.display import display
import shutil

# Pad naar de map met ZIP-bestanden en waar alles uitgepakt wordt
input_folder = "/home/nena-meijer/PyCharmMiscProject/VWS_dossiers_zip"
output_folder = "/home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles"

# Maximale bestandsnaam lengte (inclusief extensie)
MAX_FILENAME_LENGTH = 100

# Data opslag
data = []

# Zoek alle ZIP-bestanden in de input folder
zip_files = sorted([f for f in os.listdir(input_folder) if f.endswith(".zip")])

# Loop door alle ZIP-bestanden en verwerk ze
for dossier_id, zip_filename in enumerate(zip_files, start=1):
    zip_path = os.path.join(input_folder, zip_filename)
    extract_path = os.path.join(output_folder, f"dossier_{dossier_id}")

    # Zorg dat de map bestaat
    os.makedirs(extract_path, exist_ok=True)

    # ZIP-bestand openen en verwerken
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        for zip_info in zip_ref.infolist():
            if zip_info.is_dir():
                continue  # Skip directories

            # Bepaal originele bestandsnaam en extensie
            original_name = os.path.basename(zip_info.filename)
            file_ext = os.path.splitext(original_name)[1].lower()

            # Beperk de naam tot MAX_FILENAME_LENGTH, behoud de extensie
            base_name = os.path.splitext(original_name)[0]
            if len(base_name) > MAX_FILENAME_LENGTH:
                base_name = base_name[:MAX_FILENAME_LENGTH]
            safe_filename = f"{base_name}{file_ext}"

            # Opslaan op veilige locatie
            safe_path = os.path.join(extract_path, safe_filename)

            # Bestand veilig extraheren
            with zip_ref.open(zip_info) as source, open(safe_path, "wb") as target:
                shutil.copyfileobj(source, target)

    # Metadata.json uitlezen (als die bestaat)
    metadata_path = os.path.join(extract_path, "metadata.json")
    published_date, decision_date, dossier_name = None, None, None
    if os.path.exists(metadata_path):
        with open(metadata_path, "r", encoding="utf-8") as f:
            metadata = json.load(f)
            dossier_name = metadata.get("title")
            published_date = metadata.get("published_date")
            decision_date = metadata.get("decision_date")

    # Datumconversie naar datetime-formaat (indien beschikbaar)
    published_date = pd.to_datetime(published_date, errors='coerce')
    decision_date = pd.to_datetime(decision_date, errors='coerce')

    # Bestandsteller starten
    file_counter = 1

    # Loop door alle uitgepakte bestanden
    for file in os.listdir(extract_path):
        if file == "metadata.json":  # Metadata.json zelf negeren
            continue

        file_path = os.path.join(extract_path, file)
        file_ext = os.path.splitext(file)[1].lower()

        # Genereer file_id (bijv. 1-1, 1-2, etc.)
        file_id = f"{dossier_id}-{file_counter}"
        file_counter += 1  # Verhoog teller

        # Opslaan in lijst
        data.append({
            "dossier_id": dossier_id,
            "dossier_name": dossier_name,
            "file_id": file_id,
            "file_name": file,
            "file_source": file_path,
            "file_type": file_ext,
            "dossier_published_date": published_date,
            "dossier_decision_date": decision_date
        })

# DataFrame maken en weergeven
df = pd.DataFrame(data)

# Instellingen voor brede tabellen en volledige tekstweergave
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)

# DataFrame weergeven
display(df)

# %%
df.to_csv("df.csv", index=False)

# %%
import pandas as pd
from IPython.display import display

# CSV inlezen
df = pd.read_csv("df.csv")

# Filter alleen relevante kolommen
df_filtered = df[["dossier_id", "dossier_name", "file_name", "dossier_published_date", "dossier_decision_date"]]

# Verwijder metadata.json en groepeer per dossier_id
df_aggregated = (
    df_filtered[df_filtered["file_name"] != "metadata.json"]
    .groupby(["dossier_id", "dossier_name", "dossier_published_date", "dossier_decision_date"])
    .agg(document_count=("file_name", "count"))  # Tel documenten per dossier
    .reset_index()
)

# Instellingen om lange tekst volledig te tonen
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)

# DataFrame weergeven in Jupyter Notebook
display(df_aggregated)

# Opslaan als CSV
df_aggregated.to_csv("df_dossiers.csv", index=False)

print("✅ Geaggregeerde CSV opgeslagen als 'df_dossiers.csv'")
# Out:
#      dossier_id                                                                                                                   dossier_name dossier_published_date dossier_decision_date  document_count
# 0             1                                                                   (4e deel) Besluit Woo-verzoek Covid-19 aanpak DOC-19 Q4 2020             2024-02-05            2023-07-29             229
# 1             2                                                                          Woo-besluit aangaande kaders werkproces Wob-verzoeken             2024-03-22            2023-03-20              83
# 2             3                                                                        1e deel Besluit Woo verzoek Covid-19 aanpak ACC Q4 2020             2024-02-07            2022-08-18             208
# 3             4                                                                        2e deel Besluit Woo verzoek Covid-19 aanpak ACC Q1 2021             2024-02-08            2023-02-17             239
# 4             5                                                              3e deel Besluit Woo verzoek Covid-19 aanpak ACC-19 April-Mei 2021             2024-02-07            2022-05-12             144
# ..          ...                                                                                                                            ...                    ...                   ...             ...
# 215         216                                                                       Woo-deelbesluit aangaande overeenkomsten PCR-laboratoria             2024-06-06            2024-03-27              68
# 216         217                                                                 Woo-deelbesluit aangaande vaccinatie aansprakelijkheid Deel II             2024-10-09            2024-10-02             116
# 217         218                                                          Woo-deelbesluit aangaande ‘Capaciteit van ziekenhuizen IC-capaciteit'             2024-10-19            2024-09-12             199
# 218         219  Woo-deelbesluit aangaande ‘de inkoop van persoonlijke beschermingsmiddelen tijdens de coronacrisis en het onderzoek daarnaar’             2024-04-05            2024-02-14            2695
# 219         220                                                         Woo-verzoek d.d. 6 januari 2022 inzake het Europees Herstelfonds (LNV)             2024-02-05            2022-05-12               9
#
# [220 rows x 5 columns]
# ✅ Geaggregeerde CSV opgeslagen als 'df_dossiers.csv'

# %%
import pandas as pd
from IPython.display import display

# CSV inlezen
df = pd.read_csv("df.csv")

# Verwijder spaties in kolomnamen (indien nodig)
df.columns = df.columns.str.strip()

# Controleer of de verwachte kolommen aanwezig zijn
expected_columns = ["dossier_id", "file_name", "file_type"]
missing_columns = [col for col in expected_columns if col not in df.columns]

if missing_columns:
    print(f"❌ De volgende kolommen ontbreken in de CSV: {missing_columns}")
else:
    # Selecteer relevante kolommen en hernoem file_name naar document_title
    df_documents = df[["dossier_id", "file_name", "file_type"]].rename(
        columns={"file_name": "document_title", "file_type": "document_type"}
    )

    # Verwijder metadata.json
    df_documents = df_documents[df_documents["document_title"] != "metadata.json"]

    # Verwijder de punt uit document_type (extensie)
    df_documents["document_type"] = df_documents["document_type"].str.replace(".", "", regex=False)

    # Document-ID toevoegen (per dossier_id een oplopende teller)
    df_documents["document_id"] = (
        df_documents.groupby("dossier_id").cumcount() + 1  # Start teller bij 1 per dossier
    ).astype(str)

    # Combineer document_id met dossier_id
    df_documents["document_id"] = df_documents["dossier_id"].astype(str) + "-" + df_documents["document_id"]

    # Kolommen opnieuw ordenen
    df_documents = df_documents[["dossier_id", "document_id", "document_title", "document_type"]]

    # Opslaan als nieuwe CSV
    df_documents.to_csv("df_documents.csv", index=False)

    # DataFrame weergeven
    display(df_documents)
    print("✅ Geëxporteerd als 'df_documents.csv'")
# Out:
#         dossier_id document_id                                                                            document_title document_type
# 0                1         1-1                        VWS-WC-098-DOC201208J-Concept_Platte_tekst_herijkte_routekaart.pdf           pdf
# 1                1         1-2                         VWS-WC-098-201130D-Actiepuntenlijst_DOC-19_-_27_november_2020.pdf           pdf
# 2                1         1-3                  VWS-WC-098-201127F-Presentatie_verdiepingssessie_vaccinatiestrategie.pdf           pdf
# 3                1         1-4                   VWS-WC-098-201215F-Implementatie_gedragsinterventies_DGSC-19_en_RRT.pdf           pdf
# 4                1         1-5                                       VWS-WC-098-201006A-Agenda_DOC-19_6_oktober_2020.pdf           pdf
# ...            ...         ...                                                                                       ...           ...
# 109029         220       220-5                    VWS-WC-107-2a-2020_RV_0022_Masterplan_emissieloze_maritieme_sector.pdf           pdf
# 109030         220       220-6                      VWS-WC-107-1-FW_Masterplan_voor_een_emissieloze_maritieme_sector.pdf           pdf
# 109031         220       220-7                                        VWS-WC-107-4-video-overleg_Corona_herstelfonds.pdf           pdf
# 109032         220       220-8  VWS-WC-107-3-Vraag_om_informatie_over_RFF_in_relatie_tot_emissiearme_kotter_visserij.pdf           pdf
# 109033         220       220-9                 VWS-WC-107-6-RE_Reactie_gevraagd_op_fiche_emissieloze_kotter_voor_RRF.pdf           pdf
#
# [109034 rows x 4 columns]
# ✅ Geëxporteerd als 'df_documents.csv'

# %%
import time

def scrape_document_metadata(dossier_url):
    """Scrapet documentmetadata van alle pagina's binnen een dossier met een crawl delay."""

    # Extract dossier ID uit de URL
    dossier_id_match = re.search(r'/dossier/([^/]+)', dossier_url)
    dossier_id_str = dossier_id_match.group(1) if dossier_id_match else None

    metadata_list = []
    seen_documents = set()
    page = 1
    max_pages = 50  # Failsafe om te voorkomen dat hij oneindig blijft lopen

    while page <= max_pages:
        paged_url = f"{dossier_url}?prefix=VWS-WC&dossierId={dossier_id_str}&pu={page}#tabcontrol-1"
        response = requests.get(paged_url)
        if response.status_code != 200:
            print(f"Fout bij ophalen van {paged_url}")
            break

        soup = BeautifulSoup(response.text, "html.parser")
        table_rows = soup.select(".woo-table tbody tr")
        if not table_rows:
            print(f"Geen documenten gevonden op pagina {page}, stoppen met scrapen.")
            break

        new_documents_found = False

        for row in table_rows:
            try:
                # Document ID ophalen uit de eerste kolom
                doc_id_tag = row.select_one("td:nth-of-type(1)")
                doc_id = doc_id_tag.text.strip() if doc_id_tag else None

                # Document URL ophalen
                doc_link_tag = row.select_one("td:nth-of-type(3) a")
                doc_url = doc_link_tag["href"] if doc_link_tag else ""

                if not doc_id or doc_id in seen_documents:
                    continue

                seen_documents.add(doc_id)
                new_documents_found = True

                # Documenttype
                doc_type_tag = row.select_one("td:nth-of-type(2) use")
                doc_type_key = doc_type_tag["xlink:href"].split("#")[-1] if doc_type_tag else "unknown"
                doc_type = DOCUMENT_TYPE_MAP.get(doc_type_key, "Onbekend")

                # Documentdatum correct ophalen
                doc_date_tag = row.select_one("td:nth-of-type(4) time")
                doc_date = doc_date_tag["datetime"] if doc_date_tag else None

                metadata_list.append({
                    "document_id": doc_id,
                    "document_sourcetype": doc_type,
                    "document_date": doc_date,
                    "dossier_id": dossier_id
                })
            except Exception as e:
                print(f"Fout bij parsen: {e}")

        if not new_documents_found:
            print(f"Geen nieuwe documenten meer gevonden op pagina {page}, stoppen met scrapen.")
            break

        page += 1
        time.sleep(1)  # Crawl delay na elke pagina scrape

    for doc in metadata_list:
        print(doc)

    return metadata_list

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# Mapping van documenttypes
DOCUMENT_TYPE_MAP = {
    "unknown": "Onbekend",
    "pdf": "PDF",
    "email": "E-mailbericht",
    "presentation": "Presentatie",
    "doc": "Word-document",
    "chat": "Chatbericht",
    "image": "Afbeelding",
    "spreadsheet": "Spreadsheet"
}

# Inlezen van de bestaande documentgegevens
df_documents = pd.read_csv("df_documents.csv", dtype={"document_id": str})
df_dossiers = pd.read_csv("df_dossiers_final.csv", dtype={"dossier_id": int})

# Handmatig dossier_id invoeren
dossier_id = 10
dossier = df_dossiers[df_dossiers["dossier_id"] == dossier_id].iloc[0]
dossier_url = dossier["dossier_sourceURL"]

print(f"Scrapen: {dossier_url}")
document_metadata = scrape_document_metadata(dossier_url)

# Omzetten naar dataframe
df_metadata = pd.DataFrame(document_metadata)

# **Snellere matching door eerst te filteren op dossier_id**
def match_documents(df_documents, df_metadata, dossier_id):
    df_documents_dossier = df_documents[df_documents["dossier_id"] == dossier_id]

    for i, doc_row in df_documents_dossier.iterrows():
        for _, meta_row in df_metadata.iterrows():
            if meta_row["document_id"] in doc_row["document_title"]:  # Zoek in de titel
                df_documents.at[i, "document_sourcetype"] = meta_row["document_sourcetype"]
                df_documents.at[i, "document_date"] = meta_row["document_date"]
                break  # Stop zodra een match is gevonden
    return df_documents

df_documents = match_documents(df_documents, df_metadata, dossier_id)

# Opslaan van de verrijkte dataset
df_documents.to_csv("df_documents_dates.csv", index=False)
print(f"Scraping en verrijking voltooid voor dossier {dossier_id}!")
# Out:
# Scrapen: https://open.minvws.nl/dossier/VWS-WC/069
# Geen nieuwe documenten meer gevonden op pagina 2, stoppen met scrapen.
# {'document_id': 'Gedeeltelijke openbaarmaking', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 10}
# {'document_id': 'Wob-besluit', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 10}
# {'document_id': 'wob-besluit-mccb.pdf (PDF, 3.48 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 10}
# {'document_id': 'ministerie van Justitie en Veiligheid', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 10}
# {'document_id': 'Maart - juni 2020', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 10}
# {'document_id': '25 februari 2021', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 10}
# {'document_id': "129 documenten,                        \n                                                    399 pagina's\n                            \n                                                \nInventarislijst", 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 10}
# {'document_id': 'Scenario’s en maatregelen', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 10}
# {'document_id': 'MCCb0309A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-09', 'dossier_id': 10}
# {'document_id': 'MCCb0309E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 10}
# {'document_id': 'MCCb0312A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-12', 'dossier_id': 10}
# {'document_id': 'MCCb0316A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 10}
# {'document_id': 'MCCb0316C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-05', 'dossier_id': 10}
# {'document_id': 'MCCb0319A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-19', 'dossier_id': 10}
# {'document_id': 'MCCb0325A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-25', 'dossier_id': 10}
# {'document_id': 'MCCb0327A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-27', 'dossier_id': 10}
# {'document_id': 'MCCb0331A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0331L', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0402B', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0402D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0402E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 10}
# {'document_id': 'MCCb0402G', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 10}
# {'document_id': 'MCCb0407A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-07', 'dossier_id': 10}
# {'document_id': 'MCCb0409A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-09', 'dossier_id': 10}
# {'document_id': 'MCCb0409C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-09', 'dossier_id': 10}
# {'document_id': 'MCCb0421C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-21', 'dossier_id': 10}
# {'document_id': 'MCCb042IG', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-21', 'dossier_id': 10}
# {'document_id': 'MCCb0421J', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 10}
# {'document_id': 'MCCb0421K', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 10}
# {'document_id': 'MCCb0429A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-25', 'dossier_id': 10}
# {'document_id': 'MCCb0506A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 10}
# {'document_id': 'MCCb0506G', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 10}
# {'document_id': 'MCCb0506H', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 10}
# {'document_id': 'MCCb0506J', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 10}
# {'document_id': 'MCCb0513B', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-13', 'dossier_id': 10}
# {'document_id': 'MCCb0513F', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-13', 'dossier_id': 10}
# {'document_id': 'MCCb0519A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 10}
# {'document_id': 'MCCb0519C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 10}
# {'document_id': 'MCCb0519I', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 10}
# {'document_id': 'MCCb0527B', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 10}
# {'document_id': 'MCCb0527F', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 10}
# {'document_id': 'MCCb0527G', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 10}
# {'document_id': 'MCCb0527H', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 10}
# {'document_id': 'MCCb05Z7J', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 10}
# {'document_id': 'MCCb0603A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-03', 'dossier_id': 10}
# {'document_id': 'MCCb0603C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-03', 'dossier_id': 10}
# {'document_id': 'MCCb0603F', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-03', 'dossier_id': 10}
# {'document_id': 'MCCb0603H', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-03', 'dossier_id': 10}
# {'document_id': 'MCCb0603I', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-03', 'dossier_id': 10}
# {'document_id': 'MCCb0603J', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-03', 'dossier_id': 10}
# {'document_id': 'MCCb0b24A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-24', 'dossier_id': 10}
# {'document_id': 'MCCb0624C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-24', 'dossier_id': 10}
# {'document_id': 'MCCb0624D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-24', 'dossier_id': 10}
# {'document_id': 'MCCb0624E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-24', 'dossier_id': 10}
# {'document_id': 'MCCb0415E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-15', 'dossier_id': 10}
# {'document_id': 'MCCb0421A', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-21', 'dossier_id': 10}
# {'document_id': 'MCCb0506E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 10}
# {'document_id': 'MCCb0429F', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-20', 'dossier_id': 10}
# {'document_id': 'MCCb0316I', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 10}
# {'document_id': 'MCCb0519J', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 10}
# {'document_id': 'MCCb0331N1', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0429D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-25', 'dossier_id': 10}
# {'document_id': 'MCCb0407D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-07', 'dossier_id': 10}
# {'document_id': 'MCCb0429H', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-29', 'dossier_id': 10}
# {'document_id': 'MCCb0319D1', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-19', 'dossier_id': 10}
# {'document_id': 'MCCb0319E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-19', 'dossier_id': 10}
# {'document_id': 'MCCb0331E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0407C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-07', 'dossier_id': 10}
# {'document_id': 'MCCb0409F', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-09', 'dossier_id': 10}
# {'document_id': 'MCCb0421D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-21', 'dossier_id': 10}
# {'document_id': 'MCCb0421E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-21', 'dossier_id': 10}
# {'document_id': 'MCCb0421L', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 10}
# {'document_id': 'MCCb0429E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-25', 'dossier_id': 10}
# {'document_id': 'MCCb0506C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 10}
# {'document_id': 'MCCb0527D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 10}
# {'document_id': 'MCCb0527E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 10}
# {'document_id': 'MCCb0527I', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 10}
# {'document_id': 'MCCb0624B', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-24', 'dossier_id': 10}
# {'document_id': 'MCCb0519H-1', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 10}
# {'document_id': 'MCCb0603G', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-03', 'dossier_id': 10}
# {'document_id': 'MCCb0303', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-03', 'dossier_id': 10}
# {'document_id': 'MCCb0303AI', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-03', 'dossier_id': 10}
# {'document_id': 'MCCb0303D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-03', 'dossier_id': 10}
# {'document_id': 'MCCb0303G', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-03', 'dossier_id': 10}
# {'document_id': 'MCCb0309', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-09', 'dossier_id': 10}
# {'document_id': 'MCCb0309D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-09', 'dossier_id': 10}
# {'document_id': 'MCCb0312', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-12', 'dossier_id': 10}
# {'document_id': 'MCCb0312B', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-12', 'dossier_id': 10}
# {'document_id': 'MCCb0312C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-12', 'dossier_id': 10}
# {'document_id': 'MCCb0316', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 10}
# {'document_id': 'MCCb0316D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 10}
# {'document_id': 'MCCb0319', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-19', 'dossier_id': 10}
# {'document_id': 'MCCb0323', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-23', 'dossier_id': 10}
# {'document_id': 'MCCb0325', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-25', 'dossier_id': 10}
# {'document_id': 'MCCb0325C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-25', 'dossier_id': 10}
# {'document_id': 'MCCb0325D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-25', 'dossier_id': 10}
# {'document_id': 'MCCb0325E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-25', 'dossier_id': 10}
# {'document_id': 'MCCb0325F', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-25', 'dossier_id': 10}
# {'document_id': 'MCCb0331', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0331D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0331F', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0331G', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0402', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 10}
# {'document_id': 'MCCb0402C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0402F', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 10}
# {'document_id': 'MCCb0407', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-07', 'dossier_id': 10}
# {'document_id': 'MCCb0407E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-07', 'dossier_id': 10}
# {'document_id': 'MCCb0407F', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-07', 'dossier_id': 10}
# {'document_id': 'MCCb0407G', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-07', 'dossier_id': 10}
# {'document_id': 'MCCb0407I', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-07', 'dossier_id': 10}
# {'document_id': 'MCCb0409', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-09', 'dossier_id': 10}
# {'document_id': 'MCCb0409D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-09', 'dossier_id': 10}
# {'document_id': 'MCCb0409E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-09', 'dossier_id': 10}
# {'document_id': 'MCCb0409I', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-09', 'dossier_id': 10}
# {'document_id': 'MCCb0415', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-15', 'dossier_id': 10}
# {'document_id': 'MCCb0415B', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-15', 'dossier_id': 10}
# {'document_id': 'MCCb0415C', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-15', 'dossier_id': 10}
# {'document_id': 'MCCb0415D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-15', 'dossier_id': 10}
# {'document_id': 'MCCb0421', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-21', 'dossier_id': 10}
# {'document_id': 'MCCb0421I', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 10}
# {'document_id': 'MCCb0429', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-20', 'dossier_id': 10}
# {'document_id': 'MCCb0429G', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-29', 'dossier_id': 10}
# {'document_id': 'MCCb0506', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 10}
# {'document_id': 'MCCb0506I', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-06', 'dossier_id': 10}
# {'document_id': 'MCCb0513', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-13', 'dossier_id': 10}
# {'document_id': 'MCCb0513E', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-13', 'dossier_id': 10}
# {'document_id': 'MCCb0519', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 10}
# {'document_id': 'MCCb0519G', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 10}
# {'document_id': 'MCCb0519H', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 10}
# {'document_id': 'MCCb0527', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 10}
# {'document_id': 'MCCb0527L', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-27', 'dossier_id': 10}
# {'document_id': 'MCCb06OZ', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-03', 'dossier_id': 10}
# {'document_id': 'MCCb0603D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-06-03', 'dossier_id': 10}
# {'document_id': 'MCCb0331I', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 10}
# {'document_id': 'MCCb0112D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-13', 'dossier_id': 10}
# {'document_id': 'MCCb0519D', 'document_sourcetype': 'Onbekend', 'document_date': '2020-05-19', 'dossier_id': 10}
# {'document_id': 'MCCb0421F', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 10}
# {'document_id': '8 februari 2024 13:59', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 10}
# Scraping en verrijking voltooid voor dossier 10!
