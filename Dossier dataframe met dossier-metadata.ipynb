# %%
import os
import json
import zipfile
import pandas as pd
from IPython.display import display
import shutil

# Pad naar de map met ZIP-bestanden en waar alles uitgepakt wordt
input_folder = "/home/nena-meijer/PyCharmMiscProject/VWS_dossiers_zip"
output_folder = "/home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles"

# Maximale bestandsnaam lengte (inclusief extensie)
MAX_FILENAME_LENGTH = 100

# Kies hier het ZIP-bestand dat je wilt testen (pas de naam aan)
test_zip_filename = "Beslissing op bezwaar Wob-besluit coronamaatregelen.zip"  # Zet hier de naam van het ZIP-bestand dat je wilt testen
zip_path = os.path.join(input_folder, test_zip_filename)

# Dossier-ID starten bij 1
dossier_id = 1
extract_path = os.path.join(output_folder, f"dossier_{dossier_id}")

# Zorg dat de map bestaat
os.makedirs(extract_path, exist_ok=True)

# Data opslag
data = []

# ZIP-bestand openen en verwerken
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    for zip_info in zip_ref.infolist():
        if zip_info.is_dir():
            continue  # Skip directories

        # Bepaal originele bestandsnaam en extensie
        original_name = os.path.basename(zip_info.filename)
        file_ext = os.path.splitext(original_name)[1].lower()

        # Beperk de naam tot MAX_FILENAME_LENGTH, behoud de extensie
        base_name = os.path.splitext(original_name)[0]
        if len(base_name) > MAX_FILENAME_LENGTH:
            base_name = base_name[:MAX_FILENAME_LENGTH]
        safe_filename = f"{base_name}{file_ext}"

        # Opslaan op veilige locatie
        safe_path = os.path.join(extract_path, safe_filename)

        # Bestand veilig extraheren
        with zip_ref.open(zip_info) as source, open(safe_path, "wb") as target:
            shutil.copyfileobj(source, target)

# Metadata.json uitlezen (als die bestaat)
metadata_path = os.path.join(extract_path, "metadata.json")
published_date, decision_date = None, None
dossier_name = None
if os.path.exists(metadata_path):
    with open(metadata_path, "r", encoding="utf-8") as f:
        metadata = json.load(f)
        dossier_name = metadata.get("title")
        published_date = metadata.get("published_date")
        decision_date = metadata.get("decision_date")

# Bestandsteller starten
file_counter = 1

# Loop door alle uitgepakte bestanden
for file in os.listdir(extract_path):
    if file == "metadata.json":  # Metadata.json zelf negeren
        continue

    file_path = os.path.join(extract_path, file)
    file_ext = os.path.splitext(file)[1].lower()

    # Genereer file_id (bijv. 1-1, 1-2, etc.)
    file_id = f"{dossier_id}-{file_counter}"
    file_counter += 1  # Verhoog teller

    # Opslaan in lijst
    data.append({
        "dossier_id": dossier_id,
        "dossier_name": dossier_name,
        "file_id": file_id,
        "file_name": file,
        "file_type": file_ext,
        "dossier_published_date": published_date,
        "dossier_decision_date": decision_date
    })

# DataFrame maken en weergeven
df = pd.DataFrame(data)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)
display(df)

# %%
import os
import json
import zipfile
import pandas as pd
from IPython.display import display
import shutil

# Pad naar de map met ZIP-bestanden en waar alles uitgepakt wordt
input_folder = "/home/nena-meijer/PyCharmMiscProject/VWS_dossiers_zip"
output_folder = "/home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles"

# Maximale bestandsnaam lengte (inclusief extensie)
MAX_FILENAME_LENGTH = 100

# Data opslag
data = []

# Zoek alle ZIP-bestanden in de input folder
zip_files = sorted([f for f in os.listdir(input_folder) if f.endswith(".zip")])

# Loop door alle ZIP-bestanden en verwerk ze
for dossier_id, zip_filename in enumerate(zip_files, start=1):
    zip_path = os.path.join(input_folder, zip_filename)
    extract_path = os.path.join(output_folder, f"dossier_{dossier_id}")

    # Zorg dat de map bestaat
    os.makedirs(extract_path, exist_ok=True)

    # ZIP-bestand openen en verwerken
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        for zip_info in zip_ref.infolist():
            if zip_info.is_dir():
                continue  # Skip directories

            # Bepaal originele bestandsnaam en extensie
            original_name = os.path.basename(zip_info.filename)
            file_ext = os.path.splitext(original_name)[1].lower()

            # Beperk de naam tot MAX_FILENAME_LENGTH, behoud de extensie
            base_name = os.path.splitext(original_name)[0]
            if len(base_name) > MAX_FILENAME_LENGTH:
                base_name = base_name[:MAX_FILENAME_LENGTH]
            safe_filename = f"{base_name}{file_ext}"

            # Opslaan op veilige locatie
            safe_path = os.path.join(extract_path, safe_filename)

            # Bestand veilig extraheren
            with zip_ref.open(zip_info) as source, open(safe_path, "wb") as target:
                shutil.copyfileobj(source, target)

    # Metadata.json uitlezen (als die bestaat)
    metadata_path = os.path.join(extract_path, "metadata.json")
    published_date, decision_date, dossier_name = None, None, None
    if os.path.exists(metadata_path):
        with open(metadata_path, "r", encoding="utf-8") as f:
            metadata = json.load(f)
            dossier_name = metadata.get("title")
            published_date = metadata.get("published_date")
            decision_date = metadata.get("decision_date")

    # Datumconversie naar datetime-formaat (indien beschikbaar)
    published_date = pd.to_datetime(published_date, errors='coerce')
    decision_date = pd.to_datetime(decision_date, errors='coerce')

    # Bestandsteller starten
    file_counter = 1

    # Loop door alle uitgepakte bestanden
    for file in os.listdir(extract_path):
        if file == "metadata.json":  # Metadata.json zelf negeren
            continue

        file_path = os.path.join(extract_path, file)
        file_ext = os.path.splitext(file)[1].lower()

        # Genereer file_id (bijv. 1-1, 1-2, etc.)
        file_id = f"{dossier_id}-{file_counter}"
        file_counter += 1  # Verhoog teller

        # Opslaan in lijst
        data.append({
            "dossier_id": dossier_id,
            "dossier_name": dossier_name,
            "file_id": file_id,
            "file_name": file,
            "file_source": file_path,
            "file_type": file_ext,
            "dossier_published_date": published_date,
            "dossier_decision_date": decision_date
        })

# DataFrame maken en weergeven
df = pd.DataFrame(data)

# Instellingen voor brede tabellen en volledige tekstweergave
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)

# DataFrame weergeven
display(df)

# %%
df.to_csv("df.csv", index=False)

# %%
import pandas as pd
from IPython.display import display

# CSV inlezen
df = pd.read_csv("df.csv")

# Filter alleen relevante kolommen
df_filtered = df[["dossier_id", "dossier_name", "file_name", "dossier_published_date", "dossier_decision_date"]]

# Verwijder metadata.json en groepeer per dossier_id
df_aggregated = (
    df_filtered[df_filtered["file_name"] != "metadata.json"]
    .groupby(["dossier_id", "dossier_name", "dossier_published_date", "dossier_decision_date"])
    .agg(document_count=("file_name", "count"))  # Tel documenten per dossier
    .reset_index()
)

# Instellingen om lange tekst volledig te tonen
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)

# DataFrame weergeven in Jupyter Notebook
display(df_aggregated)

# Opslaan als CSV
df_aggregated.to_csv("df_dossiers.csv", index=False)

print("✅ Geaggregeerde CSV opgeslagen als 'df_dossiers.csv'")
# Out:
#      dossier_id                                                                                                                   dossier_name dossier_published_date dossier_decision_date  document_count
# 0             1                                                                   (4e deel) Besluit Woo-verzoek Covid-19 aanpak DOC-19 Q4 2020             2024-02-05            2023-07-29             229
# 1             2                                                                          Woo-besluit aangaande kaders werkproces Wob-verzoeken             2024-03-22            2023-03-20              83
# 2             3                                                                        1e deel Besluit Woo verzoek Covid-19 aanpak ACC Q4 2020             2024-02-07            2022-08-18             208
# 3             4                                                                        2e deel Besluit Woo verzoek Covid-19 aanpak ACC Q1 2021             2024-02-08            2023-02-17             239
# 4             5                                                              3e deel Besluit Woo verzoek Covid-19 aanpak ACC-19 April-Mei 2021             2024-02-07            2022-05-12             144
# ..          ...                                                                                                                            ...                    ...                   ...             ...
# 215         216                                                                       Woo-deelbesluit aangaande overeenkomsten PCR-laboratoria             2024-06-06            2024-03-27              68
# 216         217                                                                 Woo-deelbesluit aangaande vaccinatie aansprakelijkheid Deel II             2024-10-09            2024-10-02             116
# 217         218                                                          Woo-deelbesluit aangaande ‘Capaciteit van ziekenhuizen IC-capaciteit'             2024-10-19            2024-09-12             199
# 218         219  Woo-deelbesluit aangaande ‘de inkoop van persoonlijke beschermingsmiddelen tijdens de coronacrisis en het onderzoek daarnaar’             2024-04-05            2024-02-14            2695
# 219         220                                                         Woo-verzoek d.d. 6 januari 2022 inzake het Europees Herstelfonds (LNV)             2024-02-05            2022-05-12               9
#
# [220 rows x 5 columns]
# ✅ Geaggregeerde CSV opgeslagen als 'df_dossiers.csv'

# %%
import pandas as pd
from IPython.display import display

# CSV inlezen
df = pd.read_csv("df.csv")

# Verwijder spaties in kolomnamen (indien nodig)
df.columns = df.columns.str.strip()

# Controleer of de verwachte kolommen aanwezig zijn
expected_columns = ["dossier_id", "file_name", "file_type"]
missing_columns = [col for col in expected_columns if col not in df.columns]

if missing_columns:
    print(f"❌ De volgende kolommen ontbreken in de CSV: {missing_columns}")
else:
    # Selecteer relevante kolommen en hernoem file_name naar document_title
    df_documents = df[["dossier_id", "file_name", "file_type"]].rename(
        columns={"file_name": "document_title", "file_type": "document_type"}
    )

    # Verwijder metadata.json
    df_documents = df_documents[df_documents["document_title"] != "metadata.json"]

    # Verwijder de punt uit document_type (extensie)
    df_documents["document_type"] = df_documents["document_type"].str.replace(".", "", regex=False)

    # Document-ID toevoegen (per dossier_id een oplopende teller)
    df_documents["document_id"] = (
        df_documents.groupby("dossier_id").cumcount() + 1  # Start teller bij 1 per dossier
    ).astype(str)

    # Combineer document_id met dossier_id
    df_documents["document_id"] = df_documents["dossier_id"].astype(str) + "-" + df_documents["document_id"]

    # Kolommen opnieuw ordenen
    df_documents = df_documents[["dossier_id", "document_id", "document_title", "document_type"]]

    # Opslaan als nieuwe CSV
    df_documents.to_csv("df_documents.csv", index=False)

    # DataFrame weergeven
    display(df_documents)
    print("✅ Geëxporteerd als 'df_documents.csv'")
# Out:
#         dossier_id document_id                                                                            document_title document_type
# 0                1         1-1                        VWS-WC-098-DOC201208J-Concept_Platte_tekst_herijkte_routekaart.pdf           pdf
# 1                1         1-2                         VWS-WC-098-201130D-Actiepuntenlijst_DOC-19_-_27_november_2020.pdf           pdf
# 2                1         1-3                  VWS-WC-098-201127F-Presentatie_verdiepingssessie_vaccinatiestrategie.pdf           pdf
# 3                1         1-4                   VWS-WC-098-201215F-Implementatie_gedragsinterventies_DGSC-19_en_RRT.pdf           pdf
# 4                1         1-5                                       VWS-WC-098-201006A-Agenda_DOC-19_6_oktober_2020.pdf           pdf
# ...            ...         ...                                                                                       ...           ...
# 109029         220       220-5                    VWS-WC-107-2a-2020_RV_0022_Masterplan_emissieloze_maritieme_sector.pdf           pdf
# 109030         220       220-6                      VWS-WC-107-1-FW_Masterplan_voor_een_emissieloze_maritieme_sector.pdf           pdf
# 109031         220       220-7                                        VWS-WC-107-4-video-overleg_Corona_herstelfonds.pdf           pdf
# 109032         220       220-8  VWS-WC-107-3-Vraag_om_informatie_over_RFF_in_relatie_tot_emissiearme_kotter_visserij.pdf           pdf
# 109033         220       220-9                 VWS-WC-107-6-RE_Reactie_gevraagd_op_fiche_emissieloze_kotter_voor_RRF.pdf           pdf
#
# [109034 rows x 4 columns]
# ✅ Geëxporteerd als 'df_documents.csv'

# %%
import time

def scrape_document_metadata(dossier_url):
    """Scrapet documentmetadata van alle pagina's binnen een dossier met een crawl delay."""

    # Extract dossier ID uit de URL
    dossier_id_match = re.search(r'/dossier/([^/]+)', dossier_url)
    dossier_id_str = dossier_id_match.group(1) if dossier_id_match else None

    metadata_list = []
    seen_documents = set()
    page = 1
    max_pages = 65 # Failsafe om te voorkomen dat hij oneindig blijft lopen

    while page <= max_pages:
        paged_url = f"{dossier_url}?prefix=VWS-WC&dossierId={dossier_id_str}&pu={page}#tabcontrol-1"
        response = requests.get(paged_url)
        if response.status_code != 200:
            print(f"Fout bij ophalen van {paged_url}")
            break

        soup = BeautifulSoup(response.text, "html.parser")
        table_rows = soup.select(".woo-table tbody tr")
        if not table_rows:
            print(f"Geen documenten gevonden op pagina {page}, stoppen met scrapen.")
            break

        new_documents_found = False

        for row in table_rows:
            try:
                # Document ID ophalen uit de eerste kolom
                doc_id_tag = row.select_one("td:nth-of-type(1)")
                doc_id = doc_id_tag.text.strip() if doc_id_tag else None

                # Document URL ophalen
                doc_link_tag = row.select_one("td:nth-of-type(3) a")
                doc_url = doc_link_tag["href"] if doc_link_tag else ""

                if not doc_id or doc_id in seen_documents:
                    continue

                seen_documents.add(doc_id)
                new_documents_found = True

                # Documenttype
                doc_type_tag = row.select_one("td:nth-of-type(2) use")
                doc_type_key = doc_type_tag["xlink:href"].split("#")[-1] if doc_type_tag else "unknown"
                doc_type = DOCUMENT_TYPE_MAP.get(doc_type_key, "Onbekend")

                # Documentdatum correct ophalen
                doc_date_tag = row.select_one("td:nth-of-type(4) time")
                doc_date = doc_date_tag["datetime"] if doc_date_tag else None

                metadata_list.append({
                    "document_id": doc_id,
                    "document_sourcetype": doc_type,
                    "document_date": doc_date,
                    "dossier_id": dossier_id
                })
            except Exception as e:
                print(f"Fout bij parsen: {e}")

        if not new_documents_found:
            print(f"Geen nieuwe documenten meer gevonden op pagina {page}, stoppen met scrapen.")
            break

        page += 1
        time.sleep(1)  # Crawl delay na elke pagina scrape

    for doc in metadata_list:
        print(doc)

    return metadata_list

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# Mapping van documenttypes
DOCUMENT_TYPE_MAP = {
    "unknown": "Onbekend",
    "pdf": "PDF",
    "email": "E-mailbericht",
    "presentation": "Presentatie",
    "doc": "Word-document",
    "chat": "Chatbericht",
    "image": "Afbeelding",
    "spreadsheet": "Spreadsheet"
}

# Inlezen van de bestaande documentgegevens
df_documents = pd.read_csv("df_documents_dates.csv", dtype={"document_id": str})
df_dossiers = pd.read_csv("df_dossiers_final.csv", dtype={"dossier_id": int})

# Handmatig dossier_id invoeren
dossier_id = 205

dossier = df_dossiers[df_dossiers["dossier_id"] == dossier_id].iloc[0]
dossier_url = dossier["dossier_sourceURL"]

print(f"Scrapen: {dossier_url}")
document_metadata = scrape_document_metadata(dossier_url)

# Omzetten naar dataframe
df_metadata = pd.DataFrame(document_metadata)

def extract_prefix(document_title):
    """Probeert het juiste dossierprefix te extraheren uit de document_title."""

    # Specifieke uitzondering: als het document begint met "VWS-WC-19.00-1-", dan is de prefix gewoon "VWS-WC"
    if document_title.startswith("VWS-WC-44"):
        return "VWS-WC-44"

    # Standaardpatronen voor prefixes
    match = re.match(r"^(VWS-WC-\d{3}|VWS-WOO-[A-Za-z0-9]+|VWS-WC)", document_title)
    return match.group(1) if match else None

def match_documents(df_documents, df_metadata, dossier_id):
    """Matcht gescrapete metadata met documenten op basis van dossierprefix en document_id."""
    df_documents_dossier = df_documents[df_documents["dossier_id"] == dossier_id]

    if df_documents_dossier.empty:
        print(f"⚠️ Geen documenten gevonden voor dossier_id {dossier_id}")
        return df_documents

    # Zoek het eerste document dat GEEN generieke naam heeft
    sample_document_title = None
    for title in df_documents_dossier["document_title"]:
        if not title.lower().startswith("besluitbrief"):  # Voeg andere generieke namen toe indien nodig
            sample_document_title = title
            break

    if not sample_document_title:
        print(f"❌ Geen geldig document gevonden om een prefix uit te halen voor dossier {dossier_id}.")
        return df_documents

    dossier_prefix = extract_prefix(sample_document_title)

    if not dossier_prefix:
        print(f"❌ Geen geldig dossierprefix gevonden in: {sample_document_title}")
        return df_documents

    print(f"🔎 Dossierprefix bepaald als: {dossier_prefix}")

    for i, doc_row in df_documents_dossier.iterrows():
        document_title = doc_row["document_title"]
        print(f"\n---\n🔍 Matching document: {document_title}")

        for _, meta_row in df_metadata.iterrows():
            meta_doc_id = str(meta_row["document_id"]).strip()  # Zorgt dat het ID een string is
            expected_identifier = f"{dossier_prefix}-{meta_doc_id}"  # Verwachte match

            # Exacte match met regex
            if re.search(rf"\b{re.escape(expected_identifier)}\b", document_title):
                print(f"  ✅ MATCH GEVONDEN! Updaten document {meta_doc_id}")

                df_documents.at[i, "document_sourcetype"] = meta_row["document_sourcetype"]
                df_documents.at[i, "document_date"] = meta_row["document_date"]

                # Print de waarde die in de CSV wordt gezet
                print(f"  📌 In CSV zetten → Type: {meta_row['document_sourcetype']}, Datum: {meta_row['document_date']}")
                break  # Stop met zoeken zodra de match is gevonden

    return df_documents

df_documents = match_documents(df_documents, df_metadata, dossier_id)

# Opslaan van de verrijkte dataset
df_documents.to_csv("df_documents_dates.csv", index=False)
print(f"Scraping en verrijking voltooid voor dossier {dossier_id}!")
print(dossier_url)
# Out:
# Scrapen: https://open.minvws.nl/dossier/VWS-WOO/3478791-1040904-pdo
# Geen nieuwe documenten meer gevonden op pagina 63, stoppen met scrapen.
# {'document_id': 'Gedeeltelijke openbaarmaking', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': 'Woo-besluit', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': 'decision-3478791-1040904-pdo.pdf (PDF, 1.15 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': 'ministerie van Volksgezondheid, Welzijn en Sport', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': 'Februari 2021', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '21 december 2022', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': "13.418 documenten,                        \n                                                    24.551 pagina's\n                            \n                                                \nInventarislijst", 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': 'Vaccinaties en medicatie', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '230929 bob Geredigeerd.pdf (PDF, 8.7 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '240419 bob_Geredigeerd.pdf (PDF, 2.82 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '241119 Herstel Woo-deelbesluit Vaccinaties en Medicatie_Geredigeerd.pdf (PDF, 1.28 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '1106859', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1106870', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1106879', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-18', 'dossier_id': 205}
# {'document_id': '1106883', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-24', 'dossier_id': 205}
# {'document_id': '1106907', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1106913', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1106920', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1106947', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1106948', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-19', 'dossier_id': 205}
# {'document_id': '1106950', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1106972', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-22', 'dossier_id': 205}
# {'document_id': '1106993', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1106998', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-18', 'dossier_id': 205}
# {'document_id': '1107004', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-19', 'dossier_id': 205}
# {'document_id': '1107008', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-26', 'dossier_id': 205}
# {'document_id': '1107011', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-19', 'dossier_id': 205}
# {'document_id': '1107015', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1107024', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1107049', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-18', 'dossier_id': 205}
# {'document_id': '1107051', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-22', 'dossier_id': 205}
# {'document_id': '1107093', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-25', 'dossier_id': 205}
# {'document_id': '1107095', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-23', 'dossier_id': 205}
# {'document_id': '1107107', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1107108', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1107110', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-18', 'dossier_id': 205}
# {'document_id': '1107119', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1107134', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1107136', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-03-01', 'dossier_id': 205}
# {'document_id': '1107142', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-24', 'dossier_id': 205}
# {'document_id': '1107158', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1107169', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1107187', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1107197', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-22', 'dossier_id': 205}
# {'document_id': '1107212', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1107234', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1107236', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-18', 'dossier_id': 205}
# {'document_id': '1107244', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-24', 'dossier_id': 205}
# {'document_id': '1107266', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1107284', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-02', 'dossier_id': 205}
# {'document_id': '1107316', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-16', 'dossier_id': 205}
# {'document_id': '1107325', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-20', 'dossier_id': 205}
# {'document_id': '1107345', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-24', 'dossier_id': 205}
# {'document_id': '1107346', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-22', 'dossier_id': 205}
# {'document_id': '1107351', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1107442', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1107626', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-23', 'dossier_id': 205}
# {'document_id': '1107818', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107850', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107852', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107854', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107888', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107892', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107902', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107937', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107951', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107959', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108012', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108015', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108018', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108019', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108021', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108026', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108027', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108031', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108034', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108038', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108039', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108041', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108043', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108055', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108057', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108063', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108071', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108073', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108077', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108079', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108083', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108093', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108105', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108109', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108115', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108119', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108131', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108139', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108141', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108158', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108170', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108172', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108176', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108188', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108198', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108258', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108262', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108263', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108265', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108267', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108270', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108272', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108288', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108296', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107895', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107901', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107918', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107922', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107928', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107933', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108002', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1109664', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-02', 'dossier_id': 205}
# {'document_id': '1109702', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1107935', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107939', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107941', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107945', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107947', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107949', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107953', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107955', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107957', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107975', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107976', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107992', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107994', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107998', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108001', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108010', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108054', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108065', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108067', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108069', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108125', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108127', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108148', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108154', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108160', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108164', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108178', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108186', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108209', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108210', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108235', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108248', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108249', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108253', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108300', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108306', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108382', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108402', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108404', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108406', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108408', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108415', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108417', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108446', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108453', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108496', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108521', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1108527', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-24', 'dossier_id': 205}
# {'document_id': '1108756', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1108762', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1108788', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-23', 'dossier_id': 205}
# {'document_id': '1108798', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1108806', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1108970', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1108990', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1109482', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1109488', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-07', 'dossier_id': 205}
# {'document_id': '1109575', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1109589', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1109596', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-09', 'dossier_id': 205}
# {'document_id': '1109658', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109660', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109662', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1109669', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109673', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109686', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109710', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-10', 'dossier_id': 205}
# {'document_id': '1109711', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109713', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109717', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109741', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109858', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1109887', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1109905', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109908', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-09', 'dossier_id': 205}
# {'document_id': '1109953', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-10', 'dossier_id': 205}
# {'document_id': '1109990', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1110002', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1110063', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-25', 'dossier_id': 205}
# {'document_id': '1110074', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-25', 'dossier_id': 205}
# {'document_id': '1110120', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1108123', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1109486', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1107890', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108061', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107907', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107868', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107894', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107943', 'document_sourcetype': 'Onbekend', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1110076', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-16', 'dossier_id': 205}
# {'document_id': '1109680', 'document_sourcetype': 'Onbekend', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1108189', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107017', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-19', 'dossier_id': 205}
# {'document_id': '1107930', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107986', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108023', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108240', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108204', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108961', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1108022', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108372', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108373', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108075', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1106961', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1107032', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1107101', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1107914', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107916', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1107987', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108199', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108200', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108201', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108205', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108220', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108174', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108242', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108251', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108261', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108366', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108286', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108287', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108440', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108445', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108391', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108441', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108444', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108484', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108492', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108580', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-10', 'dossier_id': 205}
# {'document_id': '1108523', 'document_sourcetype': 'PDF', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1108568', 'document_sourcetype': 'Word-document', 'document_date': '2021-01-18', 'dossier_id': 205}
# {'document_id': '1108586', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1108677', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1108692', 'document_sourcetype': 'PDF', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1108745', 'document_sourcetype': 'PDF', 'document_date': '2021-02-24', 'dossier_id': 205}
# {'document_id': '1108619', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-09', 'dossier_id': 205}
# {'document_id': '1109080', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-02', 'dossier_id': 205}
# {'document_id': '1109152', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109155', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109156', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109157', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109160', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109251', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1109252', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1109618', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-09', 'dossier_id': 205}
# {'document_id': '1109614', 'document_sourcetype': 'PDF', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1108437', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1106841', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-04-29', 'dossier_id': 205}
# {'document_id': '1107906', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108042', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108150', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1109258', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1108519', 'document_sourcetype': 'PDF', 'document_date': '2021-02-25', 'dossier_id': 205}
# {'document_id': '1109253', 'document_sourcetype': 'Spreadsheet', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1108232', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108426', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108430', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108479', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108485', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108556', 'document_sourcetype': 'Word-document', 'document_date': '2021-01-28', 'dossier_id': 205}
# {'document_id': '1108557', 'document_sourcetype': 'Word-document', 'document_date': '2021-01-28', 'dossier_id': 205}
# {'document_id': '1109478', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1109481', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1108049', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108264', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108266', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108285', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108395', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108558', 'document_sourcetype': 'Word-document', 'document_date': '2021-01-28', 'dossier_id': 205}
# {'document_id': '1108674', 'document_sourcetype': 'Spreadsheet', 'document_date': '2021-02-16', 'dossier_id': 205}
# {'document_id': '1108738', 'document_sourcetype': 'PDF', 'document_date': '2021-02-24', 'dossier_id': 205}
# {'document_id': '1108960', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-20', 'dossier_id': 205}
# {'document_id': '1108393', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1106900', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1108962', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1107470', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-26', 'dossier_id': 205}
# {'document_id': '1107546', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1107552', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1107609', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-10', 'dossier_id': 205}
# {'document_id': '1108016', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108017', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108046', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1109623', 'document_sourcetype': 'Presentatie', 'document_date': '2021-02-09', 'dossier_id': 205}
# {'document_id': '1108006', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108044', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108244', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108394', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108397', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108498', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108500', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108190', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '19 november 2024 13:40', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '19 november 2024 13:38', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '30 augustus 2024 8:01', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '2 mei 2024 16:01', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '2 mei 2024 12:30', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '1 mei 2024 13:45', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '1 mei 2024 13:38', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '24 april 2024 11:42', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 205}
# {'document_id': '1108312', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108336', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108338', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108344', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108386', 'document_sourcetype': 'PDF', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108390', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108411', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108412', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108448', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-27', 'dossier_id': 205}
# {'document_id': '1108513', 'document_sourcetype': 'PDF', 'document_date': '2021-02-26', 'dossier_id': 205}
# {'document_id': '1108536', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-01-11', 'dossier_id': 205}
# {'document_id': '1108552', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-01-22', 'dossier_id': 205}
# {'document_id': '1108591', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1108596', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1108599', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1108601', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-14', 'dossier_id': 205}
# {'document_id': '1108642', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1108758', 'document_sourcetype': 'PDF', 'document_date': '2021-05-20', 'dossier_id': 205}
# {'document_id': '1108771', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1108773', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-14', 'dossier_id': 205}
# {'document_id': '1108790', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-23', 'dossier_id': 205}
# {'document_id': '1108791', 'document_sourcetype': 'Presentatie', 'document_date': '2021-05-20', 'dossier_id': 205}
# {'document_id': '1108792', 'document_sourcetype': 'PDF', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1108794', 'document_sourcetype': 'PDF', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1108800', 'document_sourcetype': 'PDF', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1108804', 'document_sourcetype': 'PDF', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1108837', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1109022', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-02', 'dossier_id': 205}
# {'document_id': '1109059', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109106', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-02', 'dossier_id': 205}
# {'document_id': '1109110', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-02', 'dossier_id': 205}
# {'document_id': '1109126', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-02', 'dossier_id': 205}
# {'document_id': '1109127', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1109146', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109165', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-02', 'dossier_id': 205}
# {'document_id': '1109205', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-10', 'dossier_id': 205}
# {'document_id': '1109206', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1109230', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1109234', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109243', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1109259', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1109298', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1109301', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1109324', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1109339', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1109351', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1109390', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109421', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109422', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109438', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-13', 'dossier_id': 205}
# {'document_id': '1109451', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-10', 'dossier_id': 205}
# {'document_id': '1109452', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1109467', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109477', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109595', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-10', 'dossier_id': 205}
# {'document_id': '1109612', 'document_sourcetype': 'PDF', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1109619', 'document_sourcetype': 'PDF', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1109622', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-09', 'dossier_id': 205}
# {'document_id': '1109637', 'document_sourcetype': 'PDF', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109640', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1109668', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109677', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-03', 'dossier_id': 205}
# {'document_id': '1109683', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-04', 'dossier_id': 205}
# {'document_id': '1109695', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-10', 'dossier_id': 205}
# {'document_id': '1109700', 'document_sourcetype': 'PDF', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109706', 'document_sourcetype': 'PDF', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109708', 'document_sourcetype': 'PDF', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109724', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1109734', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1109738', 'document_sourcetype': 'PDF', 'document_date': '2021-02-09', 'dossier_id': 205}
# {'document_id': '1109778', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109804', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-08', 'dossier_id': 205}
# {'document_id': '1109832', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109838', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109852', 'document_sourcetype': 'PDF', 'document_date': '2021-02-09', 'dossier_id': 205}
# {'document_id': '1109889', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-14', 'dossier_id': 205}
# {'document_id': '1109896', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109901', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109902', 'document_sourcetype': 'PDF', 'document_date': '2021-02-05', 'dossier_id': 205}
# {'document_id': '1109909', 'document_sourcetype': 'E-mailbericht', 'document_date': '2021-02-14', 'dossier_id': 205}
# {'document_id': '1109920', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1109939', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1109963', 'document_sourcetype': 'PDF', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109965', 'document_sourcetype': 'PDF', 'document_date': '2021-02-12', 'dossier_id': 205}
# {'document_id': '1109974', 'document_sourcetype': 'PDF', 'document_date': '2021-02-15', 'dossier_id': 205}
# {'document_id': '1109987', 'document_sourcetype': 'PDF', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1109991', 'document_sourcetype': 'PDF', 'document_date': '2021-02-11', 'dossier_id': 205}
# {'document_id': '1110005', 'document_sourcetype': 'PDF', 'document_date': '2021-02-25', 'dossier_id': 205}
# {'document_id': '1110014', 'document_sourcetype': 'PDF', 'document_date': '2021-02-16', 'dossier_id': 205}
# {'document_id': '1110016', 'document_sourcetype': 'Word-document', 'document_date': '2021-05-20', 'dossier_id': 205}
# {'document_id': '1110017', 'document_sourcetype': 'PDF', 'document_date': '2021-02-20', 'dossier_id': 205}
# {'document_id': '1110019', 'document_sourcetype': 'PDF', 'document_date': '2021-02-16', 'dossier_id': 205}
# {'document_id': '1110021', 'document_sourcetype': 'PDF', 'document_date': '2021-02-16', 'dossier_id': 205}
# {'document_id': '1110023', 'document_sourcetype': 'PDF', 'document_date': '2021-02-01', 'dossier_id': 205}
# {'document_id': '1110027', 'document_sourcetype': 'Word-document', 'document_date': '2021-02-17', 'dossier_id': 205}
# {'document_id': '1110031', 'document_sourcetype': 'PDF', 'document_date': '2021-02-19', 'dossier_id': 205}
# {'document_id': '1110036', 'document_sourcetype': 'PDF', 'document_date': '2021-02-23', 'dossier_id': 205}
# {'document_id': '1110049', 'document_sourcetype': 'PDF', 'document_date': '2021-02-25', 'dossier_id': 205}
# {'document_id': '1110055', 'document_sourcetype': 'PDF', 'document_date': '2021-02-25', 'dossier_id': 205}
# ...
#   ✅ MATCH GEVONDEN! Updaten document 1112280
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-05
#
# ---
# 🔍 Matching document: VWS-WOO-08-1127738-RE_reactie_NCSC_advies_merkingrubricering_risico_analyse.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1127738
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-11
#
# ---
# 🔍 Matching document: VWS-WOO-08-1160225-FW_verzoek_Dienst_Testen_aanhaking_initiatiefnota_groenlinks.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1137507-Bijlage_3_Rolomschrijving_en_werkwijze_Wetenschappelijke_Adviesraad_Corona_Gedrag.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1137507
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-02-12
#
# ---
# 🔍 Matching document: VWS-WOO-08-1159627-FW_zuid_afrikaanse_variant_en_astrazeneca.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1110424-20210203_Memo_analyse_HIS-offertes_COVID-19_vaccinaties.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1110424
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-02-04
#
# ---
# 🔍 Matching document: VWS-WOO-08-1109110-Nieuwe_versie_brief.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1109110
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-02
#
# ---
# 🔍 Matching document: VWS-WOO-08-1140638-RE_COVID19_neutralisatie__hoe_pakken_we_dit_op__voor_MT_IIV.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1140638
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-17
#
# ---
# 🔍 Matching document: VWS-WOO-08-1110331-6._Factsheet_DOTT_week05_LCT.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1110331
#   📌 In CSV zetten → Type: PDF, Datum: 2021-02-03
#
# ---
# 🔍 Matching document: VWS-WOO-08-1116350-Acties_crisisoverleg_VWS-clientenorganisaties_16-2-2021.xlsx.xlsx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1116350
#   📌 In CSV zetten → Type: Spreadsheet, Datum: 2021-02-19
#
# ---
# 🔍 Matching document: VWS-WOO-08-1147770-RE_Vraag_Nursing-artikel_AstraZeneca_.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1147770
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-12
#
# ---
# 🔍 Matching document: VWS-WOO-08-1160378-RE_Distributieplan_restant_Moderna_vaccins_t.b.v._Onderzoek.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1163211-RE_Dashboard_en_ziekenhuizen.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1163211
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-01
#
# ---
# 🔍 Matching document: VWS-WOO-08-1124280-RE_zuid_afrikaanse_variant_en_astrazeneca_en_de_aantallen_virus_varianten_in_Nl.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1124280
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-08
#
# ---
# 🔍 Matching document: VWS-WOO-08-1118976-RE_Leveringen_AstraZeneca_vaccin_Q1Q2.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1118976
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-12
#
# ---
# 🔍 Matching document: VWS-WOO-08-1157354-Aantekeningen_-.docx.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1138518-RE_overlijden_na_vaccinatie.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1138518
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-15
#
# ---
# 🔍 Matching document: VWS-WOO-08-1146322-RE_Levering_Pfizer_vaccins.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1146322
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-18
#
# ---
# 🔍 Matching document: VWS-WOO-08-1165942-210106_1e_Brief_Gedragsreflecties_op_scenario_en_maatregelen-def_-.docx.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1295017-NoteToSFGCtte_vote_on_vaccines.docx.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1153951-aanvraagformulier_vaccins_Defensie_en_BuZa.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1153951
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-02-16
#
# ---
# 🔍 Matching document: VWS-WOO-08-1119570-RE_nav_jouw_vraag_voor_persmoment.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1119570
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-05
#
# ---
# 🔍 Matching document: VWS-WOO-08-1110406-20210204_Geannoteerde_Agenda_VC_Gezaghebbers.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1110406
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-02-02
#
# ---
# 🔍 Matching document: VWS-WOO-08-1165645-NCTV_dagstart_terugkoppeling__17_feb.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1120979-fiches_voor_Recovery_and_Resilience_Fund_van_de_EC.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1120979
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-01
#
# ---
# 🔍 Matching document: VWS-WOO-08-1158816-6.11_cover_note_Task_Force_AOB_internal_market_VTC_25Feb2021.docx.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1142504-Niuewe_radiocommercials.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1142504
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-28
#
# ---
# 🔍 Matching document: VWS-WOO-08-1141389-RE_nagebeld_over_102_jarige_mevrouw.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1141389
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-03-01
#
# ---
# 🔍 Matching document: VWS-WOO-08-1144543-FW_Viruswaarheid_en_kinderen.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1144543
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-02
#
# ---
# 🔍 Matching document: VWS-WOO-08-1159287-FW_Follow-up_discussion_Janssen_COVID-19_Vaccine.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1126152-RE_Eerste_leveringen_COVID_voor_-_en_BES_-.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1126152
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-01
#
# ---
# 🔍 Matching document: VWS-WOO-08-1118179-RE_Afbakening_zorgmedewerkers.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1118179
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-15
#
# ---
# 🔍 Matching document: VWS-WOO-08-1143818-RE_Apple_Maps_voor_Covid-19_testlocaties.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1143818
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-21
#
# ---
# 🔍 Matching document: VWS-WOO-08-1150196-RE_Begroting_COVID-15__16__17_2021.xlsx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1150196
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-17
#
# ---
# 🔍 Matching document: VWS-WOO-08-1165362-RE_Covid_vragen__.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1146463-FW_beoordeling_VTGM_instructie_.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1146463
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-09
#
# ---
# 🔍 Matching document: VWS-WOO-08-1136907-16022021_Presentatie_Dagstart_light_versie.pptx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1136907
#   📌 In CSV zetten → Type: Presentatie, Datum: 2021-02-16
#
# ---
# 🔍 Matching document: VWS-WOO-08-1126285-RE_Ideeen_voor_gedragsinterventies_voor_Vaccineren_vanuit_RRT.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1126285
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-10
#
# ---
# 🔍 Matching document: VWS-WOO-08-1147584-RE_Vraag_Gezondheidsraad_vaccinatiebeleid_in_Versie_4_stand_vanzakenbrief.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1147584
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-24
#
# ---
# 🔍 Matching document: VWS-WOO-08-1138483-FW_Eerste_antwoorden_op_jullie_vragen_van_woensdag_10_februari_2021.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1138483
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-03-03
#
# ---
# 🔍 Matching document: VWS-WOO-08-1155757-Duiding_wekelijkse_rapportage_week7_v4.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1155757
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-02-16
#
# ---
# 🔍 Matching document: VWS-WOO-08-1120528-RE_Vraag_aan_-_-__betr._Webinar_17_febr._2021.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1120528
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-24
#
# ---
# 🔍 Matching document: VWS-WOO-08-1137082-B4_Vaccinatiescenarios_Gesprekshandleiding_focusgroep_DEF.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1137082
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-02-22
#
# ---
# 🔍 Matching document: VWS-WOO-08-1126963-20210223_Dagafronding_PM.pptx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1126963
#   📌 In CSV zetten → Type: Presentatie, Datum: 2021-02-23
#
# ---
# 🔍 Matching document: VWS-WOO-08-1151068-FW_Vaccinatie_van_medewerkers_van_klinische_MSR-pati__nten.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1151068
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-05
#
# ---
# 🔍 Matching document: VWS-WOO-08-1110401-2021-ERN_COVID-19_vaccination.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1110401
#   📌 In CSV zetten → Type: PDF, Datum: 2021-02-09
#
# ---
# 🔍 Matching document: VWS-WOO-08-1111631-RE_aantekeningen_bij_opdrachtbrief.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1111631
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-24
#
# ---
# 🔍 Matching document: VWS-WOO-08-1156874-Antw__signalen_vaccineren.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1156874
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-10
#
# ---
# 🔍 Matching document: VWS-WOO-08-1121276-RE_Antw__mix_COVID_vaccins.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1121276
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-24
#
# ---
# 🔍 Matching document: VWS-WOO-08-1145932-RE_Project_WO-Covid19_Stappen_voorwaarts.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1145932
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-19
#
# ---
# 🔍 Matching document: VWS-WOO-08-1156735-RE_Melding_dichte_flacons__AGB_41412903.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1156735
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-26
#
# ---
# 🔍 Matching document: VWS-WOO-08-1134442-Operatie_Steepen_the_Curve_-_VWS_update_10_feb_2021__002___003_.pptx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1134442
#   📌 In CSV zetten → Type: Presentatie, Datum: 2021-02-23
#
# ---
# 🔍 Matching document: VWS-WOO-08-1136682-FW_Dubbel_check__medische_indicatie.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1136682
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-12
#
# ---
# 🔍 Matching document: VWS-WOO-08-1156846-RE_Veegactie_vraag.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1156846
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-15
#
# ---
# 🔍 Matching document: VWS-WOO-08-1122428-Fw_nieuwe_tekst_voor_enkele_dosis_vaccin_na_eerdere_ernstige_bijwerkingen.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1122428
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-23
#
# ---
# 🔍 Matching document: VWS-WOO-08-1130527-20210204_PPT_TB_concept_0.4_Slides_GGD_GHOR_NL_v2.pptx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1130527
#   📌 In CSV zetten → Type: Presentatie, Datum: 2021-02-03
#
# ---
# 🔍 Matching document: VWS-WOO-08-1161741-FW_Reminder--_Deelname_aan_vaccinatieprogramma_.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1145350-RE_Marjolein_CC_email.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1145350
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-22
#
# ---
# 🔍 Matching document: VWS-WOO-08-1146730-RE_Gesprek_gister_.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1146730
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-24
#
# ---
# 🔍 Matching document: VWS-WOO-08-1158730-FW_Callcenter.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1158730
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-02
#
# ---
# 🔍 Matching document: VWS-WOO-08-1142612-FW_pbm_voor_mantelzorgers.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1142612
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-24
#
# ---
# 🔍 Matching document: VWS-WOO-08-1114275-Advies_prioritering_medische_hoogrisicogroepen_voor_COVID-19-vaccinatie.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1114275
#   📌 In CSV zetten → Type: PDF, Datum: 2021-01-31
#
# ---
# 🔍 Matching document: VWS-WOO-08-1159333-FW_7-institutenoverleg_ma_15_februari_a.s._agenda_en_stukken.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-08-1115300-FW_HSC_audio_meeting_100221_14.00_Summary_of_the_view_of_all_ERNs_on_priorities_a.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1115300
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-11
#
# ---
# 🔍 Matching document: VWS-WOO-08-1145697-RE_Antw___ServiceNow_Vaccinatie_Management_Platform.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1145697
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-17
#
# ---
# 🔍 Matching document: VWS-WOO-08-1113461-Nota_ter_beslissing_2021-01-27_9_19_12.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1113461
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-02-03
#
# ---
# 🔍 Matching document: VWS-WOO-08-1128191-RE_URGENT__stand_van_zaken_vaccinatie_Covid_Statia_ne_bezoek_opdinsdag_16_feb.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1128191
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-11
#
# ---
# 🔍 Matching document: VWS-WOO-08-1137781-RE_script_Vaccinatie_proces_-_V6.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1137781
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-11
#
# ---
# 🔍 Matching document: VWS-WOO-08-1145401-RE_Nieuwe_versie_passage_COVID-19_vaccinatie.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1145401
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-22
#
# ---
# 🔍 Matching document: VWS-WOO-08-1136429-Adviesvraag_RIVM_inzake_type_II_mondkapjes_-_-_-_-.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1136429
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-02-19
#
# ---
# 🔍 Matching document: VWS-WOO-08-1118338-RE_Vaccin-procedure_overleg_12022021__vertrouwelijk_.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1118338
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-12
#
# ---
# 🔍 Matching document: VWS-WOO-08-1140888-RE_serologische_bepalingen_COBRA-KAI_studie.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1140888
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-23
#
# ---
# 🔍 Matching document: VWS-WOO-08-1130236-Verslag_Overkoepelend_uitvoeringsoverleg_25_februari_2021_versie_0.1_-.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1130236
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-03-02
#
# ---
# 🔍 Matching document: VWS-WOO-08-1116436-Agenda_16_februari.docx.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1116436
#   📌 In CSV zetten → Type: Word-document, Datum: 2021-02-16
#
# ---
# 🔍 Matching document: VWS-WOO-08-1113643-217513_akkoord_min_MZS_op_nota.pdf.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1113643
#   📌 In CSV zetten → Type: PDF, Datum: 2021-02-11
#
# ---
# 🔍 Matching document: VWS-WOO-08-1112557-RE_Antw__Elimination_strategy_HSC_discussion_paper_25.02.21.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1112557
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-28
#
# ---
# 🔍 Matching document: VWS-WOO-08-1155114-20210223_Verslag_miniwerkgroep_geanonimiseerde_data_DPV_210_v1.0.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1155114
#   📌 In CSV zetten → Type: PDF, Datum: 2021-02-23
#
# ---
# 🔍 Matching document: VWS-WOO-08-1107212-RE_Aanbiedingsbrief_extra_beveiliging_opslaglocaties.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1107212
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-17
#
# ---
# 🔍 Matching document: VWS-WOO-08-1145911-FW_PGB-zorgverleners.pdf
#   ✅ MATCH GEVONDEN! Updaten document 1145911
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2021-02-02
#
# ---
# 🔍 Matching document: VWS-WOO-08-1154250-Verslag_RIVM_VWS_GGD_GHOR_31-3-2021.docx.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 93
#      89                 break  # Stop met zoeken zodra de match is gevonden
#      91     return df_documents
# ---> 93 df_documents = match_documents(df_documents, df_metadata, dossier_id)
#      95 # Opslaan van de verrijkte dataset
#      96 df_documents.to_csv("df_documents_dates.csv", index=False)
#
# Cell In[2], line 81, in match_documents(df_documents, df_metadata, dossier_id)
#      78 expected_identifier = f"{dossier_prefix}-{meta_doc_id}"  # Verwachte match
#      80 # Exacte match met regex
# ---> 81 if re.search(rf"\b{re.escape(expected_identifier)}\b", document_title):
#      82     print(f"  ✅ MATCH GEVONDEN! Updaten document {meta_doc_id}")
#      84     df_documents.at[i, "document_sourcetype"] = meta_row["document_sourcetype"]
#
# File /usr/lib/python3.12/re/__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# File /usr/lib/python3.12/re/__init__.py:291, in _compile(pattern, flags)
#     289 key = (type(pattern), pattern, flags)
#     290 # Item in _cache should be moved to the end if found.
# --> 291 p = _cache.pop(key, None)
#     292 if p is None:
#     293     if isinstance(pattern, Pattern):
#
# KeyboardInterrupt:
