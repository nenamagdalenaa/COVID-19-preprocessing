# %%
import os
import json
import zipfile
import pandas as pd
from IPython.display import display
import shutil

# Pad naar de map met ZIP-bestanden en waar alles uitgepakt wordt
input_folder = "/home/nena-meijer/PyCharmMiscProject/VWS_dossiers_zip"
output_folder = "/home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles"

# Maximale bestandsnaam lengte (inclusief extensie)
MAX_FILENAME_LENGTH = 100

# Kies hier het ZIP-bestand dat je wilt testen (pas de naam aan)
test_zip_filename = "Beslissing op bezwaar Wob-besluit coronamaatregelen.zip"  # Zet hier de naam van het ZIP-bestand dat je wilt testen
zip_path = os.path.join(input_folder, test_zip_filename)

# Dossier-ID starten bij 1
dossier_id = 1
extract_path = os.path.join(output_folder, f"dossier_{dossier_id}")

# Zorg dat de map bestaat
os.makedirs(extract_path, exist_ok=True)

# Data opslag
data = []

# ZIP-bestand openen en verwerken
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    for zip_info in zip_ref.infolist():
        if zip_info.is_dir():
            continue  # Skip directories

        # Bepaal originele bestandsnaam en extensie
        original_name = os.path.basename(zip_info.filename)
        file_ext = os.path.splitext(original_name)[1].lower()

        # Beperk de naam tot MAX_FILENAME_LENGTH, behoud de extensie
        base_name = os.path.splitext(original_name)[0]
        if len(base_name) > MAX_FILENAME_LENGTH:
            base_name = base_name[:MAX_FILENAME_LENGTH]
        safe_filename = f"{base_name}{file_ext}"

        # Opslaan op veilige locatie
        safe_path = os.path.join(extract_path, safe_filename)

        # Bestand veilig extraheren
        with zip_ref.open(zip_info) as source, open(safe_path, "wb") as target:
            shutil.copyfileobj(source, target)

# Metadata.json uitlezen (als die bestaat)
metadata_path = os.path.join(extract_path, "metadata.json")
published_date, decision_date = None, None
dossier_name = None
if os.path.exists(metadata_path):
    with open(metadata_path, "r", encoding="utf-8") as f:
        metadata = json.load(f)
        dossier_name = metadata.get("title")
        published_date = metadata.get("published_date")
        decision_date = metadata.get("decision_date")

# Bestandsteller starten
file_counter = 1

# Loop door alle uitgepakte bestanden
for file in os.listdir(extract_path):
    if file == "metadata.json":  # Metadata.json zelf negeren
        continue

    file_path = os.path.join(extract_path, file)
    file_ext = os.path.splitext(file)[1].lower()

    # Genereer file_id (bijv. 1-1, 1-2, etc.)
    file_id = f"{dossier_id}-{file_counter}"
    file_counter += 1  # Verhoog teller

    # Opslaan in lijst
    data.append({
        "dossier_id": dossier_id,
        "dossier_name": dossier_name,
        "file_id": file_id,
        "file_name": file,
        "file_type": file_ext,
        "dossier_published_date": published_date,
        "dossier_decision_date": decision_date
    })

# DataFrame maken en weergeven
df = pd.DataFrame(data)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)
display(df)

# %%
import os
import json
import zipfile
import pandas as pd
from IPython.display import display
import shutil

# Pad naar de map met ZIP-bestanden en waar alles uitgepakt wordt
input_folder = "/home/nena-meijer/PyCharmMiscProject/VWS_dossiers_zip"
output_folder = "/home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles"

# Maximale bestandsnaam lengte (inclusief extensie)
MAX_FILENAME_LENGTH = 100

# Data opslag
data = []

# Zoek alle ZIP-bestanden in de input folder
zip_files = sorted([f for f in os.listdir(input_folder) if f.endswith(".zip")])

# Loop door alle ZIP-bestanden en verwerk ze
for dossier_id, zip_filename in enumerate(zip_files, start=1):
    zip_path = os.path.join(input_folder, zip_filename)
    extract_path = os.path.join(output_folder, f"dossier_{dossier_id}")

    # Zorg dat de map bestaat
    os.makedirs(extract_path, exist_ok=True)

    # ZIP-bestand openen en verwerken
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        for zip_info in zip_ref.infolist():
            if zip_info.is_dir():
                continue  # Skip directories

            # Bepaal originele bestandsnaam en extensie
            original_name = os.path.basename(zip_info.filename)
            file_ext = os.path.splitext(original_name)[1].lower()

            # Beperk de naam tot MAX_FILENAME_LENGTH, behoud de extensie
            base_name = os.path.splitext(original_name)[0]
            if len(base_name) > MAX_FILENAME_LENGTH:
                base_name = base_name[:MAX_FILENAME_LENGTH]
            safe_filename = f"{base_name}{file_ext}"

            # Opslaan op veilige locatie
            safe_path = os.path.join(extract_path, safe_filename)

            # Bestand veilig extraheren
            with zip_ref.open(zip_info) as source, open(safe_path, "wb") as target:
                shutil.copyfileobj(source, target)

    # Metadata.json uitlezen (als die bestaat)
    metadata_path = os.path.join(extract_path, "metadata.json")
    published_date, decision_date, dossier_name = None, None, None
    if os.path.exists(metadata_path):
        with open(metadata_path, "r", encoding="utf-8") as f:
            metadata = json.load(f)
            dossier_name = metadata.get("title")
            published_date = metadata.get("published_date")
            decision_date = metadata.get("decision_date")

    # Datumconversie naar datetime-formaat (indien beschikbaar)
    published_date = pd.to_datetime(published_date, errors='coerce')
    decision_date = pd.to_datetime(decision_date, errors='coerce')

    # Bestandsteller starten
    file_counter = 1

    # Loop door alle uitgepakte bestanden
    for file in os.listdir(extract_path):
        if file == "metadata.json":  # Metadata.json zelf negeren
            continue

        file_path = os.path.join(extract_path, file)
        file_ext = os.path.splitext(file)[1].lower()

        # Genereer file_id (bijv. 1-1, 1-2, etc.)
        file_id = f"{dossier_id}-{file_counter}"
        file_counter += 1  # Verhoog teller

        # Opslaan in lijst
        data.append({
            "dossier_id": dossier_id,
            "dossier_name": dossier_name,
            "file_id": file_id,
            "file_name": file,
            "file_source": file_path,
            "file_type": file_ext,
            "dossier_published_date": published_date,
            "dossier_decision_date": decision_date
        })

# DataFrame maken en weergeven
df = pd.DataFrame(data)

# Instellingen voor brede tabellen en volledige tekstweergave
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)

# DataFrame weergeven
display(df)

# %%
df.to_csv("df.csv", index=False)

# %%
import pandas as pd
from IPython.display import display

# CSV inlezen
df = pd.read_csv("df.csv")

# Filter alleen relevante kolommen
df_filtered = df[["dossier_id", "dossier_name", "file_name", "dossier_published_date", "dossier_decision_date"]]

# Verwijder metadata.json en groepeer per dossier_id
df_aggregated = (
    df_filtered[df_filtered["file_name"] != "metadata.json"]
    .groupby(["dossier_id", "dossier_name", "dossier_published_date", "dossier_decision_date"])
    .agg(document_count=("file_name", "count"))  # Tel documenten per dossier
    .reset_index()
)

# Instellingen om lange tekst volledig te tonen
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)

# DataFrame weergeven in Jupyter Notebook
display(df_aggregated)

# Opslaan als CSV
df_aggregated.to_csv("df_dossiers.csv", index=False)

print("✅ Geaggregeerde CSV opgeslagen als 'df_dossiers.csv'")
# Out:
#      dossier_id                                                                                                                   dossier_name dossier_published_date dossier_decision_date  document_count
# 0             1                                                                   (4e deel) Besluit Woo-verzoek Covid-19 aanpak DOC-19 Q4 2020             2024-02-05            2023-07-29             229
# 1             2                                                                          Woo-besluit aangaande kaders werkproces Wob-verzoeken             2024-03-22            2023-03-20              83
# 2             3                                                                        1e deel Besluit Woo verzoek Covid-19 aanpak ACC Q4 2020             2024-02-07            2022-08-18             208
# 3             4                                                                        2e deel Besluit Woo verzoek Covid-19 aanpak ACC Q1 2021             2024-02-08            2023-02-17             239
# 4             5                                                              3e deel Besluit Woo verzoek Covid-19 aanpak ACC-19 April-Mei 2021             2024-02-07            2022-05-12             144
# ..          ...                                                                                                                            ...                    ...                   ...             ...
# 215         216                                                                       Woo-deelbesluit aangaande overeenkomsten PCR-laboratoria             2024-06-06            2024-03-27              68
# 216         217                                                                 Woo-deelbesluit aangaande vaccinatie aansprakelijkheid Deel II             2024-10-09            2024-10-02             116
# 217         218                                                          Woo-deelbesluit aangaande ‘Capaciteit van ziekenhuizen IC-capaciteit'             2024-10-19            2024-09-12             199
# 218         219  Woo-deelbesluit aangaande ‘de inkoop van persoonlijke beschermingsmiddelen tijdens de coronacrisis en het onderzoek daarnaar’             2024-04-05            2024-02-14            2695
# 219         220                                                         Woo-verzoek d.d. 6 januari 2022 inzake het Europees Herstelfonds (LNV)             2024-02-05            2022-05-12               9
#
# [220 rows x 5 columns]
# ✅ Geaggregeerde CSV opgeslagen als 'df_dossiers.csv'

# %%
import pandas as pd
from IPython.display import display

# CSV inlezen
df = pd.read_csv("df.csv")

# Verwijder spaties in kolomnamen (indien nodig)
df.columns = df.columns.str.strip()

# Controleer of de verwachte kolommen aanwezig zijn
expected_columns = ["dossier_id", "file_name", "file_type"]
missing_columns = [col for col in expected_columns if col not in df.columns]

if missing_columns:
    print(f"❌ De volgende kolommen ontbreken in de CSV: {missing_columns}")
else:
    # Selecteer relevante kolommen en hernoem file_name naar document_title
    df_documents = df[["dossier_id", "file_name", "file_type"]].rename(
        columns={"file_name": "document_title", "file_type": "document_type"}
    )

    # Verwijder metadata.json
    df_documents = df_documents[df_documents["document_title"] != "metadata.json"]

    # Verwijder de punt uit document_type (extensie)
    df_documents["document_type"] = df_documents["document_type"].str.replace(".", "", regex=False)

    # Document-ID toevoegen (per dossier_id een oplopende teller)
    df_documents["document_id"] = (
        df_documents.groupby("dossier_id").cumcount() + 1  # Start teller bij 1 per dossier
    ).astype(str)

    # Combineer document_id met dossier_id
    df_documents["document_id"] = df_documents["dossier_id"].astype(str) + "-" + df_documents["document_id"]

    # Kolommen opnieuw ordenen
    df_documents = df_documents[["dossier_id", "document_id", "document_title", "document_type"]]

    # Opslaan als nieuwe CSV
    df_documents.to_csv("df_documents.csv", index=False)

    # DataFrame weergeven
    display(df_documents)
    print("✅ Geëxporteerd als 'df_documents.csv'")
# Out:
#         dossier_id document_id                                                                            document_title document_type
# 0                1         1-1                        VWS-WC-098-DOC201208J-Concept_Platte_tekst_herijkte_routekaart.pdf           pdf
# 1                1         1-2                         VWS-WC-098-201130D-Actiepuntenlijst_DOC-19_-_27_november_2020.pdf           pdf
# 2                1         1-3                  VWS-WC-098-201127F-Presentatie_verdiepingssessie_vaccinatiestrategie.pdf           pdf
# 3                1         1-4                   VWS-WC-098-201215F-Implementatie_gedragsinterventies_DGSC-19_en_RRT.pdf           pdf
# 4                1         1-5                                       VWS-WC-098-201006A-Agenda_DOC-19_6_oktober_2020.pdf           pdf
# ...            ...         ...                                                                                       ...           ...
# 109029         220       220-5                    VWS-WC-107-2a-2020_RV_0022_Masterplan_emissieloze_maritieme_sector.pdf           pdf
# 109030         220       220-6                      VWS-WC-107-1-FW_Masterplan_voor_een_emissieloze_maritieme_sector.pdf           pdf
# 109031         220       220-7                                        VWS-WC-107-4-video-overleg_Corona_herstelfonds.pdf           pdf
# 109032         220       220-8  VWS-WC-107-3-Vraag_om_informatie_over_RFF_in_relatie_tot_emissiearme_kotter_visserij.pdf           pdf
# 109033         220       220-9                 VWS-WC-107-6-RE_Reactie_gevraagd_op_fiche_emissieloze_kotter_voor_RRF.pdf           pdf
#
# [109034 rows x 4 columns]
# ✅ Geëxporteerd als 'df_documents.csv'

# %%
import time

def scrape_document_metadata(dossier_url):
    """Scrapet documentmetadata van alle pagina's binnen een dossier met een crawl delay."""

    # Extract dossier ID uit de URL
    dossier_id_match = re.search(r'/dossier/([^/]+)', dossier_url)
    dossier_id_str = dossier_id_match.group(1) if dossier_id_match else None

    metadata_list = []
    seen_documents = set()
    page = 1
    max_pages = 80 # Failsafe om te voorkomen dat hij oneindig blijft lopen

    while page <= max_pages:
        paged_url = f"{dossier_url}?prefix=VWS-WC&dossierId={dossier_id_str}&pu={page}#tabcontrol-1"
        response = requests.get(paged_url)
        if response.status_code != 200:
            print(f"Fout bij ophalen van {paged_url}")
            break

        soup = BeautifulSoup(response.text, "html.parser")
        table_rows = soup.select(".woo-table tbody tr")
        if not table_rows:
            print(f"Geen documenten gevonden op pagina {page}, stoppen met scrapen.")
            break

        new_documents_found = False

        for row in table_rows:
            try:
                # Document ID ophalen uit de eerste kolom
                doc_id_tag = row.select_one("td:nth-of-type(1)")
                doc_id = doc_id_tag.text.strip() if doc_id_tag else None

                # Document URL ophalen
                doc_link_tag = row.select_one("td:nth-of-type(3) a")
                doc_url = doc_link_tag["href"] if doc_link_tag else ""

                if not doc_id or doc_id in seen_documents:
                    continue

                seen_documents.add(doc_id)
                new_documents_found = True

                # Documenttype
                doc_type_tag = row.select_one("td:nth-of-type(2) use")
                doc_type_key = doc_type_tag["xlink:href"].split("#")[-1] if doc_type_tag else "unknown"
                doc_type = DOCUMENT_TYPE_MAP.get(doc_type_key, "Onbekend")

                # Documentdatum correct ophalen
                doc_date_tag = row.select_one("td:nth-of-type(4) time")
                doc_date = doc_date_tag["datetime"] if doc_date_tag else None

                metadata_list.append({
                    "document_id": doc_id,
                    "document_sourcetype": doc_type,
                    "document_date": doc_date,
                    "dossier_id": dossier_id
                })
            except Exception as e:
                print(f"Fout bij parsen: {e}")

        if not new_documents_found:
            print(f"Geen nieuwe documenten meer gevonden op pagina {page}, stoppen met scrapen.")
            break

        page += 1
        time.sleep(1)  # Crawl delay na elke pagina scrape

    for doc in metadata_list:
        print(doc)

    return metadata_list

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# Mapping van documenttypes
DOCUMENT_TYPE_MAP = {
    "unknown": "Onbekend",
    "pdf": "PDF",
    "email": "E-mailbericht",
    "presentation": "Presentatie",
    "doc": "Word-document",
    "chat": "Chatbericht",
    "image": "Afbeelding",
    "spreadsheet": "Spreadsheet"
}

# Inlezen van de bestaande documentgegevens
df_documents = pd.read_csv("df_ALL_documents.csv", dtype={"document_id": str})
df_dossiers = pd.read_csv("df_dossiers_final.csv", dtype={"dossier_id": int})

# Handmatig dossier_id invoeren
dossier_id = 131

dossier = df_dossiers[df_dossiers["dossier_id"] == dossier_id].iloc[0]
dossier_url = dossier["dossier_sourceURL"]

print(f"Scrapen: {dossier_url}")
document_metadata = scrape_document_metadata(dossier_url)

# Omzetten naar dataframe
df_metadata = pd.DataFrame(document_metadata)

def extract_prefix(document_title):
    """Probeert het juiste dossierprefix te extraheren uit de document_title."""

    # Specifieke uitzondering: als het document begint met "VWS-WC-19.00-1-", dan is de prefix gewoon "VWS-WC"
    if document_title.startswith("CCMO-WOO-00-104.pdf"):
        return "CCMO-WOO-00"

    # Standaardpatronen voor prefixes
    match = re.match(r"^(VWS-WC-\d{3}|VWS-WOO-[A-Za-z0-9]+|VWS-WC)", document_title)
    return match.group(1) if match else None

def match_documents(df_documents, df_metadata, dossier_id):
    """Matcht gescrapete metadata met documenten op basis van dossierprefix en document_id."""
    df_documents_dossier = df_documents[df_documents["dossier_id"] == dossier_id]

    if df_documents_dossier.empty:
        print(f"⚠️ Geen documenten gevonden voor dossier_id {dossier_id}")
        return df_documents

    # Zoek het eerste document dat GEEN generieke naam heeft
    sample_document_title = None
    for title in df_documents_dossier["document_title"]:
        if not title.lower().startswith("besluitbrief"):  # Voeg andere generieke namen toe indien nodig
            sample_document_title = title
            break

    if not sample_document_title:
        print(f"❌ Geen geldig document gevonden om een prefix uit te halen voor dossier {dossier_id}.")
        return df_documents

    dossier_prefix = extract_prefix(sample_document_title)

    if not dossier_prefix:
        print(f"❌ Geen geldig dossierprefix gevonden in: {sample_document_title}")
        return df_documents

    print(f"🔎 Dossierprefix bepaald als: {dossier_prefix}")

    for i, doc_row in df_documents_dossier.iterrows():
        document_title = doc_row["document_title"]
        print(f"\n---\n🔍 Matching document: {document_title}")

        for _, meta_row in df_metadata.iterrows():
            meta_doc_id = str(meta_row["document_id"]).strip()  # Zorgt dat het ID een string is
            expected_identifier = f"{dossier_prefix}-{meta_doc_id}"  # Verwachte match

            # Exacte match met regex
            if re.search(rf"\b{re.escape(expected_identifier)}\b", document_title):
                print(f"  ✅ MATCH GEVONDEN! Updaten document {meta_doc_id}")

                df_documents.at[i, "document_sourcetype"] = meta_row["document_sourcetype"]
                df_documents.at[i, "document_date"] = meta_row["document_date"]

                # Print de waarde die in de CSV wordt gezet
                print(f"  📌 In CSV zetten → Type: {meta_row['document_sourcetype']}, Datum: {meta_row['document_date']}")
                break  # Stop met zoeken zodra de match is gevonden

    return df_documents

df_documents = match_documents(df_documents, df_metadata, dossier_id)

# Opslaan van de verrijkte dataset
df_documents.to_csv("df_ALL_documents.csv", index=False)
print(f"Scraping en verrijking voltooid voor dossier {dossier_id}!")
print(dossier_url)
# Out:
# Scrapen: https://open.minvws.nl/dossier/VWS-WOO/3276778-1019108-wjz
# Geen nieuwe documenten meer gevonden op pagina 48, stoppen met scrapen.
# {'document_id': 'Gedeeltelijke openbaarmaking', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': 'Wob-besluit', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': '211101 Wob-deelbesluit scenarios en maatregelen aug20 3276778-1019108-WJZ.pdf (PDF, 2.58 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': 'ministerie van Volksgezondheid, Welzijn en Sport', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': 'Augustus 2020', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': '1 november 2021', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': "9.987 documenten,                        \n                                                    19.750 pagina's\n                            \n                                                \nInventarislijst", 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': 'Scenario’s en maatregelen', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': '220224 beslissing op bezwaar DWJZ-2021001168 3327340-1025408-WJZ.pdf (PDF, 2.83 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': '220428 beslissing op bezwaar DWJZ-2021001195.pdf (PDF, 3.89 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': '231130 beslissing op bezwaar DWJZ-2022000555.PDF (PDF, 3.53 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': '530003', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530009', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530021', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530045', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530053', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530097', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530122', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530126', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530190', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530192', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530256', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530262', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530270', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530272', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530274', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530284', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530286', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530287', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530295', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530296', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530297', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530312', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530314', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530322', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530420', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530433', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530441', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530445', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530449', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530451', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530454', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530456', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530458', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530459', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530461', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530462', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530463', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530469', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530471', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530473', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530475', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530518', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-07-27', 'dossier_id': 131}
# {'document_id': '530519', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-07-27', 'dossier_id': 131}
# {'document_id': '530539', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-07-26', 'dossier_id': 131}
# {'document_id': '530560', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '530595', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '530596', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '530616', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-16', 'dossier_id': 131}
# {'document_id': '530620', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-29', 'dossier_id': 131}
# {'document_id': '530625', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-15', 'dossier_id': 131}
# {'document_id': '530627', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '530638', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '530656', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '530669', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '530680', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '530700', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-24', 'dossier_id': 131}
# {'document_id': '530705', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '530721', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '530723', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-17', 'dossier_id': 131}
# {'document_id': '530731', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-03', 'dossier_id': 131}
# {'document_id': '530742', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-02', 'dossier_id': 131}
# {'document_id': '530744', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-01', 'dossier_id': 131}
# {'document_id': '530752', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-03', 'dossier_id': 131}
# {'document_id': '530753', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-03', 'dossier_id': 131}
# {'document_id': '530767', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '530769', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '530783', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-12', 'dossier_id': 131}
# {'document_id': '530784', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '530789', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-12', 'dossier_id': 131}
# {'document_id': '530805', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '530812', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-17', 'dossier_id': 131}
# {'document_id': '530820', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '530837', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-19', 'dossier_id': 131}
# {'document_id': '530870', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-23', 'dossier_id': 131}
# {'document_id': '530872', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-23', 'dossier_id': 131}
# {'document_id': '530881', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '530907', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '530910', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '530912', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '530919', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '530936', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '530968', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '530970', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-09', 'dossier_id': 131}
# {'document_id': '530974', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '530976', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '530997', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-15', 'dossier_id': 131}
# {'document_id': '530999', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-17', 'dossier_id': 131}
# {'document_id': '531021', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '531046', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-29', 'dossier_id': 131}
# {'document_id': '531061', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-02', 'dossier_id': 131}
# {'document_id': '531069', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-02', 'dossier_id': 131}
# {'document_id': '531070', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '531074', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '531075', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '531090', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-17', 'dossier_id': 131}
# {'document_id': '531097', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-23', 'dossier_id': 131}
# {'document_id': '531143', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '531146', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '531174', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-02', 'dossier_id': 131}
# {'document_id': '531176', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-24', 'dossier_id': 131}
# {'document_id': '532058', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '532062', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '532078', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '532080', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-30', 'dossier_id': 131}
# {'document_id': '532091', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-21', 'dossier_id': 131}
# {'document_id': '532092', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '532139', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '532143', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '532146', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '532148', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '532149', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '532158', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-25', 'dossier_id': 131}
# {'document_id': '532164', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-21', 'dossier_id': 131}
# {'document_id': '532165', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-21', 'dossier_id': 131}
# {'document_id': '532216', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532226', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-29', 'dossier_id': 131}
# {'document_id': '532228', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '532230', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-29', 'dossier_id': 131}
# {'document_id': '532241', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '532242', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '530017', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530054', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530057', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530059', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530067', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530089', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530101', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530110', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530112', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530128', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530130', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530132', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530134', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530136', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530138', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530140', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530142', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530144', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530146', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530147', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530149', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530151', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530153', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530155', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530157', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530159', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530163', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530166', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530170', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530173', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530175', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530177', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530184', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530193', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530195', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530197', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530204', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530206', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530208', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530211', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530224', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530227', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530229', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530231', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530235', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530238', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530240', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530249', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530280', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530301', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530303', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530310', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530315', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530324', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530326', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530328', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530331', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530335', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530341', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530366', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530376', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530383', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530385', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530387', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530389', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530391', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530393', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530395', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530399', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530401', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530403', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530407', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530409', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530411', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530415', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530429', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530435', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530437', 'document_sourcetype': 'Onbekend', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '532012', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-12', 'dossier_id': 131}
# {'document_id': '532015', 'document_sourcetype': 'Onbekend', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532017', 'document_sourcetype': 'Presentatie', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532018', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532019', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-12', 'dossier_id': 131}
# {'document_id': '532020', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-25', 'dossier_id': 131}
# {'document_id': '532021', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532022', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-17', 'dossier_id': 131}
# {'document_id': '532023', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532048', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '532054', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-12', 'dossier_id': 131}
# {'document_id': '532055', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532057', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532167', 'document_sourcetype': 'PDF', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '532177', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '532178', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '532182', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-16', 'dossier_id': 131}
# {'document_id': '532184', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '532185', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-16', 'dossier_id': 131}
# {'document_id': '532198', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532199', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '532200', 'document_sourcetype': 'PDF', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '532202', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532203', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532204', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532208', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532217', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-15', 'dossier_id': 131}
# {'document_id': '532267', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '532270', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '532363', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '532365', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '532369', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '532377', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532383', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '532394', 'document_sourcetype': 'PDF', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532402', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-10', 'dossier_id': 131}
# {'document_id': '532406', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-17', 'dossier_id': 131}
# {'document_id': '532421', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '532423', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532424', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '532425', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-31', 'dossier_id': 131}
# {'document_id': '532429', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-30', 'dossier_id': 131}
# {'document_id': '532433', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '532434', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '532444', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532449', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-08', 'dossier_id': 131}
# {'document_id': '532450', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '532456', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532466', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-09', 'dossier_id': 131}
# {'document_id': '532467', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '532468', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '532479', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '532597', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532604', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '532613', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-30', 'dossier_id': 131}
# {'document_id': '532621', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '532634', 'document_sourcetype': 'Presentatie', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532639', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532648', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '532653', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '532656', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '7157', 'document_sourcetype': 'PDF', 'document_date': '2020-08-02', 'dossier_id': 131}
# {'document_id': '530043', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530105', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530107', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530172', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530181', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530183', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530186', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530191', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530271', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530307', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530320', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530339', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530343', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530347', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530349', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530351', 'document_sourcetype': 'PDF', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530413', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530418', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530448', 'document_sourcetype': 'Word-document', 'document_date': '2020-10-29', 'dossier_id': 131}
# {'document_id': '530774', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '531183', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-25', 'dossier_id': 131}
# {'document_id': '531233', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '531392', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '531553', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-30', 'dossier_id': 131}
# {'document_id': '531674', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '531997', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-21', 'dossier_id': 131}
# {'document_id': '531999', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '532000', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '532001', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-12', 'dossier_id': 131}
# {'document_id': '532002', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532003', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-12', 'dossier_id': 131}
# {'document_id': '532004', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532005', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532006', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532007', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-21', 'dossier_id': 131}
# {'document_id': '532008', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '532009', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '532010', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532013', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532014', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '537035', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '541572', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '541853', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '548005', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '549822', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '550103', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-31', 'dossier_id': 131}
# {'document_id': '552718', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-30', 'dossier_id': 131}
# {'document_id': '555625', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '559929', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '560232', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-19', 'dossier_id': 131}
# {'document_id': '567697', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '575245', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '576005', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '576011', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '576262', 'document_sourcetype': 'PDF', 'document_date': '2020-08-31', 'dossier_id': 131}
# {'document_id': '14 januari 2025 14:40', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 131}
# {'document_id': '531195', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '531196', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '531220', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '531225', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '531227', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '531246', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '531264', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '531268', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-10', 'dossier_id': 131}
# {'document_id': '531295', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '531302', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '531323', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-17', 'dossier_id': 131}
# {'document_id': '531352', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-17', 'dossier_id': 131}
# {'document_id': '531378', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-19', 'dossier_id': 131}
# {'document_id': '531379', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-19', 'dossier_id': 131}
# {'document_id': '531394', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-23', 'dossier_id': 131}
# {'document_id': '531402', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-24', 'dossier_id': 131}
# {'document_id': '531408', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-24', 'dossier_id': 131}
# {'document_id': '531413', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-24', 'dossier_id': 131}
# {'document_id': '531419', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-25', 'dossier_id': 131}
# {'document_id': '531436', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '531443', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '531466', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-31', 'dossier_id': 131}
# {'document_id': '531506', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '531514', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-25', 'dossier_id': 131}
# {'document_id': '531519', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '531528', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-10', 'dossier_id': 131}
# {'document_id': '531534', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '531563', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '531564', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '531593', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '531594', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '531607', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '531609', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-07', 'dossier_id': 131}
# {'document_id': '531613', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-31', 'dossier_id': 131}
# {'document_id': '531621', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '531651', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '531652', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-21', 'dossier_id': 131}
# {'document_id': '531662', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '531676', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-31', 'dossier_id': 131}
# {'document_id': '531689', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-14', 'dossier_id': 131}
# {'document_id': '531691', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-10', 'dossier_id': 131}
# {'document_id': '531698', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-03', 'dossier_id': 131}
# {'document_id': '531702', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-27', 'dossier_id': 131}
# {'document_id': '531710', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-24', 'dossier_id': 131}
# {'document_id': '531711', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '531737', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-17', 'dossier_id': 131}
# {'document_id': '531742', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-25', 'dossier_id': 131}
# {'document_id': '531747', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-17', 'dossier_id': 131}
# {'document_id': '531762', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-10-08', 'dossier_id': 131}
# {'document_id': '531801', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '531810', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '531812', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '531816', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-19', 'dossier_id': 131}
# {'document_id': '531818', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-19', 'dossier_id': 131}
# {'document_id': '531843', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '531852', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-24', 'dossier_id': 131}
# {'document_id': '531876', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-10-08', 'dossier_id': 131}
# {'document_id': '531889', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '531899', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '531907', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '531932', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-10', 'dossier_id': 131}
# {'document_id': '531933', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-21', 'dossier_id': 131}
# {'document_id': '531947', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-30', 'dossier_id': 131}
# {'document_id': '531949', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-21', 'dossier_id': 131}
# {'document_id': '531956', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-18', 'dossier_id': 131}
# {'document_id': '531975', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-20', 'dossier_id': 131}
# {'document_id': '531994', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-10', 'dossier_id': 131}
# {'document_id': '531998', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-10', 'dossier_id': 131}
# {'document_id': '532016', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532026', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-06', 'dossier_id': 131}
# {'document_id': '532028', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-09', 'dossier_id': 131}
# {'document_id': '532114', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-05', 'dossier_id': 131}
# {'document_id': '532126', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-25', 'dossier_id': 131}
# {'document_id': '532137', 'document_sourcetype': 'PDF', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '532140', 'document_sourcetype': 'PDF', 'document_date': '2020-08-28', 'dossier_id': 131}
# {'document_id': '532151', 'document_sourcetype': 'Spreadsheet', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '532154', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532155', 'document_sourcetype': 'E-mailbericht', 'document_date': '2020-08-26', 'dossier_id': 131}
# {'document_id': '532157', 'document_sourcetype': 'Presentatie', 'document_date': '2020-08-03', 'dossier_id': 131}
# {'document_id': '532169', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532170', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532171', 'document_sourcetype': 'Presentatie', 'document_date': '2020-08-11', 'dossier_id': 131}
# {'document_id': '532172', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-19', 'dossier_id': 131}
# {'document_id': '532183', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-04', 'dossier_id': 131}
# {'document_id': '532205', 'document_sourcetype': 'PDF', 'document_date': '2020-08-13', 'dossier_id': 131}
# {'document_id': '532222', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-25', 'dossier_id': 131}
# {'document_id': '532223', 'document_sourcetype': 'PDF', 'document_date': '2020-08-12', 'dossier_id': 131}
# {'document_id': '532229', 'document_sourcetype': 'Word-document', 'document_date': '2020-08-18', 'dossier_id': 131}
# ...
#   ✅ MATCH GEVONDEN! Updaten document 552800
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-21
#
# ---
# 🔍 Matching document: VWS-WOO-06-557340.pdf
#   ✅ MATCH GEVONDEN! Updaten document 557340
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-12
#
# ---
# 🔍 Matching document: VWS-WOO-06-576159.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-574730.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-557102.pdf
#   ✅ MATCH GEVONDEN! Updaten document 557102
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-10
#
# ---
# 🔍 Matching document: VWS-WOO-06-569960.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-544231.pdf
#   ✅ MATCH GEVONDEN! Updaten document 544231
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-11
#
# ---
# 🔍 Matching document: VWS-WOO-06-542762.pdf
#   ✅ MATCH GEVONDEN! Updaten document 542762
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-20
#
# ---
# 🔍 Matching document: VWS-WOO-06-540847.pdf
#   ✅ MATCH GEVONDEN! Updaten document 540847
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-04
#
# ---
# 🔍 Matching document: VWS-WOO-06-557197.pdf
#   ✅ MATCH GEVONDEN! Updaten document 557197
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-26
#
# ---
# 🔍 Matching document: VWS-WOO-06-571395.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-571721.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-555069.pdf
#   ✅ MATCH GEVONDEN! Updaten document 555069
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-11
#
# ---
# 🔍 Matching document: VWS-WOO-06-550653.pdf
#   ✅ MATCH GEVONDEN! Updaten document 550653
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-09-14
#
# ---
# 🔍 Matching document: VWS-WOO-06-570711.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-537895.pdf
#   ✅ MATCH GEVONDEN! Updaten document 537895
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-25
#
# ---
# 🔍 Matching document: VWS-WOO-06-546426.pdf
#   ✅ MATCH GEVONDEN! Updaten document 546426
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-13
#
# ---
# 🔍 Matching document: VWS-WOO-06-562109.pdf
#   ✅ MATCH GEVONDEN! Updaten document 562109
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-25
#
# ---
# 🔍 Matching document: VWS-WOO-06-536802.pdf
#   ✅ MATCH GEVONDEN! Updaten document 536802
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-31
#
# ---
# 🔍 Matching document: VWS-WOO-06-530881.pdf
#   ✅ MATCH GEVONDEN! Updaten document 530881
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-26
#
# ---
# 🔍 Matching document: VWS-WOO-06-532235.pdf
#   ✅ MATCH GEVONDEN! Updaten document 532235
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-18
#
# ---
# 🔍 Matching document: VWS-WOO-06-548849.pdf
#   ✅ MATCH GEVONDEN! Updaten document 548849
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-14
#
# ---
# 🔍 Matching document: VWS-WOO-06-546125.pdf
#   ✅ MATCH GEVONDEN! Updaten document 546125
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-20
#
# ---
# 🔍 Matching document: VWS-WOO-06-560356.pdf
#   ✅ MATCH GEVONDEN! Updaten document 560356
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-28
#
# ---
# 🔍 Matching document: VWS-WOO-06-539280.pdf
#   ✅ MATCH GEVONDEN! Updaten document 539280
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-17
#
# ---
# 🔍 Matching document: VWS-WOO-06-567800.pdf
#   ✅ MATCH GEVONDEN! Updaten document 567800
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-20
#
# ---
# 🔍 Matching document: VWS-WOO-06-557829.pdf
#   ✅ MATCH GEVONDEN! Updaten document 557829
#   📌 In CSV zetten → Type: PDF, Datum: 2020-08-27
#
# ---
# 🔍 Matching document: VWS-WOO-06-530625.pdf
#   ✅ MATCH GEVONDEN! Updaten document 530625
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-15
#
# ---
# 🔍 Matching document: VWS-WOO-06-575217.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-570183.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-552511.pdf
#   ✅ MATCH GEVONDEN! Updaten document 552511
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-19
#
# ---
# 🔍 Matching document: VWS-WOO-06-531949.pdf
#   ✅ MATCH GEVONDEN! Updaten document 531949
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-21
#
# ---
# 🔍 Matching document: VWS-WOO-06-545392.pdf
#   ✅ MATCH GEVONDEN! Updaten document 545392
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-06
#
# ---
# 🔍 Matching document: VWS-WOO-06-532253.pdf
#   ✅ MATCH GEVONDEN! Updaten document 532253
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-18
#
# ---
# 🔍 Matching document: VWS-WOO-06-532965.pdf
#   ✅ MATCH GEVONDEN! Updaten document 532965
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-11
#
# ---
# 🔍 Matching document: VWS-WOO-06-546253.pdf
#   ✅ MATCH GEVONDEN! Updaten document 546253
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-26
#
# ---
# 🔍 Matching document: VWS-WOO-06-543299.pdf
#   ✅ MATCH GEVONDEN! Updaten document 543299
#   📌 In CSV zetten → Type: Spreadsheet, Datum: 2020-08-02
#
# ---
# 🔍 Matching document: VWS-WOO-06-543766.pdf
#   ✅ MATCH GEVONDEN! Updaten document 543766
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-17
#
# ---
# 🔍 Matching document: VWS-WOO-06-541135.pdf
#   ✅ MATCH GEVONDEN! Updaten document 541135
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-10-09
#
# ---
# 🔍 Matching document: VWS-WOO-06-546243.pdf
#   ✅ MATCH GEVONDEN! Updaten document 546243
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-16
#
# ---
# 🔍 Matching document: VWS-WOO-06-572438.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-540068.pdf
#   ✅ MATCH GEVONDEN! Updaten document 540068
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-31
#
# ---
# 🔍 Matching document: VWS-WOO-06-541884.pdf
#   ✅ MATCH GEVONDEN! Updaten document 541884
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-01
#
# ---
# 🔍 Matching document: VWS-WOO-06-533452.pdf
#   ✅ MATCH GEVONDEN! Updaten document 533452
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-13
#
# ---
# 🔍 Matching document: VWS-WOO-06-569813.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-567812.pdf
#   ✅ MATCH GEVONDEN! Updaten document 567812
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-06
#
# ---
# 🔍 Matching document: VWS-WOO-06-568856.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-559486.pdf
#   ✅ MATCH GEVONDEN! Updaten document 559486
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-25
#
# ---
# 🔍 Matching document: VWS-WOO-06-543872.pdf
#   ✅ MATCH GEVONDEN! Updaten document 543872
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-19
#
# ---
# 🔍 Matching document: VWS-WOO-06-540047.pdf
#   ✅ MATCH GEVONDEN! Updaten document 540047
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-19
#
# ---
# 🔍 Matching document: VWS-WOO-06-543474.pdf
#   ✅ MATCH GEVONDEN! Updaten document 543474
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-28
#
# ---
# 🔍 Matching document: VWS-WOO-06-564514.pdf
#   ✅ MATCH GEVONDEN! Updaten document 564514
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-18
#
# ---
# 🔍 Matching document: VWS-WOO-06-561290.pdf
#   ✅ MATCH GEVONDEN! Updaten document 561290
#   📌 In CSV zetten → Type: PDF, Datum: 2020-08-03
#
# ---
# 🔍 Matching document: VWS-WOO-06-546436.pdf
#   ✅ MATCH GEVONDEN! Updaten document 546436
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-13
#
# ---
# 🔍 Matching document: VWS-WOO-06-551314.pdf
#   ✅ MATCH GEVONDEN! Updaten document 551314
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-05
#
# ---
# 🔍 Matching document: VWS-WOO-06-550515.pdf
#   ✅ MATCH GEVONDEN! Updaten document 550515
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-06
#
# ---
# 🔍 Matching document: VWS-WOO-06-537849.pdf
#   ✅ MATCH GEVONDEN! Updaten document 537849
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-28
#
# ---
# 🔍 Matching document: VWS-WOO-06-541728.pdf
#   ✅ MATCH GEVONDEN! Updaten document 541728
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-17
#
# ---
# 🔍 Matching document: VWS-WOO-06-551137.pdf
#   ✅ MATCH GEVONDEN! Updaten document 551137
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-24
#
# ---
# 🔍 Matching document: VWS-WOO-06-558250.pdf
#   ✅ MATCH GEVONDEN! Updaten document 558250
#   📌 In CSV zetten → Type: PDF, Datum: 2020-08-05
#
# ---
# 🔍 Matching document: VWS-WOO-06-541419.pdf
#   ✅ MATCH GEVONDEN! Updaten document 541419
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-13
#
# ---
# 🔍 Matching document: VWS-WOO-06-570592.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-557841.pdf
#   ✅ MATCH GEVONDEN! Updaten document 557841
#   📌 In CSV zetten → Type: PDF, Datum: 2020-08-27
#
# ---
# 🔍 Matching document: VWS-WOO-06-551150.pdf
#   ✅ MATCH GEVONDEN! Updaten document 551150
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-06
#
# ---
# 🔍 Matching document: VWS-WOO-06-551374.pdf
#   ✅ MATCH GEVONDEN! Updaten document 551374
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-20
#
# ---
# 🔍 Matching document: VWS-WOO-06-536125.pdf
#   ✅ MATCH GEVONDEN! Updaten document 536125
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-19
#
# ---
# 🔍 Matching document: VWS-WOO-06-540735.pdf
#   ✅ MATCH GEVONDEN! Updaten document 540735
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-13
#
# ---
# 🔍 Matching document: VWS-WOO-06-563578.pdf
#   ✅ MATCH GEVONDEN! Updaten document 563578
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-03
#
# ---
# 🔍 Matching document: VWS-WOO-06-565022.pdf
#   ✅ MATCH GEVONDEN! Updaten document 565022
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-05
#
# ---
# 🔍 Matching document: VWS-WOO-06-567199.pdf
#   ✅ MATCH GEVONDEN! Updaten document 567199
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-11
#
# ---
# 🔍 Matching document: VWS-WOO-06-551845.pdf
#   ✅ MATCH GEVONDEN! Updaten document 551845
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-19
#
# ---
# 🔍 Matching document: VWS-WOO-06-572587.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-547657.pdf
#   ✅ MATCH GEVONDEN! Updaten document 547657
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-04
#
# ---
# 🔍 Matching document: VWS-WOO-06-547757.pdf
#   ✅ MATCH GEVONDEN! Updaten document 547757
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-05
#
# ---
# 🔍 Matching document: VWS-WOO-06-568092.pdf
#   ✅ MATCH GEVONDEN! Updaten document 568092
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-14
#
# ---
# 🔍 Matching document: VWS-WOO-06-542379.pdf
#   ✅ MATCH GEVONDEN! Updaten document 542379
#   📌 In CSV zetten → Type: PDF, Datum: 2020-07-22
#
# ---
# 🔍 Matching document: VWS-WOO-06-574476.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-557344.pdf
#   ✅ MATCH GEVONDEN! Updaten document 557344
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-11
#
# ---
# 🔍 Matching document: VWS-WOO-06-554523.pdf
#   ✅ MATCH GEVONDEN! Updaten document 554523
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-28
#
# ---
# 🔍 Matching document: VWS-WOO-06-539720.pdf
#   ✅ MATCH GEVONDEN! Updaten document 539720
#   📌 In CSV zetten → Type: PDF, Datum: 2020-10-09
#
# ---
# 🔍 Matching document: VWS-WOO-06-538264.pdf
#   ✅ MATCH GEVONDEN! Updaten document 538264
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-12
#
# ---
# 🔍 Matching document: VWS-WOO-06-544354.pdf
#   ✅ MATCH GEVONDEN! Updaten document 544354
#   📌 In CSV zetten → Type: PDF, Datum: 2020-08-07
#
# ---
# 🔍 Matching document: VWS-WOO-06-554530.pdf
#   ✅ MATCH GEVONDEN! Updaten document 554530
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-27
#
# ---
# 🔍 Matching document: VWS-WOO-06-542752.pdf
#   ✅ MATCH GEVONDEN! Updaten document 542752
#   📌 In CSV zetten → Type: PDF, Datum: 2020-10-09
#
# ---
# 🔍 Matching document: VWS-WOO-06-530596.pdf
#   ✅ MATCH GEVONDEN! Updaten document 530596
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-20
#
# ---
# 🔍 Matching document: VWS-WOO-06-586721.pdf
#   ✅ MATCH GEVONDEN! Updaten document 586721
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-03
#
# ---
# 🔍 Matching document: VWS-WOO-06-554160.pdf
#   ✅ MATCH GEVONDEN! Updaten document 554160
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-26
#
# ---
# 🔍 Matching document: VWS-WOO-06-548329.pdf
#   ✅ MATCH GEVONDEN! Updaten document 548329
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-21
#
# ---
# 🔍 Matching document: VWS-WOO-06-536831.pdf
#   ✅ MATCH GEVONDEN! Updaten document 536831
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-09-03
#
# ---
# 🔍 Matching document: VWS-WOO-06-536982.pdf
#   ✅ MATCH GEVONDEN! Updaten document 536982
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-13
#
# ---
# 🔍 Matching document: VWS-WOO-06-570523.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-538945.pdf
#   ✅ MATCH GEVONDEN! Updaten document 538945
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-13
#
# ---
# 🔍 Matching document: VWS-WOO-06-539425.pdf
#   ✅ MATCH GEVONDEN! Updaten document 539425
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-09-02
#
# ---
# 🔍 Matching document: VWS-WOO-06-540004.pdf
#   ✅ MATCH GEVONDEN! Updaten document 540004
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-09-03
#
# ---
# 🔍 Matching document: VWS-WOO-06-571597.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-549523.pdf
#   ✅ MATCH GEVONDEN! Updaten document 549523
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-04
#
# ---
# 🔍 Matching document: VWS-WOO-06-557084.pdf
#   ✅ MATCH GEVONDEN! Updaten document 557084
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-05
#
# ---
# 🔍 Matching document: VWS-WOO-06-531264.pdf
#   ✅ MATCH GEVONDEN! Updaten document 531264
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-11
#
# ---
# 🔍 Matching document: VWS-WOO-06-540691.pdf
#   ✅ MATCH GEVONDEN! Updaten document 540691
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-10
#
# ---
# 🔍 Matching document: VWS-WOO-06-561274.pdf
#   ✅ MATCH GEVONDEN! Updaten document 561274
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-04
#
# ---
# 🔍 Matching document: VWS-WOO-06-551980.pdf
#   ✅ MATCH GEVONDEN! Updaten document 551980
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-14
#
# ---
# 🔍 Matching document: VWS-WOO-06-572232.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-566027.pdf
#   ✅ MATCH GEVONDEN! Updaten document 566027
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-14
#
# ---
# 🔍 Matching document: VWS-WOO-06-541858.pdf
#   ✅ MATCH GEVONDEN! Updaten document 541858
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-13
#
# ---
# 🔍 Matching document: VWS-WOO-06-575829.pdf
#   ✅ MATCH GEVONDEN! Updaten document 575829
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-25
#
# ---
# 🔍 Matching document: VWS-WOO-06-541660.pdf
#   ✅ MATCH GEVONDEN! Updaten document 541660
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-26
#
# ---
# 🔍 Matching document: VWS-WOO-06-534763.pdf
#   ✅ MATCH GEVONDEN! Updaten document 534763
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-26
#
# ---
# 🔍 Matching document: VWS-WOO-06-551274.pdf
#   ✅ MATCH GEVONDEN! Updaten document 551274
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-11
#
# ---
# 🔍 Matching document: VWS-WOO-06-533133.pdf
#   ✅ MATCH GEVONDEN! Updaten document 533133
#   📌 In CSV zetten → Type: PDF, Datum: 2020-08-20
#
# ---
# 🔍 Matching document: VWS-WOO-06-566534.pdf
#   ✅ MATCH GEVONDEN! Updaten document 566534
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-05
#
# ---
# 🔍 Matching document: VWS-WOO-06-562058.pdf
#   ✅ MATCH GEVONDEN! Updaten document 562058
#   📌 In CSV zetten → Type: Spreadsheet, Datum: 2020-08-19
#
# ---
# 🔍 Matching document: VWS-WOO-06-586648.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-562179.pdf
#   ✅ MATCH GEVONDEN! Updaten document 562179
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-24
#
# ---
# 🔍 Matching document: VWS-WOO-06-551392.pdf
#   ✅ MATCH GEVONDEN! Updaten document 551392
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-06
#
# ---
# 🔍 Matching document: VWS-WOO-06-541446.pdf
#   ✅ MATCH GEVONDEN! Updaten document 541446
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-30
#
# ---
# 🔍 Matching document: VWS-WOO-06-572387.pdf
#
# ---
# 🔍 Matching document: VWS-WOO-06-563060.pdf
#   ✅ MATCH GEVONDEN! Updaten document 563060
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-12-23
#
# ---
# 🔍 Matching document: VWS-WOO-06-556978.pdf
#   ✅ MATCH GEVONDEN! Updaten document 556978
#   📌 In CSV zetten → Type: Word-document, Datum: 2020-08-21
#
# ---
# 🔍 Matching document: VWS-WOO-06-553016.pdf
#   ✅ MATCH GEVONDEN! Updaten document 553016
#   📌 In CSV zetten → Type: E-mailbericht, Datum: 2020-08-18
# Scraping en verrijking voltooid voor dossier 131!
# https://open.minvws.nl/dossier/VWS-WOO/3276778-1019108-wjz
