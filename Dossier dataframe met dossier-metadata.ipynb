# %%
import os
import json
import zipfile
import pandas as pd
from IPython.display import display
import shutil

# Pad naar de map met ZIP-bestanden en waar alles uitgepakt wordt
input_folder = "/home/nena-meijer/PyCharmMiscProject/VWS_dossiers_zip"
output_folder = "/home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles"

# Maximale bestandsnaam lengte (inclusief extensie)
MAX_FILENAME_LENGTH = 100

# Kies hier het ZIP-bestand dat je wilt testen (pas de naam aan)
test_zip_filename = "Beslissing op bezwaar Wob-besluit coronamaatregelen.zip"  # Zet hier de naam van het ZIP-bestand dat je wilt testen
zip_path = os.path.join(input_folder, test_zip_filename)

# Dossier-ID starten bij 1
dossier_id = 1
extract_path = os.path.join(output_folder, f"dossier_{dossier_id}")

# Zorg dat de map bestaat
os.makedirs(extract_path, exist_ok=True)

# Data opslag
data = []

# ZIP-bestand openen en verwerken
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    for zip_info in zip_ref.infolist():
        if zip_info.is_dir():
            continue  # Skip directories

        # Bepaal originele bestandsnaam en extensie
        original_name = os.path.basename(zip_info.filename)
        file_ext = os.path.splitext(original_name)[1].lower()

        # Beperk de naam tot MAX_FILENAME_LENGTH, behoud de extensie
        base_name = os.path.splitext(original_name)[0]
        if len(base_name) > MAX_FILENAME_LENGTH:
            base_name = base_name[:MAX_FILENAME_LENGTH]
        safe_filename = f"{base_name}{file_ext}"

        # Opslaan op veilige locatie
        safe_path = os.path.join(extract_path, safe_filename)

        # Bestand veilig extraheren
        with zip_ref.open(zip_info) as source, open(safe_path, "wb") as target:
            shutil.copyfileobj(source, target)

# Metadata.json uitlezen (als die bestaat)
metadata_path = os.path.join(extract_path, "metadata.json")
published_date, decision_date = None, None
dossier_name = None
if os.path.exists(metadata_path):
    with open(metadata_path, "r", encoding="utf-8") as f:
        metadata = json.load(f)
        dossier_name = metadata.get("title")
        published_date = metadata.get("published_date")
        decision_date = metadata.get("decision_date")

# Bestandsteller starten
file_counter = 1

# Loop door alle uitgepakte bestanden
for file in os.listdir(extract_path):
    if file == "metadata.json":  # Metadata.json zelf negeren
        continue

    file_path = os.path.join(extract_path, file)
    file_ext = os.path.splitext(file)[1].lower()

    # Genereer file_id (bijv. 1-1, 1-2, etc.)
    file_id = f"{dossier_id}-{file_counter}"
    file_counter += 1  # Verhoog teller

    # Opslaan in lijst
    data.append({
        "dossier_id": dossier_id,
        "dossier_name": dossier_name,
        "file_id": file_id,
        "file_name": file,
        "file_type": file_ext,
        "dossier_published_date": published_date,
        "dossier_decision_date": decision_date
    })

# DataFrame maken en weergeven
df = pd.DataFrame(data)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)
display(df)

# %%
import os
import json
import zipfile
import pandas as pd
from IPython.display import display
import shutil

# Pad naar de map met ZIP-bestanden en waar alles uitgepakt wordt
input_folder = "/home/nena-meijer/PyCharmMiscProject/VWS_dossiers_zip"
output_folder = "/home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles"

# Maximale bestandsnaam lengte (inclusief extensie)
MAX_FILENAME_LENGTH = 100

# Data opslag
data = []

# Zoek alle ZIP-bestanden in de input folder
zip_files = sorted([f for f in os.listdir(input_folder) if f.endswith(".zip")])

# Loop door alle ZIP-bestanden en verwerk ze
for dossier_id, zip_filename in enumerate(zip_files, start=1):
    zip_path = os.path.join(input_folder, zip_filename)
    extract_path = os.path.join(output_folder, f"dossier_{dossier_id}")

    # Zorg dat de map bestaat
    os.makedirs(extract_path, exist_ok=True)

    # ZIP-bestand openen en verwerken
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        for zip_info in zip_ref.infolist():
            if zip_info.is_dir():
                continue  # Skip directories

            # Bepaal originele bestandsnaam en extensie
            original_name = os.path.basename(zip_info.filename)
            file_ext = os.path.splitext(original_name)[1].lower()

            # Beperk de naam tot MAX_FILENAME_LENGTH, behoud de extensie
            base_name = os.path.splitext(original_name)[0]
            if len(base_name) > MAX_FILENAME_LENGTH:
                base_name = base_name[:MAX_FILENAME_LENGTH]
            safe_filename = f"{base_name}{file_ext}"

            # Opslaan op veilige locatie
            safe_path = os.path.join(extract_path, safe_filename)

            # Bestand veilig extraheren
            with zip_ref.open(zip_info) as source, open(safe_path, "wb") as target:
                shutil.copyfileobj(source, target)

    # Metadata.json uitlezen (als die bestaat)
    metadata_path = os.path.join(extract_path, "metadata.json")
    published_date, decision_date, dossier_name = None, None, None
    if os.path.exists(metadata_path):
        with open(metadata_path, "r", encoding="utf-8") as f:
            metadata = json.load(f)
            dossier_name = metadata.get("title")
            published_date = metadata.get("published_date")
            decision_date = metadata.get("decision_date")

    # Datumconversie naar datetime-formaat (indien beschikbaar)
    published_date = pd.to_datetime(published_date, errors='coerce')
    decision_date = pd.to_datetime(decision_date, errors='coerce')

    # Bestandsteller starten
    file_counter = 1

    # Loop door alle uitgepakte bestanden
    for file in os.listdir(extract_path):
        if file == "metadata.json":  # Metadata.json zelf negeren
            continue

        file_path = os.path.join(extract_path, file)
        file_ext = os.path.splitext(file)[1].lower()

        # Genereer file_id (bijv. 1-1, 1-2, etc.)
        file_id = f"{dossier_id}-{file_counter}"
        file_counter += 1  # Verhoog teller

        # Opslaan in lijst
        data.append({
            "dossier_id": dossier_id,
            "dossier_name": dossier_name,
            "file_id": file_id,
            "file_name": file,
            "file_source": file_path,
            "file_type": file_ext,
            "dossier_published_date": published_date,
            "dossier_decision_date": decision_date
        })

# DataFrame maken en weergeven
df = pd.DataFrame(data)

# Instellingen voor brede tabellen en volledige tekstweergave
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)

# DataFrame weergeven
display(df)

# %%
df.to_csv("df.csv", index=False)

# %%
import pandas as pd
from IPython.display import display

# CSV inlezen
df = pd.read_csv("df.csv")

# Filter alleen relevante kolommen
df_filtered = df[["dossier_id", "dossier_name", "file_name", "dossier_published_date", "dossier_decision_date"]]

# Verwijder metadata.json en groepeer per dossier_id
df_aggregated = (
    df_filtered[df_filtered["file_name"] != "metadata.json"]
    .groupby(["dossier_id", "dossier_name", "dossier_published_date", "dossier_decision_date"])
    .agg(document_count=("file_name", "count"))  # Tel documenten per dossier
    .reset_index()
)

# Instellingen om lange tekst volledig te tonen
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)

# DataFrame weergeven in Jupyter Notebook
display(df_aggregated)

# Opslaan als CSV
df_aggregated.to_csv("df_dossiers.csv", index=False)

print("✅ Geaggregeerde CSV opgeslagen als 'df_dossiers.csv'")
# Out:
#      dossier_id                                                                                                                   dossier_name dossier_published_date dossier_decision_date  document_count
# 0             1                                                                   (4e deel) Besluit Woo-verzoek Covid-19 aanpak DOC-19 Q4 2020             2024-02-05            2023-07-29             229
# 1             2                                                                          Woo-besluit aangaande kaders werkproces Wob-verzoeken             2024-03-22            2023-03-20              83
# 2             3                                                                        1e deel Besluit Woo verzoek Covid-19 aanpak ACC Q4 2020             2024-02-07            2022-08-18             208
# 3             4                                                                        2e deel Besluit Woo verzoek Covid-19 aanpak ACC Q1 2021             2024-02-08            2023-02-17             239
# 4             5                                                              3e deel Besluit Woo verzoek Covid-19 aanpak ACC-19 April-Mei 2021             2024-02-07            2022-05-12             144
# ..          ...                                                                                                                            ...                    ...                   ...             ...
# 215         216                                                                       Woo-deelbesluit aangaande overeenkomsten PCR-laboratoria             2024-06-06            2024-03-27              68
# 216         217                                                                 Woo-deelbesluit aangaande vaccinatie aansprakelijkheid Deel II             2024-10-09            2024-10-02             116
# 217         218                                                          Woo-deelbesluit aangaande ‘Capaciteit van ziekenhuizen IC-capaciteit'             2024-10-19            2024-09-12             199
# 218         219  Woo-deelbesluit aangaande ‘de inkoop van persoonlijke beschermingsmiddelen tijdens de coronacrisis en het onderzoek daarnaar’             2024-04-05            2024-02-14            2695
# 219         220                                                         Woo-verzoek d.d. 6 januari 2022 inzake het Europees Herstelfonds (LNV)             2024-02-05            2022-05-12               9
#
# [220 rows x 5 columns]
# ✅ Geaggregeerde CSV opgeslagen als 'df_dossiers.csv'

# %%
import pandas as pd
from IPython.display import display

# CSV inlezen
df = pd.read_csv("df.csv")

# Verwijder spaties in kolomnamen (indien nodig)
df.columns = df.columns.str.strip()

# Controleer of de verwachte kolommen aanwezig zijn
expected_columns = ["dossier_id", "file_name", "file_type"]
missing_columns = [col for col in expected_columns if col not in df.columns]

if missing_columns:
    print(f"❌ De volgende kolommen ontbreken in de CSV: {missing_columns}")
else:
    # Selecteer relevante kolommen en hernoem file_name naar document_title
    df_documents = df[["dossier_id", "file_name", "file_type"]].rename(
        columns={"file_name": "document_title", "file_type": "document_type"}
    )

    # Verwijder metadata.json
    df_documents = df_documents[df_documents["document_title"] != "metadata.json"]

    # Verwijder de punt uit document_type (extensie)
    df_documents["document_type"] = df_documents["document_type"].str.replace(".", "", regex=False)

    # Document-ID toevoegen (per dossier_id een oplopende teller)
    df_documents["document_id"] = (
        df_documents.groupby("dossier_id").cumcount() + 1  # Start teller bij 1 per dossier
    ).astype(str)

    # Combineer document_id met dossier_id
    df_documents["document_id"] = df_documents["dossier_id"].astype(str) + "-" + df_documents["document_id"]

    # Kolommen opnieuw ordenen
    df_documents = df_documents[["dossier_id", "document_id", "document_title", "document_type"]]

    # Opslaan als nieuwe CSV
    df_documents.to_csv("df_documents.csv", index=False)

    # DataFrame weergeven
    display(df_documents)
    print("✅ Geëxporteerd als 'df_documents.csv'")
# Out:
#         dossier_id document_id                                                                            document_title document_type
# 0                1         1-1                        VWS-WC-098-DOC201208J-Concept_Platte_tekst_herijkte_routekaart.pdf           pdf
# 1                1         1-2                         VWS-WC-098-201130D-Actiepuntenlijst_DOC-19_-_27_november_2020.pdf           pdf
# 2                1         1-3                  VWS-WC-098-201127F-Presentatie_verdiepingssessie_vaccinatiestrategie.pdf           pdf
# 3                1         1-4                   VWS-WC-098-201215F-Implementatie_gedragsinterventies_DGSC-19_en_RRT.pdf           pdf
# 4                1         1-5                                       VWS-WC-098-201006A-Agenda_DOC-19_6_oktober_2020.pdf           pdf
# ...            ...         ...                                                                                       ...           ...
# 109029         220       220-5                    VWS-WC-107-2a-2020_RV_0022_Masterplan_emissieloze_maritieme_sector.pdf           pdf
# 109030         220       220-6                      VWS-WC-107-1-FW_Masterplan_voor_een_emissieloze_maritieme_sector.pdf           pdf
# 109031         220       220-7                                        VWS-WC-107-4-video-overleg_Corona_herstelfonds.pdf           pdf
# 109032         220       220-8  VWS-WC-107-3-Vraag_om_informatie_over_RFF_in_relatie_tot_emissiearme_kotter_visserij.pdf           pdf
# 109033         220       220-9                 VWS-WC-107-6-RE_Reactie_gevraagd_op_fiche_emissieloze_kotter_voor_RRF.pdf           pdf
#
# [109034 rows x 4 columns]
# ✅ Geëxporteerd als 'df_documents.csv'

# %%
import time

def scrape_document_metadata(dossier_url):
    """Scrapet documentmetadata van alle pagina's binnen een dossier met een crawl delay."""

    # Extract dossier ID uit de URL
    dossier_id_match = re.search(r'/dossier/([^/]+)', dossier_url)
    dossier_id_str = dossier_id_match.group(1) if dossier_id_match else None

    metadata_list = []
    seen_documents = set()
    page = 1
    max_pages = 50  # Failsafe om te voorkomen dat hij oneindig blijft lopen

    while page <= max_pages:
        paged_url = f"{dossier_url}?prefix=VWS-WC&dossierId={dossier_id_str}&pu={page}#tabcontrol-1"
        response = requests.get(paged_url)
        if response.status_code != 200:
            print(f"Fout bij ophalen van {paged_url}")
            break

        soup = BeautifulSoup(response.text, "html.parser")
        table_rows = soup.select(".woo-table tbody tr")
        if not table_rows:
            print(f"Geen documenten gevonden op pagina {page}, stoppen met scrapen.")
            break

        new_documents_found = False

        for row in table_rows:
            try:
                # Document ID ophalen uit de eerste kolom
                doc_id_tag = row.select_one("td:nth-of-type(1)")
                doc_id = doc_id_tag.text.strip() if doc_id_tag else None

                # Document URL ophalen
                doc_link_tag = row.select_one("td:nth-of-type(3) a")
                doc_url = doc_link_tag["href"] if doc_link_tag else ""

                if not doc_id or doc_id in seen_documents:
                    continue

                seen_documents.add(doc_id)
                new_documents_found = True

                # Documenttype
                doc_type_tag = row.select_one("td:nth-of-type(2) use")
                doc_type_key = doc_type_tag["xlink:href"].split("#")[-1] if doc_type_tag else "unknown"
                doc_type = DOCUMENT_TYPE_MAP.get(doc_type_key, "Onbekend")

                # Documentdatum correct ophalen
                doc_date_tag = row.select_one("td:nth-of-type(4) time")
                doc_date = doc_date_tag["datetime"] if doc_date_tag else None

                metadata_list.append({
                    "document_id": doc_id,
                    "document_sourcetype": doc_type,
                    "document_date": doc_date,
                    "dossier_id": dossier_id
                })
            except Exception as e:
                print(f"Fout bij parsen: {e}")

        if not new_documents_found:
            print(f"Geen nieuwe documenten meer gevonden op pagina {page}, stoppen met scrapen.")
            break

        page += 1
        time.sleep(1)  # Crawl delay na elke pagina scrape

    for doc in metadata_list:
        print(doc)

    return metadata_list

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# Mapping van documenttypes
DOCUMENT_TYPE_MAP = {
    "unknown": "Onbekend",
    "pdf": "PDF",
    "email": "E-mailbericht",
    "presentation": "Presentatie",
    "doc": "Word-document",
    "chat": "Chatbericht",
    "image": "Afbeelding",
    "spreadsheet": "Spreadsheet"
}

# Inlezen van de bestaande documentgegevens
df_documents = pd.read_csv("df_documents_dates.csv", dtype={"document_id": str})
df_dossiers = pd.read_csv("df_dossiers_final.csv", dtype={"dossier_id": int})

# Handmatig dossier_id invoeren
dossier_id = 27
dossier = df_dossiers[df_dossiers["dossier_id"] == dossier_id].iloc[0]
dossier_url = dossier["dossier_sourceURL"]

print(f"Scrapen: {dossier_url}")
document_metadata = scrape_document_metadata(dossier_url)

# Omzetten naar dataframe
df_metadata = pd.DataFrame(document_metadata)

def extract_prefix(document_title):
    """Probeert het juiste dossierprefix te extraheren uit de document_title."""

    # Specifieke uitzondering: als het document begint met "VWS-WC-19.00-1-", dan is de prefix gewoon "VWS-WC"
    # if document_title.startswith("VWS-WC-19.00-1-"):
    #     return "VWS-WC-19.00-1-"

    # Standaardpatronen voor prefixes
    match = re.match(r"^(VWS-WC-\d{3}|VWS-WOO-[A-Za-z0-9]+|VWS-WC)", document_title)
    return match.group(1) if match else None

def match_documents(df_documents, df_metadata, dossier_id):
    """Matcht gescrapete metadata met documenten op basis van dossierprefix en document_id."""
    df_documents_dossier = df_documents[df_documents["dossier_id"] == dossier_id]

    if df_documents_dossier.empty:
        print(f"⚠️ Geen documenten gevonden voor dossier_id {dossier_id}")
        return df_documents

    # Zoek het eerste document dat GEEN generieke naam heeft
    sample_document_title = None
    for title in df_documents_dossier["document_title"]:
        if not title.lower().startswith("besluitbrief"):  # Voeg andere generieke namen toe indien nodig
            sample_document_title = title
            break

    if not sample_document_title:
        print(f"❌ Geen geldig document gevonden om een prefix uit te halen voor dossier {dossier_id}.")
        return df_documents

    dossier_prefix = extract_prefix(sample_document_title)

    if not dossier_prefix:
        print(f"❌ Geen geldig dossierprefix gevonden in: {sample_document_title}")
        return df_documents

    print(f"🔎 Dossierprefix bepaald als: {dossier_prefix}")

    for i, doc_row in df_documents_dossier.iterrows():
        document_title = doc_row["document_title"]
        print(f"\n---\n🔍 Matching document: {document_title}")

        for _, meta_row in df_metadata.iterrows():
            meta_doc_id = str(meta_row["document_id"]).strip()  # Zorgt dat het ID een string is
            expected_identifier = f"{dossier_prefix}-{meta_doc_id}"  # Verwachte match

            # Exacte match met regex
            if re.search(rf"\b{re.escape(expected_identifier)}\b", document_title):
                print(f"  ✅ MATCH GEVONDEN! Updaten document {meta_doc_id}")

                df_documents.at[i, "document_sourcetype"] = meta_row["document_sourcetype"]
                df_documents.at[i, "document_date"] = meta_row["document_date"]

                # Print de waarde die in de CSV wordt gezet
                print(f"  📌 In CSV zetten → Type: {meta_row['document_sourcetype']}, Datum: {meta_row['document_date']}")
                break  # Stop met zoeken zodra de match is gevonden

    return df_documents

df_documents = match_documents(df_documents, df_metadata, dossier_id)

# Opslaan van de verrijkte dataset
df_documents.to_csv("df_documents_dates.csv", index=False)
print(f"Scraping en verrijking voltooid voor dossier {dossier_id}!")
print(dossier_url)
# Out:
# Scrapen: https://open.minvws.nl/dossier/VWS-WC/036
# Geen nieuwe documenten meer gevonden op pagina 2, stoppen met scrapen.
# {'document_id': 'Openbaarmaking', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 27}
# {'document_id': 'Wob-besluit', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 27}
# {'document_id': 'besluit (3).pdf (PDF, 2.22 MB)', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 27}
# {'document_id': 'ministerie van Financiën', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 27}
# {'document_id': 'Februari - juni 2020', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 27}
# {'document_id': '9 februari 2021', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 27}
# {'document_id': "117 documenten,                        \n                                                    182 pagina's\n                            \n                                                \nInventarislijst", 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 27}
# {'document_id': 'Scenario’s en maatregelen', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 27}
# {'document_id': '800568', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-04', 'dossier_id': 27}
# {'document_id': '800529', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-05', 'dossier_id': 27}
# {'document_id': '800533', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-05', 'dossier_id': 27}
# {'document_id': '800535', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-05', 'dossier_id': 27}
# {'document_id': '800537', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-06', 'dossier_id': 27}
# {'document_id': '800543', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-09', 'dossier_id': 27}
# {'document_id': '800557', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-09', 'dossier_id': 27}
# {'document_id': '800542', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-12', 'dossier_id': 27}
# {'document_id': '851334', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-13', 'dossier_id': 27}
# {'document_id': '851341', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-13', 'dossier_id': 27}
# {'document_id': '851328', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-15', 'dossier_id': 27}
# {'document_id': '851339', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-15', 'dossier_id': 27}
# {'document_id': '851337', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-15', 'dossier_id': 27}
# {'document_id': '851344', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-15', 'dossier_id': 27}
# {'document_id': '851345', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-15', 'dossier_id': 27}
# {'document_id': '851338', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800540', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800545', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800546', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800547', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800548', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800549', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800558', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800554', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800575', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800573', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800572', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-17', 'dossier_id': 27}
# {'document_id': '800559', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-17', 'dossier_id': 27}
# {'document_id': '800556', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-17', 'dossier_id': 27}
# {'document_id': '800565', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-17', 'dossier_id': 27}
# {'document_id': '800566', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-17', 'dossier_id': 27}
# {'document_id': '800567', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-17', 'dossier_id': 27}
# {'document_id': '800786', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-19', 'dossier_id': 27}
# {'document_id': '800790', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-20', 'dossier_id': 27}
# {'document_id': '800743', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-20', 'dossier_id': 27}
# {'document_id': '800744', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-22', 'dossier_id': 27}
# {'document_id': '800745', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-22', 'dossier_id': 27}
# {'document_id': '800740', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-22', 'dossier_id': 27}
# {'document_id': '800784', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-22', 'dossier_id': 27}
# {'document_id': '800785', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-22', 'dossier_id': 27}
# {'document_id': '800735', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-23', 'dossier_id': 27}
# {'document_id': '800737', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-23', 'dossier_id': 27}
# {'document_id': '800738', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-23', 'dossier_id': 27}
# {'document_id': '800792', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-23', 'dossier_id': 27}
# {'document_id': '800802', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '800803', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '800804', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '800787', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '800788', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '800782', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '800783', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '800794', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-25', 'dossier_id': 27}
# {'document_id': '807638', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-30', 'dossier_id': 27}
# {'document_id': '807642', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-30', 'dossier_id': 27}
# {'document_id': '807654', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-30', 'dossier_id': 27}
# {'document_id': '800887', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-01', 'dossier_id': 27}
# {'document_id': '800899', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 27}
# {'document_id': '842911', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 27}
# {'document_id': '800541', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-12', 'dossier_id': 27}
# {'document_id': '800538', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-17', 'dossier_id': 27}
# {'document_id': '800530', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-21', 'dossier_id': 27}
# {'document_id': '800539', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800553', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800570', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '800571', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-16', 'dossier_id': 27}
# {'document_id': '802363594050343', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-10', 'dossier_id': 27}
# {'document_id': '802244433977748', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-11', 'dossier_id': 27}
# {'document_id': '800560', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-19', 'dossier_id': 27}
# {'document_id': '800561', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-19', 'dossier_id': 27}
# {'document_id': '800742', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-20', 'dossier_id': 27}
# {'document_id': '800896', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-03', 'dossier_id': 27}
# {'document_id': '800886', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-03', 'dossier_id': 27}
# {'document_id': '800895', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-04', 'dossier_id': 27}
# {'document_id': '800894', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-09', 'dossier_id': 27}
# {'document_id': '800902', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-15', 'dossier_id': 27}
# {'document_id': '800892', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-15', 'dossier_id': 27}
# {'document_id': '800893', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-15', 'dossier_id': 27}
# {'document_id': '800891', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-10', 'dossier_id': 27}
# {'document_id': '800888', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-15', 'dossier_id': 27}
# {'document_id': '800536', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-27', 'dossier_id': 27}
# {'document_id': '800532', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-27', 'dossier_id': 27}
# {'document_id': '808073', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-27', 'dossier_id': 27}
# {'document_id': '800531', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-02', 'dossier_id': 27}
# {'document_id': '800564', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-02', 'dossier_id': 27}
# {'document_id': '851333', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-04', 'dossier_id': 27}
# {'document_id': '800544', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-10', 'dossier_id': 27}
# {'document_id': '800552', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-11', 'dossier_id': 27}
# {'document_id': '800555', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-06', 'dossier_id': 27}
# {'document_id': '800574', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-06', 'dossier_id': 27}
# {'document_id': '851335', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-10', 'dossier_id': 27}
# {'document_id': '851342', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-12', 'dossier_id': 27}
# {'document_id': '851347', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-12', 'dossier_id': 27}
# {'document_id': '851336', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-13', 'dossier_id': 27}
# {'document_id': '851332', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-13', 'dossier_id': 27}
# {'document_id': '800796', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-23', 'dossier_id': 27}
# {'document_id': '800797', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-23', 'dossier_id': 27}
# {'document_id': '800741', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-23', 'dossier_id': 27}
# {'document_id': '800806', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-23', 'dossier_id': 27}
# {'document_id': '800801', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '800795', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '800562', 'document_sourcetype': 'Onbekend', 'document_date': '2020-02-26', 'dossier_id': 27}
# {'document_id': '800534', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-05', 'dossier_id': 27}
# {'document_id': '800563', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-06', 'dossier_id': 27}
# {'document_id': '851331', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-13', 'dossier_id': 27}
# {'document_id': '851346', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-15', 'dossier_id': 27}
# {'document_id': '800739', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-22', 'dossier_id': 27}
# {'document_id': '800791', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-23', 'dossier_id': 27}
# {'document_id': '800798', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '800789', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-24', 'dossier_id': 27}
# {'document_id': '807639', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-30', 'dossier_id': 27}
# {'document_id': '807656', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-30', 'dossier_id': 27}
# {'document_id': '851330', 'document_sourcetype': 'Onbekend', 'document_date': '2020-03-31', 'dossier_id': 27}
# {'document_id': '800898', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 27}
# {'document_id': '842910', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-02', 'dossier_id': 27}
# {'document_id': '800897', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-07', 'dossier_id': 27}
# {'document_id': '800900', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-10', 'dossier_id': 27}
# {'document_id': '800901', 'document_sourcetype': 'Onbekend', 'document_date': '2020-04-15', 'dossier_id': 27}
# {'document_id': '7 februari 2024 22:27', 'document_sourcetype': 'Onbekend', 'document_date': None, 'dossier_id': 27}
# 🔎 Dossierprefix bepaald als: VWS-WC-036
#
# ---
# 🔍 Matching document: VWS-WC-036-800738-4.1._DB_General_Escape_Clause.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800738
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-23
#
# ---
# 🔍 Matching document: VWS-WC-036-800543-A.3._Overzicht_verkiezingen_EU_lidstaten.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800543
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-09
#
# ---
# 🔍 Matching document: VWS-WC-036-807642-_t.b.v._BWO_1030-1130__voorbereiding_t.b.v._EU_Corona_discussie.pdf
#   ✅ MATCH GEVONDEN! Updaten document 807642
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-30
#
# ---
# 🔍 Matching document: VWS-WC-036-851345-11_Factsheet_flexibiliteit_SGP.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 851345
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-15
#
# ---
# 🔍 Matching document: VWS-WC-036-800787-2._DB_europese_WW.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800787
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-24
#
# ---
# 🔍 Matching document: VWS-WC-036-800899-Notitie_-_Geannoteerde_agenda_Eurogroep_7_april_2020.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800899
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-04-02
#
# ---
# 🔍 Matching document: VWS-WC-036-800792-8._AS_Appreciatie_update_voorstellen_---.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800792
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-23
#
# ---
# 🔍 Matching document: VWS-WC-036-800567-C.5._DB_Europees_Semester.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800567
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-17
#
# ---
# 🔍 Matching document: VWS-WC-036-800558-B.6._DB_ESM_verdrag.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800558
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-800786-3._AS_Tabel_Instrumentarium_ESM_EG_24_maart.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800786
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-19
#
# ---
# 🔍 Matching document: VWS-WC-036-800802-Notitie_-_Geannoteerde_agenda_Eurogroep_24_maart_2020.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800802
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-24
#
# ---
# 🔍 Matching document: VWS-WC-036-800535-0._Inhoud.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800535
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-05
#
# ---
# 🔍 Matching document: VWS-WC-036-851338-09_c__Appreciatie_FIN_---voorstellen_schoon.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 851338
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-851344-13_Overzicht__in_Engels_van_Cie__Nationale_economische_maatregelen_EU-lidstaten.do.pdf
#   ✅ MATCH GEVONDEN! Updaten document 851344
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-15
#
# ---
# 🔍 Matching document: VWS-WC-036-800568-Oplegnotitie_geannoteerde_agenda_en_CoCo-conclusies_Eurogroep_en_Ecofin_16_en_17_m.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800568
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-04
#
# ---
# 🔍 Matching document: VWS-WC-036-800557-A.2._Overzicht_EU_Ministers_van_Financi__n_en_EFC_leden__februari_2020_.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800557
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-09
#
# ---
# 🔍 Matching document: VWS-WC-036-800546-A.5._Communicatieplan.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800546
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-800784-5._AS_Factsheet_garantie-instrument_onder_artikel_VWEU_122_EG_24_maart.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800784
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-22
#
# ---
# 🔍 Matching document: VWS-WC-036-800554-B.7._CB_ESM_Backstop_-_IGA.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800554
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-800794-Brief_EK_-_Verslag_van_de_Ecofinraad_en_Eurogroep_van_23_en_24_maart_2020.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800794
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-25
#
# ---
# 🔍 Matching document: VWS-WC-036-800743-2._Ecofin-agenda_23_maart.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800743
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-20
#
# ---
# 🔍 Matching document: VWS-WC-036-800575-Notitie_-_Verslag_Eurogroep_16_maart_2020.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800575
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-800804-Notitie_-_Verslag_Ecofin_en_Eurogroep_23_en_24_maart_2020.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800804
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-24
#
# ---
# 🔍 Matching document: VWS-WC-036-800782-0._Cover_-_Dossier_Eurogroep_24_maart_2020.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800782
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-24
#
# ---
# 🔍 Matching document: VWS-WC-036-800744-Brief_TK_-_Geannoteerde_agenda_ingelaste_informele_Ecofinraad_23_maart_2020.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800744
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-22
#
# ---
# 🔍 Matching document: VWS-WC-036-800540-55622p.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800540
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-800549-B.4._DB_Updated_DBP_Oostenrijk.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800549
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-800785-4._AS_Factsheet_ECCL_procedures_EG_24_maart.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800785
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-22
#
# ---
# 🔍 Matching document: VWS-WC-036-800559-C.4.1._DB_Solvency-II.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800559
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-17
#
# ---
# 🔍 Matching document: VWS-WC-036-800573-CoCo-Conclusies_Eurogroep_en_Ecofinraad_16_en_17_maart_2020.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800573
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-800735-5._DB_Europees_Semester.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800735
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-23
#
# ---
# 🔍 Matching document: VWS-WC-036-851341-10_Appreciatie__feitelijk__Commissie-mededeling_COVID-19_m.b.t._EU-begroting.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 851341
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-13
#
# ---
# 🔍 Matching document: VWS-WC-036-800737-3._DB_Economische_impact_COVID-19_en_beleidsreactie.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800737
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-23
#
# ---
# 🔍 Matching document: VWS-WC-036-800533-45060a_min.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800533
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-05
#
# ---
# 🔍 Matching document: VWS-WC-036-800545-B.2._DB_International_meetings_-_Inflatie_en_Wisselkoers.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800545
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-800547-B.3.1._DB_Griekenland.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800547
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-807638-Bijlage_2_-_Coronafonds.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 807638
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-30
#
# ---
# 🔍 Matching document: besluitbrief.pdf
#
# ---
# 🔍 Matching document: VWS-WC-036-851328-01_Cover__inzet___spreeklijn__schoon.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 851328
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-15
#
# ---
# 🔍 Matching document: VWS-WC-036-800788-10._AS_Factsheet_vergelijking_structurele_uitdagingen_lidstaten_24-3.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800788
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-24
#
# ---
# 🔍 Matching document: VWS-WC-036-800887-64480a.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800887
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-04-01
#
# ---
# 🔍 Matching document: VWS-WC-036-842911-Bijlage_2_REA-notitie_Eurogroep.pdf
#   ✅ MATCH GEVONDEN! Updaten document 842911
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-04-02
#
# ---
# 🔍 Matching document: VWS-WC-036-851339-12_Overzicht__in_NL_van_FIN__Nationale_economische_maatregelen_EU-lidstaten.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 851339
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-15
#
# ---
# 🔍 Matching document: VWS-WC-036-800790-57704p.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800790
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-20
#
# ---
# 🔍 Matching document: VWS-WC-036-800572-C.6._DB_International_Meetings.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800572
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-17
#
# ---
# 🔍 Matching document: VWS-WC-036-800529-45060p_Stas.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800529
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-05
#
# ---
# 🔍 Matching document: VWS-WC-036-851337-09_b__---voorstel_mogelijke_ESM_instrumenten.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 851337
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-15
#
# ---
# 🔍 Matching document: VWS-WC-036-800745-Oplegnotitie_geannoteerde_agenda_informele_Ecofinraad_23_maart_2020.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800745
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-22
#
# ---
# 🔍 Matching document: VWS-WC-036-800565-C.7._DB_EDP_Roemenie.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800565
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-17
#
# ---
# 🔍 Matching document: VWS-WC-036-800542-A.1._Cover_Eurogroep_en_Ecofin_maart_2020.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800542
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-12
#
# ---
# 🔍 Matching document: VWS-WC-036-800566-C.2._Ecofin-ontbijt__EBRD_.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800566
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-17
#
# ---
# 🔍 Matching document: VWS-WC-036-800556-C.3.1._DB_CMU.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800556
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-17
#
# ---
# 🔍 Matching document: VWS-WC-036-800803-60155a.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800803
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-24
#
# ---
# 🔍 Matching document: VWS-WC-036-800537-1._Politieke_oplegger_AO_Eurogroep_en_Ecofinraad_12_maart.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800537
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-06
#
# ---
# 🔍 Matching document: VWS-WC-036-800548-A.4._Kerncijfers_EU__schuld__tekort__groei_.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800548
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-16
#
# ---
# 🔍 Matching document: VWS-WC-036-851334-05_Commissie-presentatie_economische_outlook.pdf
#   ✅ MATCH GEVONDEN! Updaten document 851334
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-13
#
# ---
# 🔍 Matching document: VWS-WC-036-800740-58408p.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800740
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-22
#
# ---
# 🔍 Matching document: VWS-WC-036-807654-BWO-notitie_EU_Corona_discussie.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 807654
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-30
#
# ---
# 🔍 Matching document: VWS-WC-036-800783-1._DB_EG_24_maart.docx.pdf
#   ✅ MATCH GEVONDEN! Updaten document 800783
#   📌 In CSV zetten → Type: Onbekend, Datum: 2020-03-24
# Scraping en verrijking voltooid voor dossier 27!
# https://open.minvws.nl/dossier/VWS-WC/036
