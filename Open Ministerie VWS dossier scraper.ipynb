# %% [markdown]
# # Scraper script OpenMinVWS dossiers
# Gebruikt Selenium om de dossier batch id te vinden en leidt naar de download pagina. BeutifulSoup download vervolgens het dossier.

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

# 🔹 **Selenium functie om batch-ID op te halen**
def find_batch_id(dossier_url):
    """
    Opent een dossierpagina, klikt op de downloadknop en retourneert de batch-URL.
    """
    chrome_driver_path = "/usr/local/bin/chromedriver"
    service = Service(chrome_driver_path)
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")  # Zet op False als je de browser wilt zien
    driver = webdriver.Chrome(service=service, options=options)

    try:
        driver.get(dossier_url)
        time.sleep(3)  # Wacht zodat JavaScript kan laden

        download_button = driver.find_element(By.XPATH, "//button[@data-e2e-name='download-documents-button']")
        download_button.click()
        time.sleep(3)  # Wacht tot de nieuwe pagina met batch-ID laadt

        batch_url = driver.current_url
        return batch_url + "/download"

    except Exception as e:
        print(f"❌ Fout bij vinden van batch-ID: {e}")
        return None
    finally:
        driver.quit()

# Voorbeeldgebruik:
# dossier_url = "https://open.minvws.nl/dossier/VWS-WOO/1841132-219465-wjz"
# batch_url = find_batch_id(dossier_url)
# print(f"✅ Batch-URL: {batch_url}")

# %%
# 🔹 **Download link voor besluitbrief**
def get_document_download_link(document_page_url):
    """
    Haalt de directe downloadlink van de besluitbrief op.
    """
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(document_page_url, headers=headers)
    if response.status_code != 200:
        print(f"❌ Kan de documentpagina niet bereiken: {response.status_code}")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    download_link_element = soup.find("a", {"data-e2e-name": "download-file-link"})
    return "https://open.minvws.nl" + download_link_element["href"] if download_link_element else None

# %%
import requests
from bs4 import BeautifulSoup

# 🔹 **Metadata en besluitbrief scraper**
def get_dossier_metadata_and_document(dossier_url):
    """
    Scraped metadata en de link naar de besluitbrief.
    """
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(dossier_url, headers=headers)
    if response.status_code != 200:
        print(f"❌ Kan de pagina niet bereiken: {response.status_code}")
        return None, None

    soup = BeautifulSoup(response.text, "html.parser")

    title_element = soup.find("h1", {"data-e2e-name": "dossier-metadata-title"})
    dossier_title = title_element.get_text(strip=True) if title_element else "Niet gevonden"
    if ":" in dossier_title:
        dossier_title = dossier_title.split(":", 1)[1].strip()

    published_date_element = soup.find("dd", {"data-e2e-name": "dossier-metadata-published-date"})
    published_date = published_date_element.find("time")["datetime"] if published_date_element else "Niet gevonden"

    decision_date_element = soup.find("td", {"data-e2e-name": "dossier-metadata-decision-date"})
    decision_date = decision_date_element.find("time")["datetime"] if decision_date_element else "Niet gevonden"

    document_link_element = soup.find("a", {"data-e2e-name": "main-document-detail-link"})
    document_page_url = "https://open.minvws.nl" + document_link_element["href"] if document_link_element else None

    return {"title": dossier_title, "published_date": published_date, "decision_date": decision_date}, document_page_url
    
# Voorbeeldgebruik
# dossier_url = "https://open.minvws.nl/dossier/VWS-WOO/1841132-219465-wjz"
# metadata = get_dossier_metadata(dossier_url)

# print("📂 Dossier Metadata:")
# print(f"🔹 Titel: {metadata['title']}")
# print(f"📅 Publicatiedatum: {metadata['published_date']}")
# print(f"📜 Beslissingsdatum: {metadata['decision_date']}")

# %%
import requests
import json
import zipfile
import os

# 🔹 **ZIP-bestand + besluitbrief downloaden**
def download_zip_and_document(dossier_url, save_path):
    """
    Zoek de ZIP-downloadlink met Selenium, download ZIP en besluitbrief en voeg metadata toe.
    """
    zip_url = find_batch_id(dossier_url)
    if not zip_url:
        print("❌ Geen batch-ID gevonden, ZIP wordt niet gedownload.")
        return

    metadata, document_page_url = get_dossier_metadata_and_document(dossier_url)
    if not metadata:
        print("⚠️ Geen metadata gevonden, ZIP wordt zonder metadata opgeslagen.")
        return

    zip_response = requests.get(zip_url, stream=True)
    if zip_response.status_code != 200:
        print(f"❌ Fout bij downloaden van ZIP: {zip_response.status_code}")
        return

    temp_zip_path = save_path + ".temp.zip"
    with open(temp_zip_path, "wb") as f:
        for chunk in zip_response.iter_content(1024):
            f.write(chunk)

    print(f"✅ ZIP gedownload: {temp_zip_path}")

    metadata_json = json.dumps(metadata, indent=4)
    safe_title = sanitize_filename(metadata['title'])
    final_zip_path = os.path.join(save_path, safe_title + ".zip")
    
    with zipfile.ZipFile(temp_zip_path, 'a') as zipf:
        zipf.writestr("metadata.json", metadata_json)

    if document_page_url:
        print(f"📄 Bezoek besluitbrief-pagina: {document_page_url}")
        document_download_url = get_document_download_link(document_page_url)

        if document_download_url:
            doc_response = requests.get(document_download_url, stream=True)
            if doc_response.status_code == 200:
                temp_doc_path = save_path + "_besluitbrief.pdf"
                with open(temp_doc_path, "wb") as f:
                    for chunk in doc_response.iter_content(1024):
                        f.write(chunk)

                print(f"✅ Besluitbrief gedownload: {temp_doc_path}")

                with zipfile.ZipFile(temp_zip_path, 'a') as zipf:
                    zipf.write(temp_doc_path, arcname="besluitbrief.pdf")

                os.remove(temp_doc_path)
                print(f"📂 Besluitbrief toegevoegd aan ZIP: {final_zip_path}")

    os.rename(temp_zip_path, final_zip_path)
    print(f"✅ ZIP compleet: {final_zip_path}")

    time.sleep(5)
    
    
# Voorbeeldgebruik:
# dossier_url = "https://open.minvws.nl/dossier/VWS-WOO/1841132-219465-wjz"
# save_path = f"/home/nena-meijer/PyCharmMiscProject/dossiers_zip/{metadata['title']}"

# download_zip_and_document(dossier_url, save_path)

# %%
def sanitize_filename(title, max_length=150):
    """
    Zorgt ervoor dat de bestandsnaam niet te lang wordt.
    """
    title = title.replace("/", "-")  # Vermijd ongeldige tekens
    return title[:max_length].strip()  # Knip af tot de max lengte

# %%
# Pad naar het bestand met de dossier-URLs
dossier_urls_path = "/home/nena-meijer/Downloads/dossier_urls.txt"
save_path = "/home/nena-meijer/PyCharmMiscProject/dossiers_zip/"

# Lees alle dossiers uit het bestand
with open(dossier_urls_path, "r") as f:
    dossier_urls = [line.strip() for line in f.readlines()][246:]
    
start_dossier_nummer = 246

for dossier_url in dossier_urls:
    print(f"Dossiernummer: {start_dossier_nummer}")
    print(f"📂 Start met downloaden van dossier: {dossier_url}")
    download_zip_and_document(dossier_url, save_path)
    print("✅ Download compleet. Start volgende...")
    start_dossier_nummer += 1

print("🎉 Alle dossiers zijn gedownload!")

# %%
# URL's matchen aan dossiers

import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from IPython.display import display

# CSV met bestaande dossiers inlezen
df = pd.read_csv("old_csvs/df_dossiers.csv")

# URLs inlezen uit dossier_urls.txt
with open("dossier_urls.txt", "r") as f:
    dossier_urls = [line.strip() for line in f.readlines()]

# Functie om de metadata titel van een dossierpagina op te halen
def get_dossier_metadata_title(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f"❌ Kan de pagina niet laden: {url} (Status: {response.status_code})")
        return None

    soup = BeautifulSoup(response.text, "html.parser")

    # Zoek de metadata titel van het dossier
    title_element = soup.find("h1", {"data-e2e-name": "dossier-metadata-title"})
    if title_element:
        title_text = title_element.get_text(strip=True).replace("Besluit over:", "").strip()
        return title_text
    return None

# Voeg een kolom voor de URL toe aan de DataFrame
df["dossier_sourceURL"] = None

# Loop door de URLs en zoek matches
for url in dossier_urls:
    dossier_title = get_dossier_metadata_title(url)

    if dossier_title:
        match_idx = df[df["dossier_name"] == dossier_title].index
        if not match_idx.empty:
            df.loc[match_idx, "dossier_sourceURL"] = url
            print(f"✅ Match gevonden: {dossier_title} → {url}")

    time.sleep(1)  # 🔹 Wacht 2 seconden om blokkering te voorkomen

# Opslaan als nieuwe CSV
df.to_csv("df_dossiers.csv", index=False)

# Weergeven in Jupyter Notebook
display(df)

print("✅ Dossier-URLs toegevoegd en opgeslagen als 'df_dossiers.csv'")

# %%
# summary en subject toevoegen aan dossiers
import requests
from bs4 import BeautifulSoup
import time

def scrape_dossier_metadata(dossier_url):
    """
    Haalt de samenvatting (dossier_summary) en het onderwerp (dossier_subject) op van een dossierpagina.

    Parameters:
    dossier_url (str): De URL van de dossierpagina.

    Returns:
    tuple: (dossier_summary, dossier_subject)
    """
    headers = {"User-Agent": "Mozilla/5.0"}

    try:
        # Haal de HTML-pagina op
        response = requests.get(dossier_url, headers=headers)
        if response.status_code != 200:
            print(f"❌ Kan {dossier_url} niet bereiken, status {response.status_code}")
            return None, None

        time.sleep(1)

        # Parse de HTML met BeautifulSoup
        soup = BeautifulSoup(response.text, "html.parser")

        # Scrape dossier_summary
        summary_element = soup.find("p", {"data-e2e-name": "dossier-summary"})
        dossier_summary = summary_element.get_text(strip=True) if summary_element else None

        # Scrape dossier_subject (eerste gevonden onderwerp)
        subject_element = soup.find("p").find("a", class_="woo-a") if soup.find("p") else None
        dossier_subject = subject_element.get_text(strip=True) if subject_element else None

        return dossier_summary, dossier_subject

    except Exception as e:
        print(f"⚠️ Fout bij verwerken van {dossier_url}: {e}")
        return None, None

# %%
import pandas as pd

# Laad df_dossiers.csv
df_dossiers = pd.read_csv("old_csvs/df_dossiers.csv")

# Voeg lege kolommen toe voor de nieuwe data (indien ze nog niet bestaan)
if "dossier_summary" not in df_dossiers.columns:
    df_dossiers["dossier_summary"] = None
if "dossier_subject" not in df_dossiers.columns:
    df_dossiers["dossier_subject"] = None

# Lees de URLs uit dossier_urls.txt
with open("dossier_urls.txt", "r") as file:
    dossier_urls = [line.strip() for line in file.readlines()]

# Loop door alle URLs en scrap de metadata
for index, row in df_dossiers.iterrows():
    dossier_url = row["dossier_sourceURL"]

    # Alleen scrapen als de URL in dossier_urls.txt voorkomt
    if dossier_url in dossier_urls:
        summary, subject = scrape_dossier_metadata(dossier_url)

        # Update DataFrame
        df_dossiers.at[index, "dossier_summary"] = summary
        df_dossiers.at[index, "dossier_subject"] = subject

# Opslaan als nieuw CSV-bestand
df_dossiers.to_csv("df_dossiers_updated.csv", index=False)

# Toon de geüpdatete DataFrame
from IPython.display import display
display(df_dossiers)

print("✅ Scraping voltooid en opgeslagen als 'df_dossiers_updated.csv'")
# Out:
#      dossier_id                                       dossier_name  \
# 0             1  (4e deel) Besluit Woo-verzoek Covid-19 aanpak ...
# 1             2  Woo-besluit aangaande kaders werkproces Wob-ve...
# 2             3  1e deel Besluit Woo verzoek Covid-19 aanpak AC...
# 3             4  2e deel Besluit Woo verzoek Covid-19 aanpak AC...
# 4             5  3e deel Besluit Woo verzoek Covid-19 aanpak AC...
# ..          ...                                                ...
# 215         216  Woo-deelbesluit aangaande overeenkomsten PCR-l...
# 216         217  Woo-deelbesluit aangaande vaccinatie aansprake...
# 217         218  Woo-deelbesluit aangaande ‘Capaciteit van ziek...
# 218         219  Woo-deelbesluit aangaande ‘de inkoop van perso...
# 219         220  Woo-verzoek d.d. 6 januari 2022 inzake het Eur...
#
#     dossier_published_date dossier_decision_date  document_count  \
# 0               2024-02-05            2023-07-29             229
# 1               2024-03-22            2023-03-20              83
# 2               2024-02-07            2022-08-18             208
# 3               2024-02-08            2023-02-17             239
# 4               2024-02-07            2022-05-12             144
# ..                     ...                   ...             ...
# 215             2024-06-06            2024-03-27              68
# 216             2024-10-09            2024-10-02             116
# 217             2024-10-19            2024-09-12             199
# 218             2024-04-05            2024-02-14            2695
# 219             2024-02-05            2022-05-12               9
#
#                                      dossier_sourceURL  \
# 0            https://open.minvws.nl/dossier/VWS-WC/098
# 1    https://open.minvws.nl/dossier/VWS-WOO/3518578...
# 2            https://open.minvws.nl/dossier/VWS-WC/090
# 3            https://open.minvws.nl/dossier/VWS-WC/095
# 4            https://open.minvws.nl/dossier/VWS-WC/096
# ..                                                 ...
# 215  https://open.minvws.nl/dossier/VWS-WOO/3792667...
# 216  https://open.minvws.nl/dossier/VWS-WOO/3939665...
# 217  https://open.minvws.nl/dossier/VWS-WOO/3959811...
# 218  https://open.minvws.nl/dossier/VWS-WOO/3773352...
# 219          https://open.minvws.nl/dossier/VWS-WC/107
#
#                                        dossier_summary dossier_subject
# 0    Besluit\r\nIk heb besloten om een deel van de ...            None
# 1    De minister van Volksgezondheid, Welzijn en Sp...            None
# 2    Besluit\r\nIk heb besloten om een deel van de ...            None
# 3    Besluit\r\nIk heb besloten om een deel van de ...            None
# 4    Besluit\r\nIk heb besloten om een deel van de ...            None
# ..                                                 ...             ...
# 215  De minister van Volksgezondheid, Welzijn en Sp...            None
# 216  De minister van Volksgezondheid, Welzijn en Sp...            None
# 217  De minister van Volksgezondheid, Welzijn en Sp...            None
# 218  De minister van Volksgezondheid, Welzijn en Sp...            None
# 219  Besluit\r\nIk heb besloten (deels) aan uw verz...            None
#
# [220 rows x 8 columns]
# ✅ Scraping voltooid en opgeslagen als 'df_dossiers_updated.csv'

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from IPython.display import display

# CSV met bestaande dossiers inlezen
df = pd.read_csv("old_csvs/df_dossiers.csv")

# URLs inlezen uit dossier_urls.txt
with open("dossier_urls.txt", "r") as f:
    dossier_urls = [line.strip() for line in f.readlines()]

# Functie om de dossiernaam en verantwoordelijke instantie op te halen
def get_dossier_info(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f"❌ Kan de pagina niet laden: {url} (Status: {response.status_code})")
        return None, None

    soup = BeautifulSoup(response.text, "html.parser")

    # Dossiernaam ophalen en 'Besluit over:' verwijderen
    title_element = soup.find("h1", {"data-e2e-name": "dossier-metadata-title"})
    dossier_name = title_element.get_text(strip=True).replace("Besluit over:", "").strip() if title_element else None

    # Verantwoordelijke instantie ophalen
    responsible_element = soup.find("td", {"data-e2e-name": "dossier-metadata-responsible"})
    responsible = responsible_element.get_text(strip=True) if responsible_element else None

    return dossier_name, responsible

# Voeg een kolom voor de verantwoordelijke instantie toe aan de DataFrame (als die nog niet bestaat)
if "dossier_responsible" not in df.columns:
    df["dossier_responsible"] = None

# Loop door de URLs en zoek de dossiernaam + verantwoordelijke instantie
for url in dossier_urls:
    dossier_name, responsible = get_dossier_info(url)

    if dossier_name and responsible:
        match_idx = df[df["dossier_name"] == dossier_name].index
        if not match_idx.empty:
            df.loc[match_idx, "dossier_responsible"] = responsible
            print(f"✅ Match gevonden: {dossier_name} → {responsible}")

    time.sleep(1)  # 🔹 Wacht 1 seconde om blokkering te voorkomen

# Opslaan als nieuwe CSV
df.to_csv("df_dossiers_responsible.csv", index=False)

# Weergeven in Jupyter Notebook
display(df)

print("✅ Verantwoordelijke instanties toegevoegd en opgeslagen als 'df_dossiers_responsible.csv'")
# Out:
# ✅ Match gevonden: Wob-deelbesluit aangaande Vaccinaties en medicatie over de periode februari 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode september 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-besluit aangaande kaders werkproces Wob-verzoeken → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode juni, juli en augustus 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen Overige over de periode september 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-besluit chatberichten aangaande communicatie tussen minister Hugo de Jonge en Jaap van Dissel, tussen minister Hugo de Jonge en minister-president Mark Rutte en tussen Jaap van Dissel en minister-president Mark Rutte die betrekking heeft op de bestrijding van het coronavirus in de meest brede zin → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit (aanvullend) op Wob-verzoek over de televisietoespraak van 16 maart 2020 → ministerie van Algemene Zaken
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over Brief over onderzoek PBM → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode januari 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande alle aan Mediq verbonden (rechts)personen → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande vaccinatie aansprakelijkheid Deel II → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-besluit COVID beleid P.I. Zwolle → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Wob- besluit inzake agenda-afspraken → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Wob-besluit op Wob-verzoek inzake communicatiebeleid covid-19 → ministerie van Algemene Zaken
# ✅ Match gevonden: Besluit op Wob-verzoek inzake communicatiebeleid covid-19 → ministerie van Algemene Zaken
# ✅ Match gevonden: Wob-besluit over domeinnaam coronacheck → ministerie van Algemene Zaken
# ✅ Match gevonden: Besluit op Wob-verzoek over reisadvies Kroatië → ministerie van Buitenlandse Zaken
# ✅ Match gevonden: Wob-deelbesluit aangaande Overleg overig over de periode februari 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode maart 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Capaciteit ziekenhuizen over de periode februari 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Besmettelijkheid kinderen over de periode maart 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Tweede deelbesluit Wob-verzoek inzake contact met het bedrijfsleven over de corona crisis → ministerie van Financiën
# ✅ Match gevonden: Wob-deelbesluit aangaande Scenario’s en maatregelen over de periode maart 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-besluit aangaande de overeenkomst met Mediq (CIBG dataset) → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Opstart Corona over december 2019 tot januari 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-besluit inzake openbaarmaking chat- en smsberichten → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit Wob-verzoek → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Wob-deelbesluit aangaande RIVM over de periode februari 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Medische hulpmiddelen over februari 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Herstelbesluit naar aanleiding van beroepschrift over het aantal aanwezigen in kerken periode 1 januari – 14 april 2020 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Coronamelder deel 3 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Vaccinaties en medicatie over de periode september 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Vaccinaties en medicatie over de periode oktober 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande ‘Capaciteit van ziekenhuizen IC-capaciteit' → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-besluit chatberichten inzake het aantal aanwezige IC-bedden bij de opschalingsplannen voor IC-capaciteit → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Testen over de periode februari 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Scenario’s en maatregelen over de periode februari 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Overleg VWS over de periode februari 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit Wob Covid-19 IAO stukken → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Wob-deelbesluit aangaande Scenario’s en maatregelen over de periode juli 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande RIVM over de periode mei 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Overleg VWS over de periode maart 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over de periode februari 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over Onderzoek naar Overeenkomst met RGA deel 2 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-besluit chatberichten aangaande de contacten tussen Thio Pharma en het ministerie van Volksgezondheid, Welzijn en Sport over de inkoop van vaccins in het buitenland. → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Informatie inzake WPG en briefing JvD → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-besluit chatberichten inzake de groepschat aangemaakt door de directeur Communicatie → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en Maatregelen over Maatregelen sport. → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande de overeenkomst met Mediq → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen Overige - Kern over de periode juli 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Long Covid deel 2 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale middelen over Covi-paspoort → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-besluit aangaande contacten bewindspersonen en OMT → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en maatregelen over Corona Opt-in → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Scenario’s en maatregelen over de periode augustus 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode juni 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande advies over zelftesten en isolatie → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Vaccinaties en medicatie over Inclusieve Vaccin Alliantie → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-besluit aangaande communicatie van het ministerie van Volksgezondheid met de IGJ en het LUMC m.b.t. Covid-19, longembolie en diagnostische protocollen → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Herziene beslissing op bezwaar op woo-besluit aangaande een dataset met daarin van alle in Nederland overleden personen het aantal dagen tussen covid-19 vaccinatie en de datum van overlijden en een dataset met covid-19 ziekenhuisopnamen volgens de GGD → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande RIVM over de periode april 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen overige - Kern over de periode oktober en november 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-besluit inzake communicatiebeleid → ministerie van Algemene Zaken
# ✅ Match gevonden: Wob-deelbesluit aangaande Overleg VWS over de periode september 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode februari 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op Wob-verzoek over optreden minister voor Rechtsbescherming in uitzending OP1 van 18 mei 2020 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Opschorting of voortijdige beëindiging onderzoek vanwege een ernstig ongewenst voorval II → Centrale Commissie Mensgebonden Onderzoek
# ✅ Match gevonden: Woo-deelbesluit aangaande RIVM over OMT vacatiegelden → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Scenario’s en maatregelen over de periode juni 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode juli 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode Augustus 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Tweede deelbesluit Wob-verzoek inzake informatie over de door Nederland gevoerde Covid-19 aanpak → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Wob-besluit terzake MKBA'S voor Coronabeleid → ministerie van Economische Zaken
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 11 juni 2021 inzake uitgezonderde detailhandel tijdens de lockdown → ministerie van Economische Zaken
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode augustus 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over Bruno Bruins → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode november 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode november 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Coronamelder deel 2 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande RIVM over besmettelijkheid → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande documenten met betrekking tot de overeenkomst met Mediq → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op Wob-verzoek inzake aanvraag bij EC voor wat betreft voucher kredietfaciliteit en zogenoemde SGR-vouchers → ministerie van Economische Zaken
# ✅ Match gevonden: Besluiten op Wob-verzoeken over huwelijk van de minister van Justitie en Veiligheid → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en maatregelen over de periode maart 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit Wob-verzoek Tozo-beschikkingen → ministerie van Sociale Zaken en Werkgelegenheid
# ✅ Match gevonden: Wob-verzoek inzake contacten met het bedrijfsleven over de coronacrisis → ministerie van Landbouw, Visserij, Voedselzekerheid en Natuur
# ✅ Match gevonden: Wob-verzoek vliegvouchers → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Besluit Wob-verzoek inzake informatie over de Baangerelateerde Investeringskorting (BIK) → ministerie van Financiën
# ✅ Match gevonden: Woo-deelbesluit aangaande Medische hulpmiddelen over de periode april 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: 1e deel Besluit Woo verzoek Covid-19 aanpak ACC Q4 2020 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande het Woo-deelbesluit Cluster SM 01 Wob Werkwijze Deel 2 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit Wob mogelijke versoepelingen van het maatregelenpakket van 20 januari 2021 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Tweede deelbesluit op uw Woo-verzoek in zake de interdepartementale werkgroep desinformatie → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Woo besluit COVID 19 wetgeving inzake algemene vergaderingen van aandeelhouders → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Wob-besluit_verzoek 2 juni 2021 inzake productie_mondkapjes → ministerie van Economische Zaken
# ✅ Match gevonden: Woo-deelbesluit aangaande ‘de inkoop van persoonlijke beschermingsmiddelen tijdens de coronacrisis en het onderzoek daarnaar’ → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op Wob-verzoek over notities LNV ter voorbereiding voor de Covid-19 Catshuis bijeenkomsten en de bijeenkomsten van de Ministeriële crisiscommissie → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Besluit op Woo-verzoek inzake het ‘Rapport van feitelijke bevindingen Review accountantswerkzaamheden NOW 1- en NOW 2-regeling’ → ministerie van Financiën
# ✅ Match gevonden: Wob- besluit onderhandelingen KLM-steunmaatregelen → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Woo-deelbesluit aangaande Digitale Middelen over de periode januari 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande het spoedadvies Tijdelijke wet uitbreiding coronatoegangsbewijzen en Tijdelijke wet differentiatie coronatoegangsbewijzen → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op WOB verzoek d.d. 18 september 2020 inzake Baangerelateerde arbeidskorting (BIK) en Vennootschapsbelasting (VPB) → ministerie van Economische Zaken
# ✅ Match gevonden: Deelbesluit 1 Wob-verzoek d.d. 11 augustus 2021 inzake het Europees Herstelfonds → ministerie van Economische Zaken
# ✅ Match gevonden: Woo-deelbesluit aangaande overeenkomsten PCR-laboratoria → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Digitale Middelen over Coronamelder → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op Wob-verzoek over de aan minister Koolmees aangeboden notities ter voorbereiding op bijeenkomsten in het Catshuis en bijeenkomsten van de ministeriële crisiscommissie (mcc) → ministerie van Sociale Zaken en Werkgelegenheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Digitale Middelen over de periode februari 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Tweede deelbesluit Wob-verzoek aantal aanwezigen in kerken periode 14 april - 26 oktober 2020 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Derde deelbesluit op WOB/Woo-verzoek over de interdepartementale werkgroep desinformatie tijdens de COVID-19 crisis → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario's en maatregelen COVID-19 Campagnes → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op WOB verzoek inzake de betrokkenheid van het ministerie van Economische Zaken en Klimaat bij het bieden van financiële oplossingen voor winkelketen HEMA. → ministerie van Economische Zaken
# ✅ Match gevonden: Besluit WOB Covid-19 MCCb stukken → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Beslissing op bezwaar Wob-verzoek inzake vliegvouchers → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Beslissing op bezwaar inzake communicatie over de mondkapjesdeal → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Besluit Wob inzake agenda afspraken Minister, Staatsecretaris en leden Bestuursraad → ministerie van Economische Zaken
# ✅ Match gevonden: Besluit op Woo-verzoek communicatie rondom de avondklok → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en Maatregelen over Wob-werkwijze deel 1 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode oktober 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 12 oktober 2020 inzake notities besluitvorming coronacrisis → ministerie van Economische Zaken
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen Overige over de periode mei 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op Wob-verzoek over aankoop medische middelen COVID-19 → ministerie van Buitenlandse Zaken
# ✅ Match gevonden: Derde deelbesluit Wob-verzoek aantal aanwezigen in kerken periode 14 april - 26 oktober 2020 → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en maatregelen over de periode september 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit Wob invoer en handhaving van de avondklok → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: 2e deel Besluit Woo verzoek Covid-19 aanpak ACC Q1 2021 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Besluit op Wob-verzoek over aantal aanwezigen in kerkelijke gebouwen → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Besluit Wob-verzoek inzake communicatie over Europese steun corona → ministerie van Financiën
# ✅ Match gevonden: Besluit op Wob verzoek inzake informatie over de Baangerelateerde Investeringskorting (BIK) en wijziging van de Vennootschapsbelasting (VPB) → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Besluit Wob-verzoek coronavoucher → ministerie van Economische Zaken
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 18 september 2020 inzake BIK en VPB → ministerie van Economische Zaken
# ✅ Match gevonden: Nederlandse bijdrage aan bestrijding COVID pandemie Suriname → ministerie van Buitenlandse Zaken
# ✅ Match gevonden: Wob omtrent informatie m.b.t. sanering nertsenhouderijen, specifiek m.b.t. de compensatiemaatregelen (Staatssteun) in de periode 11 maart 2020 tot en met 23 november 2020 → ministerie van Landbouw, Visserij, Voedselzekerheid en Natuur
# ✅ Match gevonden: Besluit op Wob-verzoek over reisadvies voor China door COVID-19 → ministerie van Buitenlandse Zaken
# ✅ Match gevonden: Wob-besluit met betrekking tot de juridische grondslag van het instellen van de avondklok in verband met Covid-19 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-verzoek d.d. 6 januari 2022 inzake het Europees Herstelfonds (LNV) → ministerie van Landbouw, Visserij, Voedselzekerheid en Natuur
# ✅ Match gevonden: Besluit op Woo-verzoek rond communicatie tussen BZK techbedrijven → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Besluit op Wob-verzoek over totstandkoming van de NOW-regeling → ministerie van Sociale Zaken en Werkgelegenheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over de periode november 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode december 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op Wob-verzoek inzake de totstandkoming van de Baangerelateerde Investeringskorting (BIK) → ministerie van Financiën
# ✅ Match gevonden: Besluit op uw Wob-verzoek d.d. 9 november 2020 m.b.t. Covid-19 en nertsen → ministerie van Landbouw, Visserij, Voedselzekerheid en Natuur
# ✅ Match gevonden: Besluit Wob-verzoek inzake contact met het bedrijfsleven over de corona-crisis → ministerie van Financiën
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode april 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode maart 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Derde deelbesluit Wob-verzoek inzake informatie over de door Nederland gevoerde covid-19 aanpak → ministerie van Financiën
# ✅ Match gevonden: Wob- besluit luchtvaartbeleid tijdens corona-epidemie → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Besluit op Wob-verzoek over Nationaal Programma Onderwijs → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Besluit WOB inzake subsidieverstrekking Goodbye 2020 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Deelbesluit 2 Wob-verzoek d.d. 11 augustus 2021 inzake het Europees Herstelfonds → ministerie van Economische Zaken
# ✅ Match gevonden: Besluit Wob-verzoek repatriëring Nederlanders uit Marokko → ministerie van Buitenlandse Zaken
# ✅ Match gevonden: Besluit op Wob-verzoek 2021-12 over Wob-verzoeken 2020-58 en 2020-46 omtrent vliegvouchers → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Eerste deelbesluit op Woo-verzoek over het aantal aanwezigen in kerken → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode september 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 31 maart 2021 inzake productie vaccins tegen Covid-19 bij Halix B.V. → ministerie van Economische Zaken
# ✅ Match gevonden: Besluit op Wob-verzoek over agenda-afspraken → ministerie van Financiën
# ✅ Match gevonden: Tweede deelbesluit op Woo-verzoek over het aantal aanwezigen in kerken → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Wob-verzoek d.d. 9 november 2020 inzake COVID-19 en nertsen → ministerie van Landbouw, Visserij, Voedselzekerheid en Natuur
# ✅ Match gevonden: Wob-besluit onderhandelingen KLM-steunmaatregelen → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Wob- besluit oranje gebieden → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode augustus 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-besluit betreffende openbaarmaking correspondentie omtrent de juridische procedure van de avondklok. → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Tweede deelbesluit op Wob verzoek inzake de financiële steun die het kabinet heeft verleend aan KLM → ministerie van Financiën
# ✅ Match gevonden: Besluit op een bezwaar tegen een Wob-besluit met betrekking inzake in Griekenland verblijvende alleenstaande minderjarige vreemdelingen en hun huisvesting → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Overleg VWS over Onderzoek naar Overeenkomst met RGA deel 3 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-verzoek d.d. 26 oktober 2020 inzake de VION-groep → ministerie van Landbouw, Visserij, Voedselzekerheid en Natuur
# ✅ Match gevonden: Woo-deelbesluit aangaande de Corman-Drosten Paper over de periode januari 2020. → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op Wob-verzoek over contacten bedrijfsleven coronasteunmaatregelen → ministerie van Onderwijs, Cultuur en Wetenschap
# ✅ Match gevonden: Deelbesluit 3 m.b.t. Wob-verzoek d.d. 26 oktober 2020 inzake de VION-groep → ministerie van Landbouw, Visserij, Voedselzekerheid en Natuur
# ✅ Match gevonden: Besluit op Woo-verzoek inzake informatie burgerinitiatief inzake collectieve aangifte → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Tweede deelbesluit Wob-verzoek inzake communicatie over Europese steun → ministerie van Financiën
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen Overige – Kern over de periode april 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode april 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en Maatregelen over Online Mediaplatforms → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinatie & Medicatie over EMA Communicatie. → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob- besluit noodzakelijkheidsverklaring → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Besluit op Woo-verzoek inzake de behandeling van het Woo-verzoek inzake de samenwerking van het Ministerie van Financiën met Sywert van Lienden, Relief Good Alliance B.V. en Stichting Hulptroepen Alliantie → ministerie van Financiën
# ✅ Match gevonden: Besluit op Wob-verzoek Halix, mondkapjes en hulptroepen.nu → ministerie van Algemene Zaken
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen Overige over de periode juni 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: 3e deel Besluit Woo verzoek Covid-19 aanpak ACC-19 April-Mei 2021 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Besluit op bezwaar Wob-verzoek aantal aanwezigen in kerken 1 januari - 14 april 2020 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Tweede deelbesluit op Wob verzoek inzake het Europees Herstelfonds → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 11 juni 2021 inzake uitgezonderde detailhandel tijdens de lockdown → ministerie van Economische Zaken
# ✅ Match gevonden: (4e deel) Besluit Woo-verzoek Covid-19 aanpak DOC-19 Q4 2020 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode oktober 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Long Covid deel 1 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode juli 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op Wob-verzoek over Covid-19 besmettingen bij onderwijspersoneel → ministerie van Onderwijs, Cultuur en Wetenschap
# ✅ Match gevonden: Besluit op Wob verzoek inzake Europees Herstelfonds → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Besluit op Wob- verzoek aangaande staatssteun KLM → ministerie van Infrastructuur en Waterstaat
# ✅ Match gevonden: Wob inzake informatie met betrekking tot het beleid t.a.v. het coronavirus en de nertsensector → ministerie van Landbouw, Visserij, Voedselzekerheid en Natuur
# ✅ Match gevonden: Besluit Wob inzake agenda afspraken Minister, Staatsscretaris en leden Bestuursraad → ministerie van Economische Zaken
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over Vaccinaties → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode februari 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode november 2020, december 2020 en januari 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit Woo-verzoek d.d. 14-12-2021 inzake documenten m.b.t. de Rapportage "Ondernemingen die knelpunten ervaren met de referentiesystimatiek bij de TVL'" → ministerie van Economische Zaken
# ✅ Match gevonden: Besluit op Wob-verzoek inzake de behandeling van het Wob-verzoek die op 16 juli 2020 is ingediend (besluit Wob-verzoek steunmaatregelen KLM 2) → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Besluit Wob ontwikkeling en invoering Tijdelijke wet maatregelen (TWM) Covid-19 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode december 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Tweede deelbesluit op Woo-verzoek inzake de Interdepartementale Werkgroep Desinformatie → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Besluit Wob sluiting horeca en winkelgelegenheden → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode mei 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit op Wob-verzoek over nota's en memo's over Covid-19 bij nertsen → ministerie van Landbouw, Visserij, Voedselzekerheid en Natuur
# ✅ Match gevonden: Woo-deelbesluit aangaande Digitale Middelen over GGD IT-systemen en DPIA'S → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit Wob COVID-19 communicatiebeleid → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over de periode januari 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Eerste deelbesluit Wob-verzoek inzake informatie over de door Nederland gevoerde covid-19 aanpak → ministerie van Financiën
# ✅ Match gevonden: Woo-deelbesluit aangaande Maatregelen Kerkgangers → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode oktober 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode mei 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Beslissing op bezwaar Wob-besluit coronamaatregelen → ministerie van Binnenlandse Zaken en Koninkrijksrelaties
# ✅ Match gevonden: Eerste deelbesluit Wob-verzoek aantal aanwezigen in kerken periode 14 april - 26 oktober 2020 → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode juni 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Derde deelbesluit op Wob-verzoek inzake het Europees Herstelfonds → ministerie van Financiën
# ✅ Match gevonden: Woo-deelbesluit aangaande Medische hulpmiddelen over de periode maart 2020 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over de periode maart 2021 → ministerie van Volksgezondheid, Welzijn en Sport
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 9 juni 2020 inzake contact met het bedrijfsleven over de corona-crisis → ministerie van Economische Zaken
# ✅ Match gevonden: Wob-besluit Wob-verzoek d.d. 13 augustus 2020 inzake medicijnenfabriek Apotex → ministerie van Economische Zaken
# ✅ Match gevonden: Besluit op Wob-verzoek inzake agenda-afspraken → ministerie van Sociale Zaken en Werkgelegenheid
# ✅ Match gevonden: Besluit op Wob-verzoek coronamaatregelen DJI → ministerie van Justitie en Veiligheid
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over de periode december 2020 → ministerie van Volksgezondheid, Welzijn en Sport
#      dossier_id                                       dossier_name  \
# 0             1  (4e deel) Besluit Woo-verzoek Covid-19 aanpak ...
# 1             2  Woo-besluit aangaande kaders werkproces Wob-ve...
# 2             3  1e deel Besluit Woo verzoek Covid-19 aanpak AC...
# 3             4  2e deel Besluit Woo verzoek Covid-19 aanpak AC...
# 4             5  3e deel Besluit Woo verzoek Covid-19 aanpak AC...
# ..          ...                                                ...
# 215         216  Woo-deelbesluit aangaande overeenkomsten PCR-l...
# 216         217  Woo-deelbesluit aangaande vaccinatie aansprake...
# 217         218  Woo-deelbesluit aangaande ‘Capaciteit van ziek...
# 218         219  Woo-deelbesluit aangaande ‘de inkoop van perso...
# 219         220  Woo-verzoek d.d. 6 januari 2022 inzake het Eur...
#
#     dossier_published_date dossier_decision_date  document_count  \
# 0               2024-02-05            2023-07-29             229
# 1               2024-03-22            2023-03-20              83
# 2               2024-02-07            2022-08-18             208
# 3               2024-02-08            2023-02-17             239
# 4               2024-02-07            2022-05-12             144
# ..                     ...                   ...             ...
# 215             2024-06-06            2024-03-27              68
# 216             2024-10-09            2024-10-02             116
# 217             2024-10-19            2024-09-12             199
# 218             2024-04-05            2024-02-14            2695
# 219             2024-02-05            2022-05-12               9
#
#                                      dossier_sourceURL  \
# 0            https://open.minvws.nl/dossier/VWS-WC/098
# 1    https://open.minvws.nl/dossier/VWS-WOO/3518578...
# 2            https://open.minvws.nl/dossier/VWS-WC/090
# 3            https://open.minvws.nl/dossier/VWS-WC/095
# 4            https://open.minvws.nl/dossier/VWS-WC/096
# ..                                                 ...
# 215  https://open.minvws.nl/dossier/VWS-WOO/3792667...
# 216  https://open.minvws.nl/dossier/VWS-WOO/3939665...
# 217  https://open.minvws.nl/dossier/VWS-WOO/3959811...
# 218  https://open.minvws.nl/dossier/VWS-WOO/3773352...
# 219          https://open.minvws.nl/dossier/VWS-WC/107
#
#                                    dossier_responsible
# 0                ministerie van Justitie en Veiligheid
# 1     ministerie van Volksgezondheid, Welzijn en Sport
# 2                ministerie van Justitie en Veiligheid
# 3                ministerie van Justitie en Veiligheid
# 4                ministerie van Justitie en Veiligheid
# ..                                                 ...
# 215   ministerie van Volksgezondheid, Welzijn en Sport
# 216   ministerie van Volksgezondheid, Welzijn en Sport
# 217   ministerie van Volksgezondheid, Welzijn en Sport
# 218   ministerie van Volksgezondheid, Welzijn en Sport
# 219  ministerie van Landbouw, Visserij, Voedselzeke...
#
# [220 rows x 7 columns]
# ✅ Verantwoordelijke instanties toegevoegd en opgeslagen als 'df_dossiers_responsible.csv'

# %%
# extract subject per dossier

import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from IPython.display import display

# CSV met bestaande dossiers inlezen
df = pd.read_csv("old_csvs/df_dossiers_responsible.csv")

# URLs inlezen uit dossier_urls.txt
with open("dossier_urls.txt", "r") as f:
    dossier_urls = [line.strip() for line in f.readlines()]

# Functie om de dossiernaam en onderwerp op te halen
def get_dossier_subject(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f"❌ Kan de pagina niet laden: {url} (Status: {response.status_code})")
        return None, None

    soup = BeautifulSoup(response.text, "html.parser")

    # Dossiernaam ophalen en 'Besluit over:' verwijderen
    title_element = soup.find("h1", {"data-e2e-name": "dossier-metadata-title"})
    dossier_name = title_element.get_text(strip=True).replace("Besluit over:", "").strip() if title_element else None

    # Onderwerp ophalen uit de bijbehorende <a> tags onder <th> met "Onderwerp"
    subject_element = soup.find("th", string="Onderwerp")
    subject = None
    if subject_element:
        subject_td = subject_element.find_next("td")  # Zoek de volgende <td> eronder
        if subject_td:
            subject_links = subject_td.find_all("a", class_="woo-a")
            subject = ", ".join(link.get_text(strip=True) for link in subject_links) if subject_links else None

    return dossier_name, subject

# Voeg een kolom voor dossier_subject toe aan de DataFrame als die nog niet bestaat
if "dossier_subject" not in df.columns:
    df["dossier_subject"] = None

# Loop door de URLs en zoek de dossiernaam en onderwerp
for url in dossier_urls:
    dossier_name, subject = get_dossier_subject(url)

    if dossier_name and subject:
        match_idx = df[df["dossier_name"] == dossier_name].index
        if not match_idx.empty:
            df.loc[match_idx, "dossier_subject"] = subject
            print(f"✅ Match gevonden: {dossier_name} → Onderwerp: {subject}")

    time.sleep(1)  # 🔹 Wacht 1 seconde om blokkering te voorkomen

# Opslaan als nieuwe CSV
df.to_csv("df_dossiers_final.csv", index=False)

# Weergeven in Jupyter Notebook
display(df)

print("✅ Onderwerpen toegevoegd en opgeslagen als 'df_dossiers_final.csv'")
# Out:
# ✅ Match gevonden: Wob-deelbesluit aangaande Vaccinaties en medicatie over de periode februari 2020 → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode september 2020 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Woo-besluit aangaande kaders werkproces Wob-verzoeken → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode juni, juli en augustus 2021 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen Overige over de periode september 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Woo-besluit chatberichten aangaande communicatie tussen minister Hugo de Jonge en Jaap van Dissel, tussen minister Hugo de Jonge en minister-president Mark Rutte en tussen Jaap van Dissel en minister-president Mark Rutte die betrekking heeft op de bestrijding van het coronavirus in de meest brede zin → Onderwerp: Chats
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over Brief over onderzoek PBM → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode januari 2021 → Onderwerp: Testen
# ✅ Match gevonden: Woo-deelbesluit aangaande alle aan Mediq verbonden (rechts)personen → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-deelbesluit aangaande vaccinatie aansprakelijkheid Deel II → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Wob-besluit COVID beleid P.I. Zwolle → Onderwerp: Overleg overig
# ✅ Match gevonden: Wob- besluit inzake agenda-afspraken → Onderwerp: Overleg overig
# ✅ Match gevonden: Wob-deelbesluit aangaande Overleg overig over de periode februari 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode maart 2020 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Wob-deelbesluit aangaande Capaciteit ziekenhuizen over de periode februari 2020 → Onderwerp: Capaciteit ziekenhuizen
# ✅ Match gevonden: Wob-deelbesluit aangaande Besmettelijkheid kinderen over de periode maart 2020 → Onderwerp: Besmettelijkheid kinderen
# ✅ Match gevonden: Tweede deelbesluit Wob-verzoek inzake contact met het bedrijfsleven over de corona crisis → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-deelbesluit aangaande Scenario’s en maatregelen over de periode maart 2020 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-besluit aangaande de overeenkomst met Mediq (CIBG dataset) → Onderwerp: Overleg VWS
# ✅ Match gevonden: Wob-deelbesluit aangaande Opstart Corona over december 2019 tot januari 2020 → Onderwerp: Opstart Corona
# ✅ Match gevonden: Woo-besluit inzake openbaarmaking chat- en smsberichten → Onderwerp: Chats
# ✅ Match gevonden: Wob-deelbesluit aangaande RIVM over de periode februari 2020 → Onderwerp: RIVM
# ✅ Match gevonden: Woo-deelbesluit aangaande Coronamelder deel 3 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Wob-deelbesluit aangaande Vaccinaties en medicatie over de periode september 2020 → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Wob-deelbesluit aangaande Vaccinaties en medicatie over de periode oktober 2020 → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Woo-deelbesluit aangaande ‘Capaciteit van ziekenhuizen IC-capaciteit' → Onderwerp: Capaciteit ziekenhuizen
# ✅ Match gevonden: Woo-besluit chatberichten inzake het aantal aanwezige IC-bedden bij de opschalingsplannen voor IC-capaciteit → Onderwerp: Chats
# ✅ Match gevonden: Wob-deelbesluit aangaande Testen over de periode februari 2020 → Onderwerp: Testen
# ✅ Match gevonden: Wob-deelbesluit aangaande Scenario’s en maatregelen over de periode februari 2020 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-deelbesluit aangaande Overleg VWS over de periode februari 2020 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Wob-deelbesluit aangaande Scenario’s en maatregelen over de periode juli 2020 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-deelbesluit aangaande RIVM over de periode mei 2020 → Onderwerp: RIVM
# ✅ Match gevonden: Wob-deelbesluit aangaande Overleg VWS over de periode maart 2020 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over de periode februari 2021 → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over Onderzoek naar Overeenkomst met RGA deel 2 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-besluit chatberichten aangaande de contacten tussen Thio Pharma en het ministerie van Volksgezondheid, Welzijn en Sport over de inkoop van vaccins in het buitenland. → Onderwerp: Chats
# ✅ Match gevonden: Woo-besluit chatberichten inzake de groepschat aangemaakt door de directeur Communicatie → Onderwerp: Chats
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en Maatregelen over Maatregelen sport. → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande de overeenkomst met Mediq → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen Overige - Kern over de periode juli 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Woo-deelbesluit aangaande Long Covid deel 2 → Onderwerp: RIVM
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale middelen over Covi-paspoort → Onderwerp: Digitale middelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en maatregelen over Corona Opt-in → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-deelbesluit aangaande Scenario’s en maatregelen over de periode augustus 2020 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode juni 2020 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Woo-deelbesluit aangaande advies over zelftesten en isolatie → Onderwerp: Testen
# ✅ Match gevonden: Wob-deelbesluit aangaande Vaccinaties en medicatie over Inclusieve Vaccin Alliantie → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Woo-besluit aangaande communicatie van het ministerie van Volksgezondheid met de IGJ en het LUMC m.b.t. Covid-19, longembolie en diagnostische protocollen → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Herziene beslissing op bezwaar op woo-besluit aangaande een dataset met daarin van alle in Nederland overleden personen het aantal dagen tussen covid-19 vaccinatie en de datum van overlijden en een dataset met covid-19 ziekenhuisopnamen volgens de GGD → Onderwerp: RIVM
# ✅ Match gevonden: Wob-deelbesluit aangaande RIVM over de periode april 2020 → Onderwerp: RIVM
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen overige - Kern over de periode oktober en november 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Wob-deelbesluit aangaande Overleg VWS over de periode september 2020 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode februari 2021 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-deelbesluit aangaande RIVM over OMT vacatiegelden → Onderwerp: RIVM
# ✅ Match gevonden: Wob-deelbesluit aangaande Scenario’s en maatregelen over de periode juni 2020 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode juli 2020 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode Augustus 2020 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Wob-besluit terzake MKBA'S voor Coronabeleid → Onderwerp: Opstart Corona
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 11 juni 2021 inzake uitgezonderde detailhandel tijdens de lockdown → Onderwerp: Opstart Corona
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode augustus 2020 → Onderwerp: Testen
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over Bruno Bruins → Onderwerp: Overleg VWS
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode november 2020 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode november 2020 → Onderwerp: Testen
# ✅ Match gevonden: Woo-deelbesluit aangaande Coronamelder deel 2 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Woo-deelbesluit aangaande RIVM over besmettelijkheid → Onderwerp: RIVM
# ✅ Match gevonden: Besluit op Wob-verzoek inzake aanvraag bij EC voor wat betreft voucher kredietfaciliteit en zogenoemde SGR-vouchers → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluiten op Wob-verzoeken over huwelijk van de minister van Justitie en Veiligheid → Onderwerp: Besmettelijkheid kinderen
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en maatregelen over de periode maart 2021 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit Wob-verzoek Tozo-beschikkingen → Onderwerp: Overleg overig
# ✅ Match gevonden: Wob-verzoek inzake contacten met het bedrijfsleven over de coronacrisis → Onderwerp: Overleg overig
# ✅ Match gevonden: Wob-verzoek vliegvouchers → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit Wob-verzoek inzake informatie over de Baangerelateerde Investeringskorting (BIK) → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Medische hulpmiddelen over de periode april 2020 → Onderwerp: Medische hulpmiddelen
# ✅ Match gevonden: 1e deel Besluit Woo verzoek Covid-19 aanpak ACC Q4 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Woo-deelbesluit aangaande het Woo-deelbesluit Cluster SM 01 Wob Werkwijze Deel 2 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit Wob mogelijke versoepelingen van het maatregelenpakket van 20 januari 2021 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Tweede deelbesluit op uw Woo-verzoek in zake de interdepartementale werkgroep desinformatie → Onderwerp: Overleg overig
# ✅ Match gevonden: Woo besluit COVID 19 wetgeving inzake algemene vergaderingen van aandeelhouders → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-besluit_verzoek 2 juni 2021 inzake productie_mondkapjes → Onderwerp: Medische hulpmiddelen
# ✅ Match gevonden: Woo-deelbesluit aangaande ‘de inkoop van persoonlijke beschermingsmiddelen tijdens de coronacrisis en het onderzoek daarnaar’ → Onderwerp: Overleg VWS
# ✅ Match gevonden: Besluit op Wob-verzoek over notities LNV ter voorbereiding voor de Covid-19 Catshuis bijeenkomsten en de bijeenkomsten van de Ministeriële crisiscommissie → Onderwerp: Opstart Corona
# ✅ Match gevonden: Besluit op Woo-verzoek inzake het ‘Rapport van feitelijke bevindingen Review accountantswerkzaamheden NOW 1- en NOW 2-regeling’ → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob- besluit onderhandelingen KLM-steunmaatregelen → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Digitale Middelen over de periode januari 2021 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Woo-deelbesluit aangaande het spoedadvies Tijdelijke wet uitbreiding coronatoegangsbewijzen en Tijdelijke wet differentiatie coronatoegangsbewijzen → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit op WOB verzoek d.d. 18 september 2020 inzake Baangerelateerde arbeidskorting (BIK) en Vennootschapsbelasting (VPB) → Onderwerp: Overleg overig
# ✅ Match gevonden: Deelbesluit 1 Wob-verzoek d.d. 11 augustus 2021 inzake het Europees Herstelfonds → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande overeenkomsten PCR-laboratoria → Onderwerp: Testen
# ✅ Match gevonden: Woo-deelbesluit aangaande Digitale Middelen over Coronamelder → Onderwerp: Digitale middelen
# ✅ Match gevonden: Besluit op Wob-verzoek over de aan minister Koolmees aangeboden notities ter voorbereiding op bijeenkomsten in het Catshuis en bijeenkomsten van de ministeriële crisiscommissie (mcc) → Onderwerp: Opstart Corona
# ✅ Match gevonden: Woo-deelbesluit aangaande Digitale Middelen over de periode februari 2021 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Tweede deelbesluit Wob-verzoek aantal aanwezigen in kerken periode 14 april - 26 oktober 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Derde deelbesluit op WOB/Woo-verzoek over de interdepartementale werkgroep desinformatie tijdens de COVID-19 crisis → Onderwerp: Overleg overig
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario's en maatregelen COVID-19 Campagnes → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit op WOB verzoek inzake de betrokkenheid van het ministerie van Economische Zaken en Klimaat bij het bieden van financiële oplossingen voor winkelketen HEMA. → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit WOB Covid-19 MCCb stukken → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Beslissing op bezwaar Wob-verzoek inzake vliegvouchers → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Beslissing op bezwaar inzake communicatie over de mondkapjesdeal → Onderwerp: Medische hulpmiddelen
# ✅ Match gevonden: Besluit Wob inzake agenda afspraken Minister, Staatsecretaris en leden Bestuursraad → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit op Woo-verzoek communicatie rondom de avondklok → Onderwerp: Overleg overig
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en Maatregelen over Wob-werkwijze deel 1 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode oktober 2020 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 12 oktober 2020 inzake notities besluitvorming coronacrisis → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen Overige over de periode mei 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit op Wob-verzoek over aankoop medische middelen COVID-19 → Onderwerp: Medische hulpmiddelen
# ✅ Match gevonden: Derde deelbesluit Wob-verzoek aantal aanwezigen in kerken periode 14 april - 26 oktober 2020 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en maatregelen over de periode september 2020 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit Wob invoer en handhaving van de avondklok → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: 2e deel Besluit Woo verzoek Covid-19 aanpak ACC Q1 2021 → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit op Wob-verzoek over aantal aanwezigen in kerkelijke gebouwen → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit Wob-verzoek inzake communicatie over Europese steun corona → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit op Wob verzoek inzake informatie over de Baangerelateerde Investeringskorting (BIK) en wijziging van de Vennootschapsbelasting (VPB) → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit Wob-verzoek coronavoucher → Onderwerp: Digitale middelen
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 18 september 2020 inzake BIK en VPB → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Nederlandse bijdrage aan bestrijding COVID pandemie Suriname → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob omtrent informatie m.b.t. sanering nertsenhouderijen, specifiek m.b.t. de compensatiemaatregelen (Staatssteun) in de periode 11 maart 2020 tot en met 23 november 2020 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit op Wob-verzoek over reisadvies voor China door COVID-19 → Onderwerp: Opstart Corona
# ✅ Match gevonden: Wob-besluit met betrekking tot de juridische grondslag van het instellen van de avondklok in verband met Covid-19 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-verzoek d.d. 6 januari 2022 inzake het Europees Herstelfonds (LNV) → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit op Woo-verzoek rond communicatie tussen BZK techbedrijven → Onderwerp: Overleg VWS
# ✅ Match gevonden: Besluit op Wob-verzoek over totstandkoming van de NOW-regeling → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over de periode november 2020 → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode december 2020 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Besluit op Wob-verzoek inzake de totstandkoming van de Baangerelateerde Investeringskorting (BIK) → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit op uw Wob-verzoek d.d. 9 november 2020 m.b.t. Covid-19 en nertsen → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit Wob-verzoek inzake contact met het bedrijfsleven over de corona-crisis → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode april 2021 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode maart 2021 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Derde deelbesluit Wob-verzoek inzake informatie over de door Nederland gevoerde covid-19 aanpak → Onderwerp: Opstart Corona
# ✅ Match gevonden: Wob- besluit luchtvaartbeleid tijdens corona-epidemie → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit op Wob-verzoek over Nationaal Programma Onderwijs → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit WOB inzake subsidieverstrekking Goodbye 2020 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Deelbesluit 2 Wob-verzoek d.d. 11 augustus 2021 inzake het Europees Herstelfonds → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit Wob-verzoek repatriëring Nederlanders uit Marokko → Onderwerp: Opstart Corona
# ✅ Match gevonden: Besluit op Wob-verzoek 2021-12 over Wob-verzoeken 2020-58 en 2020-46 omtrent vliegvouchers → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Eerste deelbesluit op Woo-verzoek over het aantal aanwezigen in kerken → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode september 2020 → Onderwerp: Testen
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 31 maart 2021 inzake productie vaccins tegen Covid-19 bij Halix B.V. → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Besluit op Wob-verzoek over agenda-afspraken → Onderwerp: Overleg overig
# ✅ Match gevonden: Tweede deelbesluit op Woo-verzoek over het aantal aanwezigen in kerken → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-verzoek d.d. 9 november 2020 inzake COVID-19 en nertsen → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-besluit onderhandelingen KLM-steunmaatregelen → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob- besluit oranje gebieden → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode augustus 2020 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Wob-besluit betreffende openbaarmaking correspondentie omtrent de juridische procedure van de avondklok. → Onderwerp: Overleg overig
# ✅ Match gevonden: Tweede deelbesluit op Wob verzoek inzake de financiële steun die het kabinet heeft verleend aan KLM → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit op een bezwaar tegen een Wob-besluit met betrekking inzake in Griekenland verblijvende alleenstaande minderjarige vreemdelingen en hun huisvesting → Onderwerp: Overleg overig
# ✅ Match gevonden: Overleg VWS over Onderzoek naar Overeenkomst met RGA deel 3 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Wob-verzoek d.d. 26 oktober 2020 inzake de VION-groep → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande de Corman-Drosten Paper over de periode januari 2020. → Onderwerp: RIVM
# ✅ Match gevonden: Besluit op Wob-verzoek over contacten bedrijfsleven coronasteunmaatregelen → Onderwerp: Opstart Corona
# ✅ Match gevonden: Deelbesluit 3 m.b.t. Wob-verzoek d.d. 26 oktober 2020 inzake de VION-groep → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit op Woo-verzoek inzake informatie burgerinitiatief inzake collectieve aangifte → Onderwerp: Overleg overig
# ✅ Match gevonden: Tweede deelbesluit Wob-verzoek inzake communicatie over Europese steun → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen Overige – Kern over de periode april 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode april 2020 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Scenario’s en Maatregelen over Online Mediaplatforms → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinatie & Medicatie over EMA Communicatie. → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Wob- besluit noodzakelijkheidsverklaring → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit op Woo-verzoek inzake de behandeling van het Woo-verzoek inzake de samenwerking van het Ministerie van Financiën met Sywert van Lienden, Relief Good Alliance B.V. en Stichting Hulptroepen Alliantie → Onderwerp: Medische hulpmiddelen
# ✅ Match gevonden: Besluit op Wob-verzoek Halix, mondkapjes en hulptroepen.nu → Onderwerp: Medische hulpmiddelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleggen Overige over de periode juni 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: 3e deel Besluit Woo verzoek Covid-19 aanpak ACC-19 April-Mei 2021 → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit op bezwaar Wob-verzoek aantal aanwezigen in kerken 1 januari - 14 april 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Tweede deelbesluit op Wob verzoek inzake het Europees Herstelfonds → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 11 juni 2021 inzake uitgezonderde detailhandel tijdens de lockdown → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: (4e deel) Besluit Woo-verzoek Covid-19 aanpak DOC-19 Q4 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode oktober 2020 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Woo-deelbesluit aangaande Long Covid deel 1 → Onderwerp: RIVM
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode juli 2020 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Besluit op Wob-verzoek over Covid-19 besmettingen bij onderwijspersoneel → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit op Wob verzoek inzake Europees Herstelfonds → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit op Wob- verzoek aangaande staatssteun KLM → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob inzake informatie met betrekking tot het beleid t.a.v. het coronavirus en de nertsensector → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit Wob inzake agenda afspraken Minister, Staatsscretaris en leden Bestuursraad → Onderwerp: Opstart Corona
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over Vaccinaties → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode februari 2021 → Onderwerp: Testen
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode november 2020, december 2020 en januari 2021 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Besluit Woo-verzoek d.d. 14-12-2021 inzake documenten m.b.t. de Rapportage "Ondernemingen die knelpunten ervaren met de referentiesystimatiek bij de TVL'" → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Besluit op Wob-verzoek inzake de behandeling van het Wob-verzoek die op 16 juli 2020 is ingediend (besluit Wob-verzoek steunmaatregelen KLM 2) → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit Wob ontwikkeling en invoering Tijdelijke wet maatregelen (TWM) Covid-19 → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode december 2020 → Onderwerp: Testen
# ✅ Match gevonden: Tweede deelbesluit op Woo-verzoek inzake de Interdepartementale Werkgroep Desinformatie → Onderwerp: Overleg overig
# ✅ Match gevonden: Besluit Wob sluiting horeca en winkelgelegenheden → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode mei 2021 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Besluit op Wob-verzoek over nota's en memo's over Covid-19 bij nertsen → Onderwerp: Opstart Corona
# ✅ Match gevonden: Woo-deelbesluit aangaande Digitale Middelen over GGD IT-systemen en DPIA'S → Onderwerp: Digitale middelen
# ✅ Match gevonden: Besluit Wob COVID-19 communicatiebeleid → Onderwerp: Overleg overig
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over de periode januari 2021 → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Eerste deelbesluit Wob-verzoek inzake informatie over de door Nederland gevoerde covid-19 aanpak → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Maatregelen Kerkgangers → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Testen over de periode oktober 2020 → Onderwerp: Testen
# ✅ Match gevonden: Wob-deelbesluit aangaande Digitale Middelen over de periode mei 2020 → Onderwerp: Digitale middelen
# ✅ Match gevonden: Beslissing op bezwaar Wob-besluit coronamaatregelen → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Eerste deelbesluit Wob-verzoek aantal aanwezigen in kerken periode 14 april - 26 oktober 2020 → Onderwerp: Overleg overig
# ✅ Match gevonden: Woo-deelbesluit aangaande Overleg VWS over de periode juni 2020 → Onderwerp: Overleg VWS
# ✅ Match gevonden: Derde deelbesluit op Wob-verzoek inzake het Europees Herstelfonds → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Medische hulpmiddelen over de periode maart 2020 → Onderwerp: Medische hulpmiddelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over de periode maart 2021 → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Besluit Wob-verzoek d.d. 9 juni 2020 inzake contact met het bedrijfsleven over de corona-crisis → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Wob-besluit Wob-verzoek d.d. 13 augustus 2020 inzake medicijnenfabriek Apotex → Onderwerp: Vaccinaties en medicatie
# ✅ Match gevonden: Besluit op Wob-verzoek inzake agenda-afspraken → Onderwerp: Opstart Corona
# ✅ Match gevonden: Besluit op Wob-verzoek coronamaatregelen DJI → Onderwerp: Scenario’s en maatregelen
# ✅ Match gevonden: Woo-deelbesluit aangaande Vaccinaties en Medicatie over de periode december 2020 → Onderwerp: Vaccinaties en medicatie
#      dossier_id                                       dossier_name  \
# 0             1  (4e deel) Besluit Woo-verzoek Covid-19 aanpak ...
# 1             2  Woo-besluit aangaande kaders werkproces Wob-ve...
# 2             3  1e deel Besluit Woo verzoek Covid-19 aanpak AC...
# 3             4  2e deel Besluit Woo verzoek Covid-19 aanpak AC...
# 4             5  3e deel Besluit Woo verzoek Covid-19 aanpak AC...
# ..          ...                                                ...
# 215         216  Woo-deelbesluit aangaande overeenkomsten PCR-l...
# 216         217  Woo-deelbesluit aangaande vaccinatie aansprake...
# 217         218  Woo-deelbesluit aangaande ‘Capaciteit van ziek...
# 218         219  Woo-deelbesluit aangaande ‘de inkoop van perso...
# 219         220  Woo-verzoek d.d. 6 januari 2022 inzake het Eur...
#
#     dossier_published_date dossier_decision_date  document_count  \
# 0               2024-02-05            2023-07-29             229
# 1               2024-03-22            2023-03-20              83
# 2               2024-02-07            2022-08-18             208
# 3               2024-02-08            2023-02-17             239
# 4               2024-02-07            2022-05-12             144
# ..                     ...                   ...             ...
# 215             2024-06-06            2024-03-27              68
# 216             2024-10-09            2024-10-02             116
# 217             2024-10-19            2024-09-12             199
# 218             2024-04-05            2024-02-14            2695
# 219             2024-02-05            2022-05-12               9
#
#                                      dossier_sourceURL  \
# 0            https://open.minvws.nl/dossier/VWS-WC/098
# 1    https://open.minvws.nl/dossier/VWS-WOO/3518578...
# 2            https://open.minvws.nl/dossier/VWS-WC/090
# 3            https://open.minvws.nl/dossier/VWS-WC/095
# 4            https://open.minvws.nl/dossier/VWS-WC/096
# ..                                                 ...
# 215  https://open.minvws.nl/dossier/VWS-WOO/3792667...
# 216  https://open.minvws.nl/dossier/VWS-WOO/3939665...
# 217  https://open.minvws.nl/dossier/VWS-WOO/3959811...
# 218  https://open.minvws.nl/dossier/VWS-WOO/3773352...
# 219          https://open.minvws.nl/dossier/VWS-WC/107
#
#                                    dossier_responsible  \
# 0                ministerie van Justitie en Veiligheid
# 1     ministerie van Volksgezondheid, Welzijn en Sport
# 2                ministerie van Justitie en Veiligheid
# 3                ministerie van Justitie en Veiligheid
# 4                ministerie van Justitie en Veiligheid
# ..                                                 ...
# 215   ministerie van Volksgezondheid, Welzijn en Sport
# 216   ministerie van Volksgezondheid, Welzijn en Sport
# 217   ministerie van Volksgezondheid, Welzijn en Sport
# 218   ministerie van Volksgezondheid, Welzijn en Sport
# 219  ministerie van Landbouw, Visserij, Voedselzeke...
#
#                dossier_subject
# 0               Overleg overig
# 1    Scenario’s en maatregelen
# 2               Overleg overig
# 3               Overleg overig
# 4               Overleg overig
# ..                         ...
# 215                     Testen
# 216   Vaccinaties en medicatie
# 217    Capaciteit ziekenhuizen
# 218                Overleg VWS
# 219             Overleg overig
#
# [220 rows x 8 columns]
# ✅ Onderwerpen toegevoegd en opgeslagen als 'df_dossiers_subject.csv'

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import urljoin
from IPython.display import display

# CSV-bestanden inlezen
df_dossiers = pd.read_csv("df_dossiers_final.csv")
df_documents = pd.read_csv("df_documents.csv")

# Base URL van de site
BASE_URL = "https://open.minvws.nl"

# Mapping van <use> symbolen naar documenttypen
DOCUMENT_TYPE_MAP = {
    "unknown": "Onbekend",
    "pdf": "PDF",
    "email": "E-mailbericht",
    "presentation": "Presentatie",
    "doc": "Word-document",
    "chat": "Chatbericht",
    "image": "Afbeelding",
    "spreadsheet": "Spreadsheet"
}

# Voeg kolommen toe als ze nog niet bestaan
if "document_sourcetype" not in df_documents.columns:
    df_documents["document_sourcetype"] = None
if "document_date" not in df_documents.columns:
    df_documents["document_date"] = None

# Functie om document metadata te scrapen uit een dossierpagina
def get_document_metadata(url, dossier_id):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f"❌ Kan de pagina niet laden: {url} (Status: {response.status_code})")
        return []

    soup = BeautifulSoup(response.text, "html.parser")

    # Documenten verzamelen
    document_rows = soup.select("div[data-e2e-name='documents-section'] table tbody tr")

    metadata_list = []

    for row in document_rows:
        # Documentnaam ophalen en opschonen
        document_name_element = row.select_one("td div.woo-readable-width a.woo-a")
        raw_document_name = document_name_element.get_text(strip=True) if document_name_element else None
        document_name = raw_document_name.replace("_", " ") if raw_document_name else None  # Vervang underscores

        # **Besluitbrief overslaan bij scrapen**
        if document_name and "besluitbrief.pdf" in document_name.lower():
            continue  # Sla besluitbrief.pdf over

        # Documentdatum ophalen
        document_date_element = row.select_one("td time")
        document_date = document_date_element["datetime"] if document_date_element else None

        # Documenttype ophalen uit de <use> of <symbol>
        document_type_element = row.select_one("td svg use")
        document_type = None
        if document_type_element:
            type_symbol = document_type_element["xlink:href"].split("#")[-1]
            document_type = DOCUMENT_TYPE_MAP.get(type_symbol, "Onbekend")

        # Alleen opslaan als er een documentnaam is
        if document_name:
            metadata_list.append({
                "dossier_id": dossier_id,
                "document_title_clean": document_name,  # Schoon document_title (spaties i.p.v. underscores)
                "document_sourcetype": document_type,
                "document_date": document_date
            })

    return metadata_list

# Filter het dossier met dossier_id = 8
df_dossier_8 = df_dossiers[df_dossiers["dossier_id"] == 8]

# Lijst om document-metadata op te slaan
all_metadata = []

# Loop door het dossier (maar nu alleen voor dossier_id=8)
for _, row in df_dossier_8.iterrows():
    dossier_id = row["dossier_id"]
    dossier_url = row["dossier_sourceURL"]

    print(f"🔍 Scrapen van dossier: {dossier_id} → {dossier_url}")

    # Haal metadata van documenten op
    metadata = get_document_metadata(dossier_url, dossier_id)
    all_metadata.extend(metadata)

    time.sleep(1)  # Voorkom blokkering

# Zet de metadata in een DataFrame
df_scraped_metadata = pd.DataFrame(all_metadata)

# 🔹 **Substring-matching met `_` vervangen door spaties**
def match_document_title(scraped_title, df_docs):
    """Zoekt of `scraped_title` als substring voorkomt in `df_docs["document_title"]` (met underscores vervangen door spaties)."""
    scraped_title_clean = scraped_title.replace("_", " ")
    matches = df_docs[df_docs["document_title"].str.replace("_", " ").str.contains(scraped_title_clean, case=False, na=False)]
    if not matches.empty:
        return matches.iloc[0]["document_title"]  # Neem de eerste match
    return None  # Geen match gevonden

# **Filter df_documents zodat alleen documenten van dossier_id = 8 worden meegenomen en besluitbrief.pdf wordt overgeslagen**
df_documents_8 = df_documents[
    (df_documents["dossier_id"] == 8) &
    (~df_documents["document_title"].str.contains("besluitbrief.pdf", case=False, na=False))
].copy()

# Voor elk gescrapet document, zoeken naar een match in df_documents
matched_rows = []
for _, scraped_row in df_scraped_metadata.iterrows():
    matched_title = match_document_title(scraped_row["document_title_clean"], df_documents_8)

    if matched_title:
        matched_rows.append({
            "dossier_id": scraped_row["dossier_id"],
            "document_title": matched_title,
            "document_sourcetype": scraped_row["document_sourcetype"],
            "document_date": scraped_row["document_date"]
        })

# Zet de gematchte metadata in een DataFrame
df_matched_metadata = pd.DataFrame(matched_rows)

# **Merge alleen de documenten die een match hebben (inner join)**
df_documents_8 = df_documents_8.merge(df_matched_metadata, on=["dossier_id", "document_title"], how="inner")

# ✅ **Oude kolommen overschrijven en dubbele verwijderen**
df_documents_8["document_sourcetype"] = df_documents_8["document_sourcetype_y"].combine_first(df_documents_8["document_sourcetype_x"])
df_documents_8["document_date"] = df_documents_8["document_date_y"].combine_first(df_documents_8["document_date_x"])

# ✅ **Verwijder de dubbele kolommen**
df_documents_8.drop(columns=["document_sourcetype_x", "document_sourcetype_y", "document_date_x", "document_date_y"], inplace=True)

# **Sla alleen de correcte documenten op, zonder besluitbrief.pdf**
df_documents_8.to_csv("df_documents_dossier_8.csv", index=False)

# **Weergeven in Jupyter Notebook**
display(df_documents_8)
# Out:
# 🔍 Scrapen van dossier: 8 → https://open.minvws.nl/dossier/VWS-WC/047
#    dossier_id document_id                                     document_title  \
# 0           8         8-1     VWS-WC-047-7-00000148-Hulptroepen_McKinsey.pdf
# 1           8         8-3  VWS-WC-047-10-00000070-PHOTO-2020-04-16-21-28-...
# 2           8         8-4  VWS-WC-047-4-00000304-PHOTO-2020-04-10-23-05-4...
# 3           8         8-5  VWS-WC-047-1-Totaal_overzicht_chats_Bas_vd_Dun...
# 4           8         8-6  VWS-WC-047-3-00000539-PHOTO-2020-05-07-23-03-0...
# 5           8         8-7  VWS-WC-047-5-00000305-PHOTO-2020-04-10-23-06-3...
# 6           8         8-8  VWS-WC-047-6-00000085-PHOTO-2021-05-19-09-09-2...
#
#   document_type document_sourcetype document_date
# 0           pdf            Onbekend    2020-05-07
# 1           pdf            Onbekend    2020-04-16
# 2           pdf            Onbekend    2020-04-10
# 3           pdf                 PDF    2021-06-29
# 4           pdf            Onbekend    2020-05-07
# 5           pdf            Onbekend    2020-04-10
# 6           pdf            Onbekend    2021-05-19

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import urljoin
from IPython.display import display

# CSV-bestanden inlezen
df_dossiers = pd.read_csv("df_dossiers_final.csv")
df_documents = pd.read_csv("df_documents.csv")

# 📌 **Kies hier het dossier_id handmatig**
selected_dossier_id = 1  # Wijzig dit nummer handmatig!

# Base URL van de site
BASE_URL = "https://open.minvws.nl"

# Mapping van <use> symbolen naar documenttypen
DOCUMENT_TYPE_MAP = {
    "unknown": "Onbekend",
    "pdf": "PDF",
    "email": "E-mailbericht",
    "presentation": "Presentatie",
    "doc": "Word-document",
    "chat": "Chatbericht",
    "image": "Afbeelding",
    "spreadsheet": "Spreadsheet"
}

# Voeg kolommen toe als ze nog niet bestaan
if "document_sourcetype" not in df_documents.columns:
    df_documents["document_sourcetype"] = None
if "document_date" not in df_documents.columns:
    df_documents["document_date"] = None

# Functie om document metadata te scrapen uit een dossierpagina
def get_document_metadata(url, dossier_id):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f"❌ Kan de pagina niet laden: {url} (Status: {response.status_code})")
        return []

    soup = BeautifulSoup(response.text, "html.parser")

    # Documenten verzamelen
    document_rows = soup.select("div[data-e2e-name='documents-section'] table tbody tr")

    metadata_list = []

    for row in document_rows:
        # Documentnaam ophalen en opschonen
        document_name_element = row.select_one("td div.woo-readable-width a.woo-a")
        raw_document_name = document_name_element.get_text(strip=True) if document_name_element else None
        document_name = raw_document_name.replace("_", " ") if raw_document_name else None  # Vervang underscores

        # **Besluitbrief overslaan bij scrapen**
        if document_name and "besluitbrief.pdf" in document_name.lower():
            continue  # Sla besluitbrief.pdf over

        # Documentdatum ophalen
        document_date_element = row.select_one("td time")
        document_date = document_date_element["datetime"] if document_date_element else None

        # Documenttype ophalen uit de <use> of <symbol>
        document_type_element = row.select_one("td svg use")
        document_type = None
        if document_type_element:
            type_symbol = document_type_element["xlink:href"].split("#")[-1]
            document_type = DOCUMENT_TYPE_MAP.get(type_symbol, "Onbekend")

        # Alleen opslaan als er een documentnaam is
        if document_name:
            metadata_list.append({
                "dossier_id": dossier_id,
                "document_title_clean": document_name,  # Schoon document_title (spaties i.p.v. underscores)
                "document_sourcetype": document_type,
                "document_date": document_date
            })

    return metadata_list

# **Filter alleen het geselecteerde dossier**
df_selected_dossier = df_dossiers[df_dossiers["dossier_id"] == selected_dossier_id]

# **Check of het dossier bestaat**
if df_selected_dossier.empty:
    print(f"⚠️ Geen dossier gevonden met dossier_id {selected_dossier_id}.")
else:
    dossier_url = df_selected_dossier.iloc[0]["dossier_sourceURL"]
    print(f"🔍 Scrapen van dossier: {selected_dossier_id} → {dossier_url}")

    # **Scrape de documentmetadata**
    metadata = get_document_metadata(dossier_url, selected_dossier_id)

    # **Stop als er geen documenten zijn gevonden**
    if not metadata:
        print(f"⚠️ Geen documenten gevonden voor dossier {selected_dossier_id}.")
    else:
        df_scraped_metadata = pd.DataFrame(metadata)

        # **Filter df_documents voor dit dossier en verwijder besluitbrief.pdf**
        df_documents_dossier = df_documents[
            (df_documents["dossier_id"] == selected_dossier_id) &
            (~df_documents["document_title"].str.contains("besluitbrief.pdf", case=False, na=False))
        ].copy()

        # 🔹 **Substring-matching met `_` vervangen door spaties**
        def match_document_title(scraped_title, df_docs):
            """Zoekt of `scraped_title` als substring voorkomt in `df_docs["document_title"]` (met underscores vervangen door spaties)."""
            scraped_title_clean = scraped_title.replace("_", " ")
            matches = df_docs[df_docs["document_title"].str.replace("_", " ").str.contains(scraped_title_clean, case=False, na=False)]
            if not matches.empty:
                return matches.iloc[0]["document_title"]  # Neem de eerste match
            return None  # Geen match gevonden

        # **Zoek een match voor elk gescrapet document**
        matched_rows = []
        for _, scraped_row in df_scraped_metadata.iterrows():
            matched_title = match_document_title(scraped_row["document_title_clean"], df_documents_dossier)

            if matched_title:
                matched_rows.append({
                    "dossier_id": scraped_row["dossier_id"],
                    "document_title": matched_title,
                    "document_sourcetype": scraped_row["document_sourcetype"],
                    "document_date": scraped_row["document_date"]
                })

        # Zet de gematchte metadata in een DataFrame
        df_matched_metadata = pd.DataFrame(matched_rows)

        # **Merge alleen de documenten die een match hebben (inner join)**
        df_documents_dossier = df_documents_dossier.merge(df_matched_metadata, on=["dossier_id", "document_title"], how="inner")

        # ✅ **Oude kolommen overschrijven en dubbele verwijderen**
        df_documents_dossier["document_sourcetype"] = df_documents_dossier["document_sourcetype_y"].combine_first(df_documents_dossier["document_sourcetype_x"])
        df_documents_dossier["document_date"] = df_documents_dossier["document_date_y"].combine_first(df_documents_dossier["document_date_x"])

        # ✅ **Verwijder de dubbele kolommen**
        df_documents_dossier.drop(columns=["document_sourcetype_x", "document_sourcetype_y", "document_date_x", "document_date_y"], inplace=True)

        # ✅ **Append het dossier naar `df_documenten_date.csv`**
        output_file = "df_documenten_date.csv"
        df_documents_dossier.to_csv(output_file, mode="a", header=not pd.io.common.file_exists(output_file), index=False)

        # ✅ **Laatste status printen**
        print(f"✅ Dossier {selected_dossier_id} toegevoegd aan 'df_documenten_date.csv'")
# Out:
# 🔍 Scrapen van dossier: 1 → https://open.minvws.nl/dossier/VWS-WC/098
# ✅ Dossier 1 toegevoegd aan 'df_documenten_date.csv'
# /tmp/ipykernel_14127/921917194.py:113: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   matches = df_docs[df_docs["document_title"].str.replace("_", " ").str.contains(scraped_title_clean, case=False, na=False)]
