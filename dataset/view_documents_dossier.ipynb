# %%
import pandas as pd

# CSV-bestanden inlezen
df_dossiers = pd.read_csv("ALL/df_dossiers.csv")
df_documents = pd.read_csv("df_ALL_documents.csv")

selected_dossier_id = 194

df_selected_documents = df_documents[df_documents["dossier_id"] == selected_dossier_id]

pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)
pd.set_option("display.max_rows", None)
display(df_selected_documents)
# Out:
#        Unnamed: 0  dossier_id document_id         document_title document_type document_sourcetype document_date                                                                      document_sourcelocal                                                                     document_sourceURL
# 57801       57801         194       194-1  VWS-WOO-06-187999.pdf           PDF       E-mailbericht    2020-09-20  /home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles/dossier_194/VWS-WOO-06-187999.pdf  https://open.minvws.nl/dossier/VWS-WOO/3561075-1045762-pdo/document/VWS-WOO-06-187999
# 57802       57802         194       194-2  VWS-WOO-06-200119.pdf           PDF       E-mailbericht    2020-10-02  /home/nena-meijer/PyCharmMiscProject/unpacked_zipfiles/dossier_194/VWS-WOO-06-200119.pdf  https://open.minvws.nl/dossier/VWS-WOO/3561075-1045762-pdo/document/VWS-WOO-06-200119
# ...
