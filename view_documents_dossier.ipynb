# %%
import pandas as pd

# CSV-bestanden inlezen
df_dossiers = pd.read_csv("df_dossiers_final.csv")
df_documents = pd.read_csv("old_csvs/df_documents_dates.csv")

selected_dossier_id = 220

df_selected_documents = df_documents[df_documents["dossier_id"] == selected_dossier_id]

pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 1000)
pd.set_option("display.max_rows", None)
display(df_selected_documents)
# Out:
#         dossier_id document_id                                                                                            document_title document_type document_sourcetype document_date
# 109025         220       220-1                                                                                          besluitbrief.pdf           pdf                 NaN           NaN
# 109026         220       220-2                                    VWS-WC-107-1a-2020_RV_0022_Masterplan_emissieloze_maritieme_sector.pdf           pdf            Onbekend    2020-09-16
# 109027         220       220-3                                    VWS-WC-107-5-Reactie_gevraagd_op_fiche_emissieloze_kotter_voor_RRF.pdf           pdf       E-mailbericht    2020-12-15
# 109028         220       220-4  VWS-WC-107-2-Terugkoppeling_gesprek_masterplan_voor_een_emissieloze_maritieme_sector__X___ma._7_dece.pdf           pdf       E-mailbericht    2020-12-08
# 109029         220       220-5                                    VWS-WC-107-2a-2020_RV_0022_Masterplan_emissieloze_maritieme_sector.pdf           pdf            Onbekend    2020-12-08
# 109030         220       220-6                                      VWS-WC-107-1-FW_Masterplan_voor_een_emissieloze_maritieme_sector.pdf           pdf       E-mailbericht    2020-09-16
# 109031         220       220-7                                                        VWS-WC-107-4-video-overleg_Corona_herstelfonds.pdf           pdf       E-mailbericht    2020-12-14
# 109032         220       220-8                  VWS-WC-107-3-Vraag_om_informatie_over_RFF_in_relatie_tot_emissiearme_kotter_visserij.pdf           pdf       E-mailbericht    2020-12-08
# 109033         220       220-9                                 VWS-WC-107-6-RE_Reactie_gevraagd_op_fiche_emissieloze_kotter_voor_RRF.pdf           pdf       E-mailbericht    2020-12-16
